# %% [markdown]
# <h1>목차<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#각-요소별-데이터-그룹바이하기" data-toc-modified-id="각-요소별-데이터-그룹바이하기-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>각 요소별 데이터 그룹바이하기</a></span></li><li><span><a href="#칼럼명-바꾸기" data-toc-modified-id="칼럼명-바꾸기-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>칼럼명 바꾸기</a></span></li><li><span><a href="#검증" data-toc-modified-id="검증-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>검증</a></span></li><li><span><a href="#오류난-것들...기록" data-toc-modified-id="오류난-것들...기록-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>오류난 것들...기록</a></span></li><li><span><a href="#가로등-데이터:-세종특별자치시-결측치-대체" data-toc-modified-id="가로등-데이터:-세종특별자치시-결측치-대체-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>가로등 데이터: 세종특별자치시 결측치 대체</a></span></li><li><span><a href="#다시-합치기.." data-toc-modified-id="다시-합치기..-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>다시 합치기..</a></span></li><li><span><a href="#city-충복치-확인-후-지우기" data-toc-modified-id="city-충복치-확인-후-지우기-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>city 충복치 확인 후 지우기</a></span></li><li><span><a href="#nan값을-제외하고-정수형으로-바꾸기-시도-(실패함-ㅠ.ㅜ)" data-toc-modified-id="nan값을-제외하고-정수형으로-바꾸기-시도-(실패함-ㅠ.ㅜ)-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>nan값을 제외하고 정수형으로 바꾸기 시도 (실패함 ㅠ.ㅜ)</a></span></li><li><span><a href="#city와-state에-시도명이-겹치지-않는지-확인하기" data-toc-modified-id="city와-state에-시도명이-겹치지-않는지-확인하기-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>city와 state에 시도명이 겹치지 않는지 확인하기</a></span></li><li><span><a href="#new_state값이-모두-올바른지-확인" data-toc-modified-id="new_state값이-모두-올바른지-확인-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>new_state값이 모두 올바른지 확인</a></span></li><li><span><a href="#올바르지-않은-값들-확인하기" data-toc-modified-id="올바르지-않은-값들-확인하기-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>올바르지 않은 값들 확인하기</a></span></li><li><span><a href="#데이터를-고치기-위한-df만들기" data-toc-modified-id="데이터를-고치기-위한-df만들기-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>데이터를 고치기 위한 df만들기</a></span></li><li><span><a href="#df3의-state,-city가-df2의-state,-city-와-같으면-df3에-df2를-더해주기" data-toc-modified-id="df3의-state,-city가-df2의-state,-city-와-같으면-df3에-df2를-더해주기-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>df3의 state, city가 df2의 state, city 와 같으면 df3에 df2를 더해주기</a></span></li><li><span><a href="#잘못된-데이터-drop-후-확인" data-toc-modified-id="잘못된-데이터-drop-후-확인-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>잘못된 데이터 drop 후 확인</a></span></li><li><span><a href="#세종시-00면-데이터를-세종특별자치시-데이터-하나로-통일하기" data-toc-modified-id="세종시-00면-데이터를-세종특별자치시-데이터-하나로-통일하기-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>세종시 00면 데이터를 세종특별자치시 데이터 하나로 통일하기</a></span></li><li><span><a href="#시도별-top5-데이터-선별하기" data-toc-modified-id="시도별-top5-데이터-선별하기-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>시도별 top5 데이터 선별하기</a></span></li><li><span><a href="#top5-데이터만-모아서-결합하기" data-toc-modified-id="top5-데이터만-모아서-결합하기-17"><span class="toc-item-num">17&nbsp;&nbsp;</span>top5 데이터만 모아서 결합하기</a></span></li><li><span><a href="#데이터-개수-확인" data-toc-modified-id="데이터-개수-확인-18"><span class="toc-item-num">18&nbsp;&nbsp;</span>데이터 개수 확인</a></span></li></ul></div>

# %% [markdown]
# ### 각 요소별 데이터 그룹바이하기

# %%
import pandas as pd
df_cctv = pd.read_csv('./cctvdf_fin_2.csv', encoding='cp949')
df_sclight = pd.read_csv('./df_sclight.csv', encoding='cp949')
df_smalight = pd.read_csv('./df_smalight.csv', encoding='cp949')
df_strlamp = pd.read_csv('./df_strlamp.csv', encoding='cp949')
df_crime = pd.read_csv('./df_crime.csv')

# %%
# 데이터 확인
df_cctv
# Out:
#                        address    state  city        lat        long  \
# 0       강원도 고성군 간성읍 신안리 254-18      강원도   고성군  38.379088  128.470971
# 1       강원도 고성군 간성읍 신안리 254-18      강원도   고성군  38.379088  128.470971
# 2                  강원도 고성군 운봉리      강원도   고성군  38.287864  128.519409
# 3           강원도 고성군 간성읍 간성로 70      강원도   고성군  38.379515  128.467187
# 4           강원도 고성군 간성읍 간성로 70      강원도   고성군  38.379515  128.467187
# ...                        ...      ...   ...        ...         ...
# 283482   세종특별자치시 보듬3로 15 (도담동)  세종특별자치시   도담동  36.512413  127.258024
# 283483   세종특별자치시 보듬5로 15 (도담동)  세종특별자치시   도담동  36.516073  127.257219
# 283484    세종특별자치시 보듬7로 1 (도담동)  세종특별자치시   도담동  36.517906  127.258179
# 283485   세종특별자치시 세종 조치원읍 남리 84  세종특별자치시  조치원읍  36.595287  127.303549
# 283486    세종특별자치시 보듬7로 1 (도담동)  세종특별자치시   도담동  36.518255  127.258233
#
#         install_cnt        date
# 0                 1  2020-07-01
# 1                 1  2020-07-01
# 2                 1  2020-07-01
# ...

# %%
df_sclight
# Out:
#                          address state city        lat        long  \
# 0              강원도 강릉시 장현동 463-1   강원도  강릉시  37.728580  128.887487
# 1               강원도 강릉시 장현동 40-1   강원도  강릉시  37.732262  128.900575
# 2               강원도 강릉시 장현동 97-2   강원도  강릉시  37.730126  128.900761
# 3               강원도 강릉시 담산동 55-1   강원도  강릉시  37.717822  128.904406
# 4               강원도 강릉시 담산동 55-1   강원도  강릉시  37.717822  128.904406
# ...                          ...   ...  ...        ...         ...
# 1688370  충청북도 충주시 수안보면 온천리 111-2  충청북도  충주시  36.845823  127.994736
# 1688371  충청북도 충주시 수안보면 온천리 131-2  충청북도  충주시  36.845097  127.994223
# 1688372   충청북도 충주시 수안보면 온천리 산2-3  충청북도  충주시  36.845238  127.999317
# 1688373  충청북도 충주시 수안보면 안보리 산1-12  충청북도  충주시  36.845208  128.000003
# 1688374  충청북도 충주시 수안보면 안보리 579-2  충청북도  충주시  36.844581  128.001291
#
#          install_cnt        date  avg_pop_density
# 0                  1  2022-07-20            90.36
# 1                  1  2022-07-20            90.36
# ...

# %%
df_smalight
# Out:
#                        address  state city        lat        long  \
# 0             도척면 궁평리 269-12 답    경기도  광주시  37.338009  127.322730
# 1              도척면 진우리 912-11구    경기도  광주시  37.307716  127.357983
# 2                도척면 상림리 99-4도    경기도  광주시  37.317668  127.305199
# 3                 도척면 궁평리 917도    경기도  광주시  37.343562  127.320075
# 4             도척면 궁평리 894-130천    경기도  광주시  37.335860  127.325204
# ...                        ...    ...  ...        ...         ...
# 73708         인천광역시 귤현동 145-14  인천광역시  계양구  37.535750  126.753260
# 73709         인천광역시 귤현동 145-14  인천광역시  계양구  37.535750  126.753260
# 73710         인천광역시 동양동 612-10  인천광역시  계양구  37.532144  126.711930
# 73711  전라남도 구례꾼 구례읍 봉북리 537-12   전라남도  구례군  35.220362  127.467767
# 73712  전라남도 구례꾼 구례읍 봉북리 1427-3   전라남도  구례군  35.219053  127.468991
#
#        install_cnt        date
# 0              NaN  2021-08-24
# 1              NaN  2021-08-24
# 2              NaN  2021-08-24
# 3              NaN  2021-08-24
# ...

# %%
df_strlamp
# Out:
#     state  city  install_cnt        date
# 0   부산광역시    동구         2900         NaN
# 1   부산광역시   동래구         4532         NaN
# 2   부산광역시    북구         4521         NaN
# 3   부산광역시   강서구        19623         NaN
# 4   부산광역시    진구         8258  2022-10-18
# ..    ...   ...          ...         ...
# 92  대전광역시   유성구        17266         NaN
# 93  대전광역시    중구         4958         NaN
# 94   전라북도   군산시        16668         NaN
# 95    제주도   제주시        43465         NaN
# 96    제주도  서귀포시        29567         NaN
#
# [97 rows x 4 columns]

# %%
df_crime
# Out:
#       state  crime_rate
# 0       강원도      0.0271
# 1       경기도      0.2489
# 2      경상남도      0.0722
# 3      경상북도      0.0451
# 4     광주광역시      0.0283
# 5     대구광역시      0.0494
# 6     대전광역시      0.0307
# 7     부산광역시      0.0767
# 8     서울특별시      0.1929
# 9   세종특별자치시      0.0041
# 10    울산광역시      0.0136
# 11    인천광역시      0.0587
# 12     전라남도      0.0343
# 13     전라북도      0.0324
# 14  제주특별자치도      0.0189
# 15     충청남도      0.0368
# 16     충청북도      0.0299

# %%
# df_cctv['install_cnt'] = 1
#df_smalight['install_cnt'] = 1

# %%
df_smalight.loc[df_smalight.state == '서울특별시시', 'state'] = '서울특별시'

# %%
df_smalight.loc[df_smalight.city == '동대문고','city'] = '동대문구'
df_smalight.loc[df_smalight.city == '남부소방서', 'city'] = '남구'
df_smalight.loc[df_smalight.city == '남산초등학교', 'city'] = '남구'

# %%
df_strlamp.loc[df_strlamp.state == '제주도', 'state'] = '제주특별자치도'

# %%
df_sclight.loc[df_sclight.city == '유성군', 'city'] = '유성구'

# %%
df_sclight.loc[df_sclight.city == '유성군']
# Out:
# Empty DataFrame
# Columns: [address, state, city, lat, long, install_cnt, date, avg_pop_density]
# Index: []

# %%
a = {'install_cnt':'sum',

    }

b = {'install_cnt':'sum',
     
    }
c = {'install_cnt':'sum',
     'avg_pop_density':'mean'
    }
groupby_cctv = df_cctv.groupby(['state', 'city',], as_index=False).agg(a)
groupby_sclight = df_sclight.groupby(['state', 'city'], as_index=False).agg(c)
groupby_smalight = df_smalight.groupby(['state', 'city'], as_index=False).agg(a)
groupby_strlamp = df_strlamp.groupby(['state', 'city'], as_index=False).agg(b)

# %%
groupby_cctv
# Out:
#     state city  install_cnt
# 0     강원도  강릉시         1699
# 1     강원도  고성군          422
# 2     강원도  동해시          330
# 3     강원도  삼척시          932
# 4     강원도  속초시          441
# ..    ...  ...          ...
# 247  충청북도  제천시          979
# 248  충청북도  증평군          910
# 249  충청북도  진천군          692
# 250  충청북도  청주시            9
# 251  충청북도  충주시         1578
#
# [252 rows x 3 columns]

# %%
groupby_sclight
# Out:
#     state city  install_cnt  avg_pop_density
# 0     강원도  강릉시        12301            90.36
# 1     강원도  근남면            1            90.36
# 2     강원도  동해시         4555            90.36
# 3     강원도  삼척시         7813            90.36
# 4     강원도  속초시         3118            90.36
# ..    ...  ...          ...              ...
# 228  충청북도  제천시         9024           219.20
# 229  충청북도  증평군         3869           219.20
# 230  충청북도  진천군            2           219.20
# 231  충청북도  청주시        25432           219.20
# 232  충청북도  충주시        10600           219.20
#
# [233 rows x 4 columns]

# %%
groupby_smalight
# Out:
#     state city  install_cnt
# 0     강원도  강릉시          0.0
# 1     강원도  고성군          0.0
# 2     강원도  동해시          0.0
# 3     강원도  삼척시          0.0
# 4     강원도  양구군          0.0
# ..    ...  ...          ...
# 207  충청북도  음성군          0.0
# 208  충청북도  제천시          0.0
# 209  충청북도  증평군          0.0
# 210  충청북도  청원군          0.0
# 211  충청북도  충주시          0.0
#
# [212 rows x 3 columns]

# %%
groupby_strlamp
# Out:
#    state city  install_cnt
# 0    강원도  춘천시        12850
# 1    경기도  고양시           42
# 2    경기도  광주시         7529
# 3    경기도  김포시        19499
# 4    경기도  수원시        24704
# ..   ...  ...          ...
# 91  충청남도  부여군           10
# 92  충청남도  서산시          100
# 93  충청남도  아산시           47
# 94  충청남도  홍성군          100
# 95  충청북도  진천군          121
#
# [96 rows x 3 columns]

# %% [markdown]
# ### 칼럼명 바꾸기

# %%
col_cctv = ['state', 'city', 'cctv_cnt']
col_sclight = ['state', 'city', 'sclight_cnt', 'avg_pop_density']
col_smalight = ['state', 'city', 'smalight_cnt']
col_strlamp = ['state', 'city', 'strlamp_cnt']

# %%
groupby_cctv.columns = col_cctv
groupby_sclight.columns = col_sclight
groupby_smalight.columns = col_smalight
groupby_strlamp.columns = col_strlamp

# %%
groupby_cctv
# Out:
#     state city  cctv_cnt
# 0     강원도  강릉시      1699
# 1     강원도  고성군       422
# 2     강원도  동해시       330
# 3     강원도  삼척시       932
# 4     강원도  속초시       441
# ..    ...  ...       ...
# 247  충청북도  제천시       979
# 248  충청북도  증평군       910
# 249  충청북도  진천군       692
# 250  충청북도  청주시         9
# 251  충청북도  충주시      1578
#
# [252 rows x 3 columns]

# %%
groupby_smalight
# Out:
#     state city  smalight_cnt
# 0     강원도  강릉시            64
# 1     강원도  고성군            94
# 2     강원도  동해시           184
# 3     강원도  삼척시            46
# 4     강원도  양구군            22
# ..    ...  ...           ...
# 207  충청북도  음성군           353
# 208  충청북도  제천시           314
# 209  충청북도  증평군             8
# 210  충청북도  청원군             1
# 211  충청북도  충주시           219
#
# [212 rows x 3 columns]

# %%
groupby_strlamp
# Out:
#    state city  strlamp_cnt
# 0    강원도  춘천시        12850
# 1    경기도  고양시           42
# 2    경기도  광주시         7529
# 3    경기도  김포시        19499
# 4    경기도  수원시        24704
# ..   ...  ...          ...
# 91  충청남도  부여군           10
# 92  충청남도  서산시          100
# 93  충청남도  아산시           47
# 94  충청남도  홍성군          100
# 95  충청북도  진천군          121
#
# [96 rows x 3 columns]

# %%
groupby_sclight
# Out:
#     state city  sclight_cnt  avg_pop_density
# 0     강원도  강릉시        12301            90.36
# 1     강원도  근남면            1            90.36
# 2     강원도  동해시         4555            90.36
# 3     강원도  삼척시         7813            90.36
# 4     강원도  속초시         3118            90.36
# ..    ...  ...          ...              ...
# 228  충청북도  제천시         9024           219.20
# 229  충청북도  증평군         3869           219.20
# 230  충청북도  진천군            2           219.20
# 231  충청북도  청주시        25432           219.20
# 232  충청북도  충주시        10600           219.20
#
# [233 rows x 4 columns]

# %%
groupby_sclight.isnull().sum()
# Out:
# state              0
# city               0
# sclight_cnt        0
# avg_pop_density    2
# dtype: int64

# %%
groupby_sclight.avg_pop_density == None
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 228    False
# 229    False
# 230    False
# 231    False
# 232    False
# Name: avg_pop_density, Length: 233, dtype: bool

# %%
df_crime
# Out:
#       state  crime_rate
# 0       강원도      0.0271
# 1       경기도      0.2489
# 2      경상남도      0.0722
# 3      경상북도      0.0451
# 4     광주광역시      0.0283
# 5     대구광역시      0.0494
# 6     대전광역시      0.0307
# 7     부산광역시      0.0767
# 8     서울특별시      0.1929
# 9   세종특별자치시      0.0041
# 10    울산광역시      0.0136
# 11    인천광역시      0.0587
# 12     전라남도      0.0343
# 13     전라북도      0.0324
# 14  제주특별자치도      0.0189
# 15     충청남도      0.0368
# 16     충청북도      0.0299

# %%
# concat을 했더니 결측값이 들어가는 문제가 발생 -> merge로 방향 선회
# pd.concat([groupby_cctv, groupby_sclight, groupby_smalight, groupby_strlamp], axis=1)
df1 = pd.merge(groupby_cctv, groupby_sclight, how = 'outer', on=['state', 'city'])
df2 = pd.merge(df1, groupby_smalight, how = 'outer', on=['state', 'city'])
df3 = pd.merge(df2, groupby_strlamp, how = 'outer', on=['state', 'city'])
df4 = pd.merge(df3, df_crime, how = 'outer', on='state')

df4
# Out:
#     state city  cctv_cnt  sclight_cnt  avg_pop_density  smalight_cnt  \
# 0     강원도  강릉시    1699.0      12301.0            90.36          64.0
# 1     강원도  고성군     422.0          NaN              NaN          94.0
# 2     강원도  동해시     330.0       4555.0            90.36         184.0
# 3     강원도  삼척시     932.0       7813.0            90.36          46.0
# 4     강원도  속초시     441.0       3118.0            90.36           NaN
# ..    ...  ...       ...          ...              ...           ...
# 272  충청북도  증평군     910.0       3869.0           219.20           8.0
# 273  충청북도  진천군     692.0          2.0           219.20           NaN
# 274  충청북도  청주시       9.0      25432.0           219.20           NaN
# 275  충청북도  충주시    1578.0      10600.0           219.20         219.0
# 276  충청북도  청원군       NaN          NaN              NaN           1.0
#
#      strlamp_cnt  crime_rate
# 0            NaN      0.0271
# 1            NaN      0.0271
# 2            NaN      0.0271
# ...

# %% [markdown]
# ### 검증

# %%
check_cctv = df_cctv.city.unique().tolist()
check_sclight = df_sclight.city.unique().tolist()
check_smalight = df_smalight.city.unique().tolist()
check_strlamp = df_strlamp.city.unique().tolist()

# check_cctv
# check_sclight
# check_smalight
# check_strlamp

# %%
check_all = set(check_cctv + check_sclight + check_smalight + check_strlamp)
len(check_all)
check_all

# %%
len(df3.city.unique())

# %%
check_1 = df3.city.unique().tolist()
check_2 = check_all - set(check_1)
len(check_2)
check_2

# %%
check_1

# %%
df3.to_csv('./final_concat')

# %%
# end-of-file

# %% [markdown]
# ### 오류난 것들...기록

# %%
df_strlamp.loc[df_strlamp.city.isnull()]

# %%
df_strlamp.loc[df_strlamp.state == '세종특별자치시']

# %%
df_strlamp.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df_strlamp.to_csv('C:/Users/TECH2_24/DATA_VIS/df_strlamp.csv', encoding='cp949', index=False)

# %% [markdown]
# ### 가로등 데이터: 세종특별자치시 결측치 대체
# *  KOSIS: 세종특별자치시 행정구역 면적 -> '면적/총면적' 계산 (in Excel)
# https://kosis.kr/statHtml/statHtml.do?orgId=208&tblId=DT_20802N_001&vw_cd=MT_OTITLE&list_id=208_BA208_SA&scrId=&seqNo=&lang_mode=ko&obj_var_id=&itm_id=&conn_path=K2&path=%252Fcommon%252Fmeta_onedepth.jsp
#
# *  가로등(원래 구글드라이브에 올려준 전처리 끝난 데이터, df_strlamp): '면적/총면적' * '가로등 개수' 로 배분 및 대체 (in Excel)

# %%
df_strlamp_final = pd.read_csv('./df_strlamp.csv', encoding='cp949')
df_strlamp_final

# %% [markdown]
# ### 다시 합치기..

# %%
b = {'install_cnt':'sum',
     
    }

groupby_strlamp = df_strlamp_final.groupby(['state', 'city'], as_index=False).agg(b)
groupby_strlamp

# %% [markdown]
# ### city 충복치 확인 후 지우기
# * state는 다르지만 city가 같은 데이터가 중복되는 문제 발생
# * 세종특별자치시에서 city가 중복된 3개 지움

# %%
df
# Out:
#        state  city  cctv_cnt  sclight_cnt  smalight_cnt  strlamp_cnt  \
# 0        강원도   강릉시      1699        12301            64        99994
# 1        강원도   고성군       422        99992            94        99994
# 2        강원도   동해시       330         4555           184        99994
# 3        강원도   삼척시       932         7813            46        99994
# 4        강원도   속초시       441         3118         99993        99994
# 5        강원도   양구군       296          190            22        99994
# 6        강원도   양양군       347         4391            40        99994
# 7        강원도   영월군       281            2         99993        99994
# 8        강원도   원주시      2820        10937           986        99994
# 9        강원도   인제군       280         2034         99993        99994
# 10       강원도   정선군       515        99992            13        99994
# 11       강원도   철원군       684         3776         99993        99994
# 12       강원도   춘천시       955        11336            27        12850
# ...

# %%
df[df.new_state.duplicated()]
# Out:
# Empty DataFrame
# Columns: [state, city, cctv_cnt, sclight_cnt, smalight_cnt, strlamp_cnt, crime_rate, avg_pop_density, new_state]
# Index: []

# %%
# drop 전 행 개수 : 277
df.shape
# Out:
# (274, 9)

# %%
idx_to_drop = [163,167,168]
df.drop(idx_to_drop, axis=0, inplace=True)

# %%
df[df.city.str.contains('대평동')].city.unique()
# Out:
# array(['대평동'], dtype=object)

# %%
df['new_state'] = df.state + ' ' + df.city

# %%
df[(df.strlamp_cnt==99994) & (df.state == '경상남도')]['city'].unique()
# Out:
# array(['거제시', '거창군', '고성군', '김해시', '남해군', '밀양시', '사천시', '산청군', '양산시',
#        '의령군', '진주시', '창녕군', '창원시', '통영시', '하동군', '함안군', '함양군', '합천군',
#        '거제면', '진영읍'], dtype=object)

# %%
df.to_csv('./df_security_cancat-2.csv',encoding='cp949')

# %%
col_strlamp = ['strlamp_cnt']
groupby_strlamp.columns = col_strlamp

# %%
test_df
# Out:
#     state city  cctv_cnt  sclight_cnt  avg_pop_density  smalight_cnt  \
# 0     강원도  강릉시    1699.0      12301.0            90.36          64.0
# 1     강원도  고성군     422.0          NaN              NaN          94.0
# 2     강원도  동해시     330.0       4555.0            90.36         184.0
# 3     강원도  삼척시     932.0       7813.0            90.36          46.0
# 4     강원도  속초시     441.0       3118.0            90.36           NaN
# ..    ...  ...       ...          ...              ...           ...
# 272  충청북도  증평군     910.0       3869.0           219.20           8.0
# 273  충청북도  진천군     692.0          2.0           219.20           NaN
# 274  충청북도  청주시       9.0      25432.0           219.20           NaN
# 275  충청북도  충주시    1578.0      10600.0           219.20         219.0
# 276  충청북도  청원군       NaN          NaN              NaN           1.0
#
#      strlamp_cnt  crime_rate
# 0            NaN      0.0271
# 1            NaN      0.0271
# 2            NaN      0.0271
# ...

# %% [markdown]
# ### nan값을 제외하고 정수형으로 바꾸기 시도 (실패함 ㅠ.ㅜ)

# %%
def sosutjum_out(x):
    try:
        return round(x)
    except:
        pass
sosutjum_out('nan')
test_df.strlamp_cnt = test_df.strlamp_cnt.apply(lambda x: sosutjum_out(x))

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 277 entries, 0 to 276
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   state            277 non-null    object
#  1   city             277 non-null    object
#  2   cctv_cnt         252 non-null    float64
#  3   sclight_cnt      233 non-null    float64
#  4   avg_pop_density  231 non-null    float64
#  5   smalight_cnt     212 non-null    float64
#  6   strlamp_cnt      96 non-null     float64
#  7   crime_rate       277 non-null    float64
# dtypes: float64(6), object(2)
# memory usage: 19.5+ KB

# %%
test_df.strlamp_cnt.astype('int64', errors='ignore')
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#        ...
# 272      NaN
# 273    121.0
# 274      NaN
# 275      NaN
# 276      NaN
# Name: strlamp_cnt, Length: 277, dtype: float64

# %%
test_df = df4.copy()

# %%
df_sclight.loc[df_sclight.state == '제주도']
# Out:
# Empty DataFrame
# Columns: [address, state, city, lat, long, install_cnt, date, avg_pop_density]
# Index: []

# %%
test_df.strlamp_cnt[test_df.strlamp_cnt == None]
# Out:
# Series([], Name: strlamp_cnt, dtype: float64)

# %%
df4.to_csv('./concated_data.csv', encoding='cp949')

# %% [markdown]
# ### city와 state에 시도명이 겹치지 않는지 확인하기
# 추후에 문제가 발생해서 전국구 시도별 행정구역을 찾고 new_state열(ex - 강원도 춘천시)과 비교해서 정확하게 고침

# %%
df4[df4.city.str.endswith('시')].city.unique()
# Out:
# array(['강릉시', '동해시', '삼척시', '속초시', '원주시', '춘천시', '태백시', '고양시', '과천시',
#        '광명시', '광주시', '구리시', '군포시', '김포시', '남양주시', '동두천시', '부천시', '성남시',
#        '수원시', '시흥시', '안산시', '안성시', '안양시', '양주시', '여주시', '오산시', '용인시',
#        '의왕시', '의정부시', '이천시', '파주시', '평택시', '포천시', '하남시', '화성시', '거제시',
#        '김해시', '밀양시', '사천시', '양산시', '진주시', '창원시', '통영시', '경산시', '경주시',
#        '구미시', '김천시', '문경시', '상주시', '안동시', '영주시', '영천시', '포항시', '공주시',
#        '광양시', '나주시', '목포시', '순천시', '여수시', '군산시', '남원시', '익산시', '전주시',
#        '정읍시', '김제시', '순창시', '서귀포시', '제주시', '논산시', '당진시', '보령시', '서산시',
#        '아산시', '천안시', '계룡시', '제천시', '청주시', '충주시'], dtype=object)

# %%
df4[df4.city.str.endswith('군')].city.unique()
# Out:
# array(['고성군', '양구군', '양양군', '영월군', '인제군', '정선군', '철원군', '평창군', '홍천군',
#        '화천군', '횡성군', '양평군', '연천군', '가평군', '거창군', '남해군', '산청군', '의령군',
#        '창녕군', '하동군', '함안군', '함양군', '합천군', '고령군', '군위군', '봉화군', '성주군',
#        '영덕군', '영양군', '예천군', '울릉군', '울진군', '의성군', '청도군', '청송군', '칠곡군',
#        '달성군', '유성군', '기장군', '울주군', '강화군', '옹진군', '강진군', '고흥군', '곡성군',
#        '구례군', '담양군', '보성군', '영광군', '영암군', '완도군', '장성군', '장흥군', '진도군',
#        '함평군', '해남군', '화순군', '무안군', '신안군', '고창군', '무주군', '부안군', '순찬군',
#        '순창군', '완주군', '임실군', '장수군', '진안군', '금산군', '부여군', '서천군', '예산군',
#        '청양군', '태안군', '홍성군', '보은군', '연기군', '괴산군', '단양군', '영동군', '옥천군',
#        '음성군', '증평군', '진천군', '청원군'], dtype=object)

# %%
l1 = df4.city.unique().tolist()

# %%
l1 = df4[df4.city.str.endswith('시')].city.unique().tolist()

# %%
l2 = df4[df4.city.str.endswith('군')].city.unique().tolist()

# %%
test_list1 = []
test_list2 = []
for i in l1:
    test_list1.append(i[:2])
   
    
for j in l2:
    
    test_list2.append(j[:2])
print(test_list1)
print(test_list2)
# Out:
# ['강릉', '동해', '삼척', '속초', '원주', '춘천', '태백', '고양', '과천', '광명', '광주', '구리', '군포', '김포', '남양', '동두', '부천', '성남', '수원', '시흥', '안산', '안성', '안양', '양주', '여주', '오산', '용인', '의왕', '의정', '이천', '파주', '평택', '포천', '하남', '화성', '거제', '김해', '밀양', '사천', '양산', '진주', '창원', '통영', '경산', '경주', '구미', '김천', '문경', '상주', '안동', '영주', '영천', '포항', '공주', '광양', '나주', '목포', '순천', '여수', '군산', '남원', '익산', '전주', '정읍', '김제', '순창', '서귀', '제주', '논산', '당진', '보령', '서산', '아산', '천안', '계룡', '제천', '청주', '충주']
# ['고성', '양구', '양양', '영월', '인제', '정선', '철원', '평창', '홍천', '화천', '횡성', '양평', '연천', '가평', '거창', '남해', '산청', '의령', '창녕', '하동', '함안', '함양', '합천', '고령', '군위', '봉화', '성주', '영덕', '영양', '예천', '울릉', '울진', '의성', '청도', '청송', '칠곡', '달성', '유성', '기장', '울주', '강화', '옹진', '강진', '고흥', '곡성', '구례', '담양', '보성', '영광', '영암', '완도', '장성', '장흥', '진도', '함평', '해남', '화순', '무안', '신안', '고창', '무주', '부안', '순찬', '순창', '완주', '임실', '장수', '진안', '금산', '부여', '서천', '예산', '청양', '태안', '홍성', '보은', '연기', '괴산', '단양', '영동', '옥천', '음성', '증평', '진천', '청원']

# %%
is_jungbok = []
for i in l1:
    if i in l2:
        is_jungbok.append(i)
        
print(is_jungbok)
# Out:
# []
# array(['강릉시', '고성군', '동해시', '삼척시', '속초시', '양구군', '양양군', '영월군', '원주시',
#        '인제군', '정선군', '철원군', '춘천시', '태백시', '평창군', '홍천군', '화천군', '횡성군',
#        '근남면', '철원읍', '고양시', '과천시', '광명시', '광주시', '구리시', '군포시', '김포시',
#        '남양주시', '동두천시', '부천시', '성남시', '수원시', '시흥시', '안산시', '안성시', '안양시',
#        '양주시', '양평군', '여주시', '연천군', '오산시', '용인시', '의왕시', '의정부시', '이천시',
#        '파주시', '평택시', '포천시', '하남시', '화성시', '가평군', '거제시', '거창군', '김해시',
#        '남해군', '밀양시', '사천시', '산청군', '양산시', '의령군', '진주시', '창녕군', '창원시',
#        '통영시', '하동군', '함안군', '함양군', '합천군', '거제면', '진영읍', '경산시', '경주시',
#        '고령군', '구미시', '군위군', '김천시', '문경시', '봉화군', '상주시', '성주군', '안동시',
#        '영덕군', '영양군', '영주시', '영천시', '예천군', '울릉군', '울진군', '의성군', '청도군',
#        '청송군', '칠곡군', '포항시', '안막동', '광산구', '남구', '동구', '북구', '서구', '달서구',
#        '달성군', '수성구', '중구', '대덕구', '유성구', '유성군', '강서구', '금정구', '기장군',
#        '동래구', '부산진구', '사상구', '사하구', '수영구', '연제구', '영도구', '해운대구', '연재구',
# ...

# %%
l1

# %%
df4.state.unique()

# %%
df_cctv.state.unique()

# %%
df_crime.state.unique()

# %%
df_sclight.state.unique()

# %%
df_smalight.state.unique()

# %%
df_strlamp.state.unique()

# %% [markdown]
# ---

# %%
df_cctv.city.unique()

# %%
df_sclight.city.unique()

# %%
df_smalight.city.unique()

# %%
df_strlamp.city.unique()

# %% [markdown]
# ### new_state값이 모두 올바른지 확인
# 방문자수 데이터를 합친 후 df에서 city에 오류확인 -> 4가지 경우의 수를 확인해서 각각 조치함

# %%
# 23. 03. 05
import pandas as pd
correction_list = ['강원도 강릉시','강원도 고성군','강원도 동해시','강원도 삼척시','강원도 속초시','강원도 양구군','강원도 양양군','강원도 영월군','강원도 원주시','강원도 인제군','강원도 정선군','강원도 철원군','강원도 춘천시','강원도 태백시','강원도 평창군','강원도 홍천군','강원도 화천군','강원도 횡성군','경기도 가평군','경기도 고양시','경기도 과천시','경기도 광명시','경기도 광주시','경기도 구리시','경기도 군포시','경기도 김포시','경기도 남양주시','경기도 동두천시','경기도 부천시','경기도 성남시','경기도 수원시','경기도 시흥시','경기도 안산시','경기도 안성시','경기도 안양시','경기도 양주시','경기도 양평군','경기도 여주시','경기도 연천군','경기도 오산시','경기도 용인시','경기도 의왕시','경기도 의정부시','경기도 이천시','경기도 파주시','경기도 평택시','경기도 포천시','경기도 하남시','경기도 화성시','경상남도 거제시','경상남도 거창군','경상남도 고성군','경상남도 김해시','경상남도 남해군','경상남도 밀양시','경상남도 사천시','경상남도 산청군','경상남도 양산시','경상남도 의령군','경상남도 진주시','경상남도 창녕군','경상남도 창원시','경상남도 통영시','경상남도 하동군','경상남도 함안군','경상남도 함양군','경상남도 합천군','경상북도 경산시','경상북도 경주시','경상북도 고령군','경상북도 구미시','경상북도 군위군','경상북도 김천시','경상북도 문경시','경상북도 봉화군','경상북도 상주시','경상북도 성주군','경상북도 안동시','경상북도 영덕군','경상북도 영양군','경상북도 영주시','경상북도 영천시','경상북도 예천군','경상북도 울릉군','경상북도 울진군','경상북도 의성군','경상북도 청도군','경상북도 청송군','경상북도 칠곡군','경상북도 포항시','광주광역시 광산구','광주광역시 남구','광주광역시 동구','광주광역시 북구','광주광역시 서구','대구광역시 남구','대구광역시 달서구','대구광역시 달성군','대구광역시 동구','대구광역시 북구','대구광역시 서구','대구광역시 수성구','대구광역시 중구','대전광역시 대덕구','대전광역시 동구','대전광역시 서구','대전광역시 유성구','대전광역시 중구','부산광역시 강서구','부산광역시 금정구','부산광역시 기장군','부산광역시 남구','부산광역시 동구','부산광역시 동래구','부산광역시 부산진구','부산광역시 북구','부산광역시 사상구','부산광역시 사하구','부산광역시 서구','부산광역시 수영구','부산광역시 연제구','부산광역시 영도구','부산광역시 중구','부산광역시 해운대구','서울특별시 강남구','서울특별시 강동구','서울특별시 강북구','서울특별시 강서구','서울특별시 관악구','서울특별시 광진구','서울특별시 구로구','서울특별시 금천구','서울특별시 노원구','서울특별시 도봉구','서울특별시 동대문구','서울특별시 동작구','서울특별시 마포구','서울특별시 서대문구','서울특별시 서초구','서울특별시 성동구','서울특별시 성북구','서울특별시 송파구','서울특별시 양천구','서울특별시 영등포구','서울특별시 용산구','서울특별시 은평구','서울특별시 종로구','서울특별시 중구','서울특별시 중랑구','울산광역시 남구','울산광역시 동구','울산광역시 북구','울산광역시 울주군','울산광역시 중구','인천광역시 강화군','인천광역시 계양구','인천광역시 남동구','인천광역시 동구','인천광역시 미추홀구','인천광역시 부평구','인천광역시 서구','인천광역시 연수구','인천광역시 옹진군','인천광역시 중구','전라남도 강진군','전라남도 고흥군','전라남도 곡성군','전라남도 광양시','전라남도 구례군','전라남도 나주시','전라남도 담양군','전라남도 목포시','전라남도 무안군','전라남도 보성군','전라남도 순천시','전라남도 신안군','전라남도 여수시','전라남도 영광군','전라남도 영암군','전라남도 완도군','전라남도 장성군','전라남도 장흥군','전라남도 진도군','전라남도 함평군','전라남도 해남군','전라남도 화순군','전라북도 고창군','전라북도 군산시','전라북도 김제시','전라북도 남원시','전라북도 무주군','전라북도 부안군','전라북도 순창군','전라북도 완주군','전라북도 익산시','전라북도 임실군','전라북도 장수군','전라북도 전주시','전라북도 정읍시','전라북도 진안군','제주특별자치도 서귀포시','제주특별자치도 제주시','충청남도 계룡시','충청남도 공주시','충청남도 금산군','충청남도 논산시','충청남도 당진시','충청남도 보령시','충청남도 부여군','충청남도 서산시','충청남도 서천군','충청남도 아산시','충청남도 예산군','충청남도 천안시','충청남도 청양군','충청남도 태안군','충청남도 홍성군','충청북도 괴산군','충청북도 단양군','충청북도 보은군','충청북도 영동군','충청북도 옥천군','충청북도 음성군','충청북도 제천시','충청북도 증평군','충청북도 진천군','충청북도 청주시','충청북도 충주시']

# %%
df = pd.read_csv('./df_security_concat-3.csv', encoding='cp949')
df
# Out:
#     state city   visit_cnt  cctv_cnt  sclight_cnt  smalight_cnt  strlamp_cnt  \
# 0     강원도  강릉시  26334028.0    1699.0      12301.0          64.0      99994.0
# 1     강원도  고성군  11612683.0     422.0      99992.0          94.0      99994.0
# 2     강원도  동해시   6798468.0     330.0       4555.0         184.0      99994.0
# 3     강원도  삼척시   8614642.0     932.0       7813.0          46.0      99994.0
# 4     강원도  속초시  19495563.0     441.0       3118.0       99993.0      99994.0
# ..    ...  ...         ...       ...          ...           ...          ...
# 270  충청남도  운산면         NaN   99991.0          1.0       99993.0      99994.0
# 271  충청남도  보은군         NaN   99991.0      99992.0           1.0      99994.0
# 272  충청남도  연기군         NaN   99991.0      99992.0           1.0      99994.0
# 273  충청남도  완주군         NaN   99991.0      99992.0           1.0      99994.0
# 274  충청북도  청원군         NaN   99991.0      99992.0           1.0      99994.0
#
#      crime_rate  avg_pop_density new_state
# ...

# %%
# new_state만 리스트로 뽑기
state_list = df.new_state.to_list()

# %%
state_list1 = []
for i in state_list:
    if i[:7] != '세종특별자치시':
        state_list1.append(i)
state_list1
# 오류 발견함 -> new_state에 nan존재
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5276\1233773038.py in <module>
#       1 state_list1 = []
#       2 for i in state_list:
# ----> 3     if i[:7] != '세종특별자치시':
#       4         state_list1.append(i)
#       5 state_list1
#
# TypeError: 'float' object is not subscriptable

# %%
df.loc[df.new_state.isnull()]  # 오류는 이것 때문인걸로....
# Out:
#        state     city   visit_cnt  cctv_cnt  sclight_cnt  smalight_cnt  \
# 149  세종특별자치시  세종특별자치시  18211355.0       NaN          NaN           NaN
#
#      strlamp_cnt  crime_rate  avg_pop_density new_state
# 149          NaN         NaN              NaN       NaN

# %%
# 세종특별자치시가 안 들어간 것만 추출하기 
state_list1 = []
for i in state_list:
    try:
        if i[:7] != '세종특별자치시':
            state_list1.append(i)
    except:
        continue
state_list1
# Out:
# ['강원도 강릉시',
#  '강원도 고성군',
#  '강원도 동해시',
#  '강원도 삼척시',
#  '강원도 속초시',
#  '강원도 양구군',
#  '강원도 양양군',
#  '강원도 영월군',
#  '강원도 원주시',
#  '강원도 인제군',
#  '강원도 정선군',
#  '강원도 철원군',
#  '강원도 춘천시',
#  '강원도 태백시',
#  '강원도 평창군',
#  '강원도 홍천군',
#  '강원도 화천군',
#  '강원도 횡성군',
#  '경기도 가평군',
#  '경기도 고양시',
#  '경기도 과천시',
#  '경기도 광명시',
#  '경기도 광주시',
#  '경기도 구리시',
#  '경기도 군포시',
#  '경기도 김포시',
#  '경기도 남양주시',
#  '경기도 동두천시',
#  '경기도 부천시',
#  '경기도 성남시',
#  '경기도 수원시',
#  '경기도 시흥시',
#  '경기도 안산시',
#  '경기도 안성시',
#  '경기도 안양시',
#  '경기도 양주시',
#  '경기도 양평군',
#  '경기도 여주시',
#  '경기도 연천군',
#  '경기도 오산시',
#  '경기도 용인시',
#  '경기도 의왕시',
#  '경기도 의정부시',
#  '경기도 이천시',
#  '경기도 파주시',
#  '경기도 평택시',
#  '경기도 포천시',
#  '경기도 하남시',
#  '경기도 화성시',
#  '경상남도 거제시',
#  '경상남도 거창군',
#  '경상남도 고성군',
#  '경상남도 김해시',
#  '경상남도 남해군',
#  '경상남도 밀양시',
#  '경상남도 사천시',
#  '경상남도 산청군',
#  '경상남도 양산시',
#  '경상남도 의령군',
#  '경상남도 진주시',
#  '경상남도 창녕군',
#  '경상남도 창원시',
#  '경상남도 통영시',
#  '경상남도 하동군',
#  '경상남도 함안군',
#  '경상남도 함양군',
#  '경상남도 합천군',
#  '경상북도 경산시',
#  '경상북도 경주시',
# ...

# %%
# 올바르지 않은 new_state값 추출
l1 = []
for i in state_list1:
    if i not in correction_list:
        l1.append(i)
print(l1)
# Out:
# ['강원도 근남면', '강원도 철원읍', '경상남도 거제면', '경상남도 진영읍', '경상북도 안막동', '부산광역시 연재구', '부산광역시 진구', '울산광역시 노원구', '인천광역시 남구', '전라남도 용산면', '전라남도 장흥읍', '전라북도 순찬군', '전라북도 공음면', '전라북도 순창시', '전라북도 함양군', '충청남도 평택시', '충청남도 운산면', '충청남도 보은군', '충청남도 연기군', '충청남도 완주군', '충청북도 청원군']

# %% [markdown]
# ### 올바르지 않은 값들 확인하기
# 확인된 바 : 올바르지 않은 값들은 모두 결측치가 세개임
#
# >데이터 전처리 방법 논의하기
# >1. 잘못된 데이터가 아래와 같이 나왔는데 전부 다 결측치가 세개인 것들이야 전처리를 어떻게 해야할까?
# >    * 올바른 데이터에 더하기 (ex - 강원도 철원읍 보안등 10개를 강원도 철원군 보안등 개수에 추가하기)
# >    * 잘못된 데이터 날려버리기
#
# >경우의 수 별 논점
# >1. 시군구 위치가 잘못된 경우 : state와 city중 어느 걸 기준으로 데이터를 통합할 것인지?
#     * ( 예 : 울산광역시 노원구-> 서울특별시 노원구 or 울산광역시 OO구?)
#     * state를 기준으로 할 경우 raw data를 뒤져서 올바른 위치를 찾아봐야 할듯
#     * city를 기준으로 할 경우 state만 바꿔주면 됨
#     * 걍 날려버리기
# >2. 나머지 세개의 경우의 수는 1번 방법대로 하고 잘못된 데이터를 없애버리면 될 듯

# %%
# 개수 확인
len(l1)
# Out:
# 0

# %%
df1 = df.copy()

# %%
c1 = df1.new_state == '강원도 근남면'
c2 = df1.new_state == '강원도 철원읍'
c3 = df1.new_state == '경상남도 거제면'
c4 = df1.new_state == '경상남도 진영읍'
c5 = df1.new_state == '경상북도 안막동'
c6 = df1.new_state == '부산광역시 연재구'
c7 = df1.new_state == '부산광역시 진구'
c8 = df1.new_state == '울산광역시 노원구'
c9 = df1.new_state == '인천광역시 남구'
c10 = df1.new_state == '전라남도 용산면'
c11 = df1.new_state == '전라남도 장흥읍'
c12 = df1.new_state == '전라북도 순찬군'
c13 = df1.new_state == '전라북도 공음면'
c14 = df1.new_state == '전라북도 순창시'
c15 = df1.new_state == '전라북도 함양군'
c16 = df1.new_state == '충청남도 평택시'
c17 = df1.new_state == '충청남도 운산면'
c18 = df1.new_state == '충청남도 보은군'
c19 = df1.new_state == '충청남도 연기군'
c20 = df1.new_state == '충청남도 완주군'
c21 = df1.new_state == '충청북도 청원군' # 21개 맞음

# %%
df1[c1|c2|c3|c4|c5|c6|c7|c8|c9|c10|c11|c12|c13|c14|c15|c16|c17|c18|c19|c20|c21]
# Out:
#      state city  visit_cnt  cctv_cnt  sclight_cnt  smalight_cnt  strlamp_cnt  \
# 229    강원도  근남면        NaN   99991.0          1.0       99993.0      99994.0
# 230    강원도  철원읍        NaN   99991.0         10.0       99993.0      99994.0
# 231   경상남도  거제면        NaN   99991.0          5.0       99993.0      99994.0
# 232   경상남도  진영읍        NaN   99991.0          3.0       99993.0      99994.0
# 233   경상북도  안막동        NaN   99991.0          1.0       99993.0      99994.0
# 234  부산광역시  연재구        NaN   99991.0      99992.0       99993.0       3922.0
# 235  부산광역시   진구        NaN   99991.0      99992.0       99993.0       8258.0
# 261  울산광역시  노원구        NaN   99991.0      99992.0           1.0      99994.0
# 262  인천광역시   남구        NaN   99991.0      99992.0           3.0      99994.0
# 263   전라남도  용산면        NaN   99991.0          1.0       99993.0      99994.0
# 264   전라남도  장흥읍        NaN   99991.0          1.0       99993.0      99994.0
# ...

# %% [markdown]
# ### 데이터를 고치기 위한 df만들기

# %%
# 잘못된 데이터만 추출한 df만들기
df2 = df1[c1|c2|c3|c4|c5|c6|c7|c8|c9|c10|c11|c12|c13|c14|c15|c16|c17|c18|c19|c20|c21]

# %%
# df2의 new_state를 올바르게 고침
df2.loc[df2.new_state == '강원도 근남면' , 'new_state'] = '강원도 철원군'  # city에 시군구가 아닌 읍면동
df2.loc[df2.new_state == '강원도 철원읍' , 'new_state'] = '강원도 철원군'  # city에 시군구가 아닌 읍면동
df2.loc[df2.new_state == '경상남도 거제면' , 'new_state'] = '경상남도 거제시'  # city에 시군구가 아닌 읍면동
df2.loc[df2.new_state == '경상남도 진영읍' , 'new_state'] = '경상남도 김해시'  # city에 시군구가 아닌 읍면동
df2.loc[df2.new_state == '경상북도 안막동' , 'new_state'] = '경상북도 안동시'  # city에 시군구가 아닌 읍면동
df2.loc[df2.new_state == '부산광역시 연재구' , 'new_state'] = '부산광역시 연제구'  # 이름이 잘못됨
df2.loc[df2.new_state == '부산광역시 진구' , 'new_state'] = '부산광역시 부산진구'  # 이름이 잘못됨
df2.loc[df2.new_state == '울산광역시 노원구' , 'new_state'] = '서울특별시 노원구'  # 위치가 잘못됨 - city를 기준으로 전처리
df2.loc[df2.new_state == '인천광역시 남구' , 'new_state'] = '인천광역시 미추홀구'  # 옛 지명
df2.loc[df2.new_state == '전라남도 용산면' , 'new_state'] = '전라남도 장흥군'  # city에 시군구가 아닌 읍면동
df2.loc[df2.new_state == '전라남도 장흥읍' , 'new_state'] = '전라남도 장흥군'  # city에 시군구가 아닌 읍면동
df2.loc[df2.new_state == '전라북도 순찬군' , 'new_state'] = '전라북도 순창군'  # 이름이 잘못됨
df2.loc[df2.new_state == '전라북도 공음면' , 'new_state'] = '전라북도 고창군'  # city에 시군구가 아닌 읍면동
df2.loc[df2.new_state == '전라북도 순창시' , 'new_state'] = '전라북도 순창군'  # 이름이 잘못됨
df2.loc[df2.new_state == '전라북도 함양군' , 'new_state'] = '경상남도 함양군'  # 위치가 잘못됨 - city를 기준으로 전처리
df2.loc[df2.new_state == '충청남도 평택시' , 'new_state'] = '경기도 평택시'  # 위치가 잘못됨 - city를 기준으로 전처리
df2.loc[df2.new_state == '충청남도 운산면' , 'new_state'] = '충청남도 서산시'  # city에 시군구가 아닌 읍면동
df2.loc[df2.new_state == '충청남도 보은군' , 'new_state'] = '충청북도 보은군'  # 위치가 잘못됨 - city를 기준으로 전처리
df2.loc[df2.new_state == '충청남도 연기군' , 'new_state'] = '세종특별자치시 연기면'  # 옛 지명
df2.loc[df2.new_state == '충청남도 완주군' , 'new_state'] = '전라북도 완주군'  # 위치가 잘못됨 - city를 기준으로 전처리
df2.loc[df2.new_state == '충청북도 청원군' , 'new_state'] = '충청북도 청주시'  # 옛 지명

# %%
# new_state에서 시만 슬라이싱해서 city칼럼에 넣어줌
df2['city'] = df2['new_state'].str.split().str[1]
# Out:
# C:\Users\kh983\AppData\Local\Temp\ipykernel_5276\3592588666.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['city'] = df2['new_state'].str.split().str[1]

# %%
# df2통째로 더하기 위해 가공해주기
df2.cctv_cnt[df2.cctv_cnt > 99990] = 0
df2.sclight_cnt[df2.sclight_cnt > 99990] = 0
df2.smalight_cnt[df2.smalight_cnt > 99990] = 0
df2.strlamp_cnt[df2.strlamp_cnt > 99990] = 0
df2.visit_cnt = 0

df2.crime_rate = 0
df2.avg_pop_density = 0
df2.new_state = ''
# Out:
# C:\Users\kh983\AppData\Local\Temp\ipykernel_5276\4282514729.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.cctv_cnt[df2.cctv_cnt > 99990] = 0
# C:\Users\kh983\AppData\Local\Temp\ipykernel_5276\4282514729.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.sclight_cnt[df2.sclight_cnt > 99990] = 0
# C:\Users\kh983\AppData\Local\Temp\ipykernel_5276\4282514729.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# iloc과 for문을 사용하기 위해 index 재배치
df2.reset_index(drop=True, inplace=True)

# %%
#결과물
df2
# Out:
#     state  city  visit_cnt  cctv_cnt  sclight_cnt  smalight_cnt  strlamp_cnt  \
# 0     강원도   철원군          0       0.0          1.0           0.0          0.0
# 1     강원도   철원군          0       0.0         10.0           0.0          0.0
# 2    경상남도   거제시          0       0.0          5.0           0.0          0.0
# 3    경상남도   김해시          0       0.0          3.0           0.0          0.0
# 4    경상북도   안동시          0       0.0          1.0           0.0          0.0
# 5   부산광역시   연제구          0       0.0          0.0           0.0       3922.0
# 6   부산광역시  부산진구          0       0.0          0.0           0.0       8258.0
# 7   울산광역시   노원구          0       0.0          0.0           1.0          0.0
# 8   인천광역시  미추홀구          0       0.0          0.0           3.0          0.0
# 9    전라남도   장흥군          0       0.0          1.0           0.0          0.0
# 10   전라남도   장흥군          0       0.0          1.0           0.0          0.0
# ...

# %% [markdown]
# ### df3의 state, city가 df2의 state, city 와 같으면 df3에 df2를 더해주기

# %%
df3 = df1.copy()

# %%
for j in range(len(df1)):
    for i in range(19):
        if df2.iloc[i,0] == df3.iloc[j,0] and df2.iloc[i,1] == df3.iloc[j,1]:
            df3.iloc[j,3] += df2.iloc[i,3]
            df3.iloc[j,4] += df2.iloc[i,4]
            df3.iloc[j,5] += df2.iloc[i,5]
            df3.iloc[j,6] += df2.iloc[i,6]

# %%
# 확인용
df1[df.city=='안동시'] # before
# Out:
#    state city   visit_cnt  cctv_cnt  sclight_cnt  smalight_cnt  strlamp_cnt  \
# 77  경상북도  안동시  10848781.0     858.0      13309.0           6.0      13433.0
#
#     crime_rate  avg_pop_density new_state
# 77      0.0451           139.72  경상북도 안동시

# %%
df3[df3.city=='안동시'] # after, sclight_cnt만 1늘어났다.
# Out:
#    state city   visit_cnt  cctv_cnt  sclight_cnt  smalight_cnt  strlamp_cnt  \
# 77  경상북도  안동시  10848781.0     858.0      13310.0           6.0      13433.0
#
#     crime_rate  avg_pop_density new_state
# 77      0.0451           139.72  경상북도 안동시

# %%
df1.loc[df3.city == '미추홀구']  # before
# Out:
#      state  city   visit_cnt  cctv_cnt  sclight_cnt  smalight_cnt  \
# 159  인천광역시  미추홀구  22630637.0    1812.0       9052.0         194.0
#
#      strlamp_cnt  crime_rate  avg_pop_density   new_state
# 159       4407.0      0.0587          2765.64  인천광역시 미추홀구

# %%
df3.loc[df3.city == '미추홀구'] # after, smalight_cnt만 3늘어났다.
# Out:
#      state  city   visit_cnt  cctv_cnt  sclight_cnt  smalight_cnt  \
# 159  인천광역시  미추홀구  22630637.0    1812.0       9052.0         197.0
#
#      strlamp_cnt  crime_rate  avg_pop_density   new_state
# 159       4407.0      0.0587          2765.64  인천광역시 미추홀구

# %% [markdown]
# ### 잘못된 데이터 drop 후 확인

# %%
idx = df1[c1|c2|c3|c4|c5|c6|c7|c8|c9|c10|c11|c12|c13|c14|c15|c16|c17|c18|c19|c20|c21].index

# %%
df3.drop(idx, axis=0, inplace = True)

# %%
state_list = df3.new_state.to_list()

# %%
state_list1 = []
for i in state_list:
    try:
        if i[:7] != '세종특별자치시':
            state_list1.append(i)
    except:
        continue
state_list1
# Out:
# ['강원도 강릉시',
#  '강원도 고성군',
#  '강원도 동해시',
#  '강원도 삼척시',
#  '강원도 속초시',
#  '강원도 양구군',
#  '강원도 양양군',
#  '강원도 영월군',
#  '강원도 원주시',
#  '강원도 인제군',
#  '강원도 정선군',
#  '강원도 철원군',
#  '강원도 춘천시',
#  '강원도 태백시',
#  '강원도 평창군',
#  '강원도 홍천군',
#  '강원도 화천군',
#  '강원도 횡성군',
#  '경기도 가평군',
#  '경기도 고양시',
#  '경기도 과천시',
#  '경기도 광명시',
#  '경기도 광주시',
#  '경기도 구리시',
#  '경기도 군포시',
#  '경기도 김포시',
#  '경기도 남양주시',
#  '경기도 동두천시',
#  '경기도 부천시',
#  '경기도 성남시',
#  '경기도 수원시',
#  '경기도 시흥시',
#  '경기도 안산시',
#  '경기도 안성시',
#  '경기도 안양시',
#  '경기도 양주시',
#  '경기도 양평군',
#  '경기도 여주시',
#  '경기도 연천군',
#  '경기도 오산시',
#  '경기도 용인시',
#  '경기도 의왕시',
#  '경기도 의정부시',
#  '경기도 이천시',
#  '경기도 파주시',
#  '경기도 평택시',
#  '경기도 포천시',
#  '경기도 하남시',
#  '경기도 화성시',
#  '경상남도 거제시',
#  '경상남도 거창군',
#  '경상남도 고성군',
#  '경상남도 김해시',
#  '경상남도 남해군',
#  '경상남도 밀양시',
#  '경상남도 사천시',
#  '경상남도 산청군',
#  '경상남도 양산시',
#  '경상남도 의령군',
#  '경상남도 진주시',
#  '경상남도 창녕군',
#  '경상남도 창원시',
#  '경상남도 통영시',
#  '경상남도 하동군',
#  '경상남도 함안군',
#  '경상남도 함양군',
#  '경상남도 합천군',
#  '경상북도 경산시',
#  '경상북도 경주시',
# ...

# %%
l1 = []
for i in state_list1:
    if i not in correction_list:
        l1.append(i)
print(l1)
# Out:
# []

# %%
df1
# Out:
#     state city   visit_cnt  cctv_cnt  sclight_cnt  smalight_cnt  strlamp_cnt  \
# 0     강원도  강릉시  26334028.0    1699.0      12301.0          64.0      99994.0
# 1     강원도  고성군  11612683.0     422.0      99992.0          94.0      99994.0
# 2     강원도  동해시   6798468.0     330.0       4555.0         184.0      99994.0
# 3     강원도  삼척시   8614642.0     932.0       7813.0          46.0      99994.0
# 4     강원도  속초시  19495563.0     441.0       3118.0       99993.0      99994.0
# ..    ...  ...         ...       ...          ...           ...          ...
# 270  충청남도  운산면         NaN   99991.0          1.0       99993.0      99994.0
# 271  충청남도  보은군         NaN   99991.0      99992.0           1.0      99994.0
# 272  충청남도  연기군         NaN   99991.0      99992.0           1.0      99994.0
# 273  충청남도  완주군         NaN   99991.0      99992.0           1.0      99994.0
# 274  충청북도  청원군         NaN   99991.0      99992.0           1.0      99994.0
#
#      crime_rate  avg_pop_density new_state
# ...

# %% [markdown]
# ### 세종시 00면 데이터를 세종특별자치시 데이터 하나로 통일하기

# %%
#22. 03.06
import pandas as pd
df = pd.read_csv('./df_security_concat_5.csv', encoding='cp949').iloc[:,2:]

# %%
df1 = df.copy()

# %%
df2 = df1.loc[df.state == '세종특별자치시']

# %%
df2.cctv_cnt[df2.cctv_cnt > 99990] = 0
df2.sclight_cnt[df2.sclight_cnt > 99990] = 0
df2.smalight_cnt[df2.smalight_cnt > 99990] = 0
df2.strlamp_cnt[df2.strlamp_cnt > 99990] = 0
df2.new_state = '세종특별자치시 세종특별자치시'
# Out:
# C:\Users\kh983\AppData\Local\Temp\ipykernel_14424\903927141.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.cctv_cnt[df2.cctv_cnt > 99990] = 0
# C:\Users\kh983\AppData\Local\Temp\ipykernel_14424\903927141.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.sclight_cnt[df2.sclight_cnt > 99990] = 0
# C:\Users\kh983\AppData\Local\Temp\ipykernel_14424\903927141.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
a = {
    'visit_cnt' : 'sum',
    'cctv_cnt' : 'sum',
    'sclight_cnt' : 'sum',
    'smalight_cnt' : 'sum',
    'strlamp_cnt' : 'sum',
    'crime_rate' : 'mean',
    'avg_pop_density' : 'mean',
    
}


state_groupby = df2.groupby(['state'], as_index=False).agg(a)
state_groupby['city'] ='세종특별자치시'

# %%
sejong_row = state_groupby[['state','city','visit_cnt','cctv_cnt','sclight_cnt','smalight_cnt','strlamp_cnt','crime_rate','avg_pop_density']]

# %%
sejong_row
# Out:
#      state     city   visit_cnt  cctv_cnt  sclight_cnt  smalight_cnt  \
# 0  세종특별자치시  세종특별자치시  18211355.0    1218.0       8029.0          23.0
#
#    strlamp_cnt  crime_rate  avg_pop_density
# 0      15458.0      0.0041           708.64

# %%
new_df = df1.append(sejong_row, ignore_index = True)
# Out:
# C:\Users\kh983\AppData\Local\Temp\ipykernel_14424\3896072846.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = df1.append(sejong_row, ignore_index = True)

# %%
idx = df2.index

# %%
len(idx)
# Out:
# 25

# %%
df1.drop(idx, axis=0, inplace=True)

# %%
new_df = df1.append(sejong_row, ignore_index = True)
# Out:
# C:\Users\kh983\AppData\Local\Temp\ipykernel_14424\3896072846.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = df1.append(sejong_row, ignore_index = True)

# %%
df
# Out:
#        state  city   visit_cnt  cctv_cnt  sclight_cnt  smalight_cnt  \
# 0        강원도   강릉시  26334028.0    1699.0      12301.0          64.0
# 1        강원도   고성군  11612683.0     422.0      99992.0          94.0
# 2        강원도   동해시   6798468.0     330.0       4555.0         184.0
# 3        강원도   삼척시   8614642.0     932.0       7813.0          46.0
# 4        강원도   속초시  19495563.0     441.0       3118.0       99993.0
# ..       ...   ...         ...       ...          ...           ...
# 248  세종특별자치시   전동면         NaN      27.0        821.0           1.0
# 249  세종특별자치시   전의면         NaN      46.0        909.0           2.0
# 250  세종특별자치시  조치원읍         NaN     203.0       1200.0           5.0
# 251  세종특별자치시   종촌동         NaN      19.0      99992.0       99993.0
# 252  세종특별자치시   한솔동         NaN      40.0      99992.0       99993.0
#
#      strlamp_cnt  crime_rate  avg_pop_density     new_state
# 0        99994.0      0.0271            90.36       강원도 강릉시
# ...

# %%
new_df
# Out:
#        state     city   visit_cnt  cctv_cnt  sclight_cnt  smalight_cnt  \
# 0        강원도      강릉시  26334028.0    1699.0      12301.0          64.0
# 1        강원도      고성군  11612683.0     422.0      99992.0          94.0
# 2        강원도      동해시   6798468.0     330.0       4555.0         184.0
# 3        강원도      삼척시   8614642.0     932.0       7813.0          46.0
# 4        강원도      속초시  19495563.0     441.0       3118.0       99993.0
# ..       ...      ...         ...       ...          ...           ...
# 224     충청북도      증평군   2848031.0     910.0       3869.0           8.0
# 225     충청북도      진천군   8030068.0     692.0          2.0       99993.0
# 226     충청북도      청주시  62425138.0       9.0      25432.0       99993.0
# 227     충청북도      충주시  14797862.0    1578.0      10600.0         219.0
# 228  세종특별자치시  세종특별자치시  18211355.0    1218.0       8029.0          23.0
#
#      strlamp_cnt  crime_rate  avg_pop_density        new_state
# ...

# %%
df1
# Out:
#     state city   visit_cnt  cctv_cnt  sclight_cnt  smalight_cnt  strlamp_cnt  \
# 0     강원도  강릉시  26334028.0    1699.0      12301.0          64.0      99994.0
# 1     강원도  고성군  11612683.0     422.0      99992.0          94.0      99994.0
# 2     강원도  동해시   6798468.0     330.0       4555.0         184.0      99994.0
# 3     강원도  삼척시   8614642.0     932.0       7813.0          46.0      99994.0
# 4     강원도  속초시  19495563.0     441.0       3118.0       99993.0      99994.0
# ..    ...  ...         ...       ...          ...           ...          ...
# 224  충청북도  제천시  12125010.0     979.0       9024.0         314.0      99994.0
# 225  충청북도  증평군   2848031.0     910.0       3869.0           8.0      99994.0
# 226  충청북도  진천군   8030068.0     692.0          2.0       99993.0        121.0
# 227  충청북도  청주시  62425138.0       9.0      25432.0       99993.0      99994.0
# 228  충청북도  충주시  14797862.0    1578.0      10600.0         219.0      99994.0
#
#      crime_rate  avg_pop_density new_state
# ...

# %%
new_df.iloc[228,9] = '세종특별자치시 세종특별자치시'

# %%
correction_list = ['강릉시','고성군','동해시','삼척시','속초시','양구군','양양군','영월군','원주시','인제군','정선군','철원군','춘천시','태백시','평창군','홍천군','화천군','횡성군','가평군','고양시','과천시','광명시','광주시','구리시','군포시','김포시','남양주시','동두천시','부천시','성남시','수원시','시흥시','안산시','안성시','안양시','양주시','양평군','여주시','연천군','오산시','용인시','의왕시','의정부시','이천시','파주시','평택시','포천시','하남시','화성시','거제시','거창군','고성군','김해시','남해군','밀양시','사천시','산청군','양산시','의령군','진주시','창녕군','창원시','통영시','하동군','함안군','함양군','합천군','경산시','경주시','고령군','구미시','군위군','김천시','문경시','봉화군','상주시','성주군','안동시','영덕군','영양군','영주시','영천시','예천군','울릉군','울진군','의성군','청도군','청송군','칠곡군','포항시','광산구','남구','동구','북구','서구','남구','달서구','달성군','동구','북구','서구','수성구','중구','대덕구','동구','서구','유성구','중구','강서구','금정구','기장군','남구','동구','동래구','부산진구','북구','사상구','사하구','서구','수영구','연제구','영도구','중구','해운대구','강남구','강동구','강북구','강서구','관악구','광진구','구로구','금천구','노원구','도봉구','동대문구','동작구','마포구','서대문구','서초구','성동구','성북구','송파구','양천구','영등포구','용산구','은평구','종로구','중구','중랑구','세종특별자치시','남구','동구','북구','울주군','중구','강화군','계양구','남동구','동구','미추홀구','부평구','서구','연수구','옹진군','중구','강진군','고흥군','곡성군','광양시','구례군','나주시','담양군','목포시','무안군','보성군','순천시','신안군','여수시','영광군','영암군','완도군','장성군','장흥군','진도군','함평군','해남군','화순군','고창군','군산시','김제시','남원시','무주군','부안군','순창군','완주군','익산시','임실군','장수군','전주시','정읍시','진안군','서귀포시','제주시','계룡시','공주시','금산군','논산시','당진시','보령시','부여군','서산시','서천군','아산시','예산군','천안시','청양군','태안군','홍성군','괴산군','단양군','보은군','영동군','옥천군','음성군','제천시','증평군','진천군','청주시','충주시']

# %%
state_list1 = new_df.city.tolist()

# %%
# 올바르지 않은 new_state값 추출
l1 = []
for i in state_list1:
    if i not in correction_list:
        l1.append(i)
print(l1)
# Out:
# []

# %%
df3 = pd.read_csv('./체류특성_전처리_효경2.csv', encoding='cp949')[]

# %%
df3
# Out:
#     state city  mean_hours  mean_days
# 0     강원도  강릉시      324.40      1.620
# 1     강원도  고성군      375.20      1.560
# 2     강원도  동해시      287.00      1.700
# 3     강원도  삼척시      318.60      1.680
# 4     강원도  속초시      280.20      1.400
# ..    ...  ...         ...        ...
# 224  충청북도  제천시      324.80      1.600
# 225  충청북도  증평군      233.00      1.680
# 226  충청북도  진천군      258.00      1.700
# 227  충청북도  청주시      208.15      1.765
# 228  충청북도  충주시      296.80      1.640
#
# [229 rows x 4 columns]

# %%
pd.concat?

# %%
new_df = new_df.sort_values(by=['state', 'city'])

# %%
pd.concat([new_df, df3], axis=1,)
# Out:
#     state city   visit_cnt  cctv_cnt  sclight_cnt  smalight_cnt  strlamp_cnt  \
# 0     강원도  강릉시  26334028.0    1699.0      12301.0          64.0      99994.0
# 1     강원도  고성군  11612683.0     422.0      99992.0          94.0      99994.0
# 2     강원도  동해시   6798468.0     330.0       4555.0         184.0      99994.0
# 3     강원도  삼척시   8614642.0     932.0       7813.0          46.0      99994.0
# 4     강원도  속초시  19495563.0     441.0       3118.0       99993.0      99994.0
# ..    ...  ...         ...       ...          ...           ...          ...
# 223  충청북도  제천시  12125010.0     979.0       9024.0         314.0      99994.0
# 224  충청북도  증평군   2848031.0     910.0       3869.0           8.0      99994.0
# 225  충청북도  진천군   8030068.0     692.0          2.0       99993.0        121.0
# 226  충청북도  청주시  62425138.0       9.0      25432.0       99993.0      99994.0
# 227  충청북도  충주시  14797862.0    1578.0      10600.0         219.0      99994.0
#
# ...

# %%
df_security_concat = pd.read_csv('./df_security_concat_6.csv', encoding='cp949')

# %%
df_security_concat[~(df_security_concat.new_state.str.split().str[1] == df_security_concat.city)]
# Out:
# Empty DataFrame
# Columns: [state, city, visit_cnt, cctv_cnt, sclight_cnt, smalight_cnt, strlamp_cnt, crime_rate, avg_pop_density, new_state, mean_hours, mean_days]
# Index: []

# %%
df_security_concat.drop('new_state', axis=1, inplace=True)

# %%
df_security_concat1 = df_security_concat[['state','city','visit_cnt','cctv_cnt','sclight_cnt','smalight_cnt','crime_rate','avg_pop_density','mean_hours','mean_days','new_state']]
df_security_concat1
# Out:
#     state city   visit_cnt  cctv_cnt  sclight_cnt  smalight_cnt  crime_rate  \
# 0     강원도  강릉시  26334028.0    1699.0      12301.0          64.0      0.0271
# 1     강원도  고성군  11612683.0     422.0          NaN          94.0      0.0271
# 2     강원도  동해시   6798468.0     330.0       4555.0         184.0      0.0271
# 3     강원도  삼척시   8614642.0     932.0       7813.0          46.0      0.0271
# 4     강원도  속초시  19495563.0     441.0       3118.0           NaN      0.0271
# ..    ...  ...         ...       ...          ...           ...         ...
# 224  충청북도  제천시  12125010.0     979.0       9024.0         314.0      0.0299
# 225  충청북도  증평군   2848031.0     910.0       3869.0           8.0      0.0299
# 226  충청북도  진천군   8030068.0     692.0          2.0           NaN      0.0299
# 227  충청북도  청주시  62425138.0       9.0      25432.0           NaN      0.0299
# 228  충청북도  충주시  14797862.0    1578.0      10600.0         219.0      0.0299
#
#      avg_pop_density  mean_hours  mean_days new_state
# ...

# %%
df_security_concat1.to_csv('./df_security_concat_7.csv', encoding='cp949')

# %%
df_security_concat1
# Out:
#     state city   visit_cnt  cctv_cnt  sclight_cnt  smalight_cnt  crime_rate  \
# 0     강원도  강릉시  26334028.0    1699.0      12301.0          64.0      0.0271
# 1     강원도  고성군  11612683.0     422.0          NaN          94.0      0.0271
# 2     강원도  동해시   6798468.0     330.0       4555.0         184.0      0.0271
# 3     강원도  삼척시   8614642.0     932.0       7813.0          46.0      0.0271
# 4     강원도  속초시  19495563.0     441.0       3118.0           NaN      0.0271
# ..    ...  ...         ...       ...          ...           ...         ...
# 224  충청북도  제천시  12125010.0     979.0       9024.0         314.0      0.0299
# 225  충청북도  증평군   2848031.0     910.0       3869.0           8.0      0.0299
# 226  충청북도  진천군   8030068.0     692.0          2.0           NaN      0.0299
# 227  충청북도  청주시  62425138.0       9.0      25432.0           NaN      0.0299
# 228  충청북도  충주시  14797862.0    1578.0      10600.0         219.0      0.0299
#
#      avg_pop_density  mean_hours  mean_days new_state
# ...

# %%
df3 # 21개 행 없어짐

# %% [markdown]
# ### 시도별 top5 데이터 선별하기

# %%
import pandas as pdcon
import numpy as np

# %%
df7 = pd.read_csv('./df_security_concat_7.csv', encoding='cp949')

# %%
df7
# Out:
#      Unnamed: 0 state city   visit_cnt  cctv_cnt  sclight_cnt  smalight_cnt  \
# 0             0   강원도  강릉시  26334028.0    1699.0      12301.0          64.0
# 1             1   강원도  고성군  11612683.0     422.0          NaN          94.0
# 2             2   강원도  동해시   6798468.0     330.0       4555.0         184.0
# 3             3   강원도  삼척시   8614642.0     932.0       7813.0          46.0
# 4             4   강원도  속초시  19495563.0     441.0       3118.0           NaN
# ..          ...   ...  ...         ...       ...          ...           ...
# 224         224  충청북도  제천시  12125010.0     979.0       9024.0         314.0
# 225         225  충청북도  증평군   2848031.0     910.0       3869.0           8.0
# 226         226  충청북도  진천군   8030068.0     692.0          2.0           NaN
# 227         227  충청북도  청주시  62425138.0       9.0      25432.0           NaN
# 228         228  충청북도  충주시  14797862.0    1578.0      10600.0         219.0
#
# ...

# %%
df7_state_unique = df7.state.unique().tolist()

# %%
df7_state_unique
# Out:
# ['강원도',
#  '경기도',
#  '경상남도',
#  '경상북도',
#  '광주광역시',
#  '대구광역시',
#  '대전광역시',
#  '부산광역시',
#  '서울특별시',
#  '세종특별자치시',
#  '울산광역시',
#  '인천광역시',
#  '전라남도',
#  '전라북도',
#  '제주특별자치도',
#  '충청남도',
#  '충청북도']

# %%
def top5(state_name):
    df_top5= df7[df7.state==state_name].sort_values(by='mean_hours' ,ascending=False).head(5)
    return df_top5

# %%
top5_list = []
for state_name in df7_state_unique:
    top5_list.append(top5(state_name).new_state.tolist())

# %%
top5_list
# Out:
# [['강원도 정선군', '강원도 평창군', '강원도 홍천군', '강원도 양구군', '강원도 고성군'],
#  ['경기도 가평군', '경기도 연천군', '경기도 평택시', '경기도 포천시', '경기도 화성시'],
#  ['경상남도 거제시', '경상남도 남해군', '경상남도 함양군', '경상남도 산청군', '경상남도 통영시'],
#  ['경상북도 울릉군', '경상북도 영양군', '경상북도 울진군', '경상북도 영주시', '경상북도 봉화군'],
#  ['광주광역시 남구', '광주광역시 광산구', '광주광역시 북구', '광주광역시 서구', '광주광역시 동구'],
#  ['대구광역시 달서구', '대구광역시 북구', '대구광역시 달성군', '대구광역시 수성구', '대구광역시 동구'],
#  ['대전광역시 유성구', '대전광역시 서구', '대전광역시 대덕구', '대전광역시 동구', '대전광역시 중구'],
#  ['부산광역시 사하구', '부산광역시 북구', '부산광역시 해운대구', '부산광역시 남구', '부산광역시 금정구'],
#  ['서울특별시 관악구', '서울특별시 은평구', '서울특별시 금천구', '서울특별시 강북구', '서울특별시 성북구'],
#  ['세종특별자치시 세종특별자치시'],
#  ['울산광역시 동구', '울산광역시 울주군', '울산광역시 북구', '울산광역시 남구', '울산광역시 중구'],
#  ['인천광역시 옹진군', '인천광역시 강화군', '인천광역시 서구', '인천광역시 연수구', '인천광역시 남동구'],
#  ['전라남도 고흥군', '전라남도 완도군', '전라남도 신안군', '전라남도 여수시', '전라남도 진도군'],
#  ['전라북도 부안군', '전라북도 장수군', '전라북도 군산시', '전라북도 익산시', '전라북도 남원시'],
#  ['제주특별자치도 제주시', '제주특별자치도 서귀포시'],
#  ['충청남도 태안군', '충청남도 보령시', '충청남도 청양군', '충청남도 서산시', '충청남도 아산시'],
# ...

# %% [markdown]
# ### top5 데이터만 모아서 결합하기

# %%
# 뻘짓
l2=[]
for j in range(17):
    state_name = top5_list[j][0].split()[0]
    l1 = []
    for column in df.iloc[:,3:7].columns:
        l1.append(df7.loc[df7.state == state_name,column].median())
    l2.append(l1)
        
l2
# Out:
# [[8409174.0, 425.0, 4391.0, 46.0],
#  [22165414.0, 1813.5, 9993.5, 321.0],
#  [7892017.5, 1074.0, 6994.0, 62.0],
#  [7170584.0, 843.0, 8229.0, 28.0],
#  [21537937.0, 81.0, 9913.0, 48.0],
#  [26030685.5, 1438.5, 9976.0, 48.0],
#  [20269458.0, 738.0, 12589.0, 66.5],
#  [16314034.5, 584.0, 4479.5, 25.0],
#  [29049617.0, 1411.0, 8646.0, 849.0],
#  [18211355.0, 1218.0, 8029.0, 23.0],
#  [13739394.0, 762.0, 5082.0, 484.0],
#  [24539676.5, 844.5, 5117.0, 292.5],
#  [5803056.5, 448.0, 7134.5, 38.5],
#  [6994697.5, 454.0, 7761.5, 50.0],
#  [45535143.0, 580.0, 16771.0, 71.0],
#  [9658307.0, 976.5, 9794.0, 62.0],
#  [6815705.0, 640.0, 6349.0, 112.0]]

# %%
len(l2)
# Out:
# 17

# %%
df = df7[df7.new_state.isin(top5_list[1])]

# %%
data_df = df7.iloc[]
# Out:
#      Unnamed: 0 state city   visit_cnt  cctv_cnt  sclight_cnt  smalight_cnt  \
# 0             0   강원도  강릉시  26334028.0    1699.0      12301.0          64.0
# 1             1   강원도  고성군  11612683.0     422.0          NaN          94.0
# 2             2   강원도  동해시   6798468.0     330.0       4555.0         184.0
# 3             3   강원도  삼척시   8614642.0     932.0       7813.0          46.0
# 4             4   강원도  속초시  19495563.0     441.0       3118.0           NaN
# ..          ...   ...  ...         ...       ...          ...           ...
# 224         224  충청북도  제천시  12125010.0     979.0       9024.0         314.0
# 225         225  충청북도  증평군   2848031.0     910.0       3869.0           8.0
# 226         226  충청북도  진천군   8030068.0     692.0          2.0           NaN
# 227         227  충청북도  청주시  62425138.0       9.0      25432.0           NaN
# 228         228  충청북도  충주시  14797862.0    1578.0      10600.0         219.0
#
# ...

# %%
len(top5_list)
# Out:
# 17

# %%
data_df = pd.read_csv('./df_security_concat_중앙값대체완료.csv',encoding='cp949')

# %%
data_df = data_df.iloc[:,2:]

# %%
data_df

# %% [markdown]
# ### 데이터 개수 확인

# %%
top5_list
a = 0
for i in range(17):
    a += len(top5_list[i])

# %%
a
# Out:
# 78

# %%
df1 = data_df[data_df.new_state.isin(top5_list[0])].sort_values(by='mean_hours' ,ascending=False)
df2 = data_df[data_df.new_state.isin(top5_list[1])].sort_values(by='mean_hours' ,ascending=False)
df3 = data_df[data_df.new_state.isin(top5_list[2])].sort_values(by='mean_hours' ,ascending=False)
df4 = data_df[data_df.new_state.isin(top5_list[3])].sort_values(by='mean_hours' ,ascending=False)
df5 = data_df[data_df.new_state.isin(top5_list[4])].sort_values(by='mean_hours' ,ascending=False)
df6 = data_df[data_df.new_state.isin(top5_list[5])].sort_values(by='mean_hours' ,ascending=False)
df7 = data_df[data_df.new_state.isin(top5_list[6])].sort_values(by='mean_hours' ,ascending=False)
df8 = data_df[data_df.new_state.isin(top5_list[7])].sort_values(by='mean_hours' ,ascending=False)
df9 = data_df[data_df.new_state.isin(top5_list[8])].sort_values(by='mean_hours' ,ascending=False)
df10 = data_df[data_df.new_state.isin(top5_list[9])].sort_values(by='mean_hours' ,ascending=False)
df11 = data_df[data_df.new_state.isin(top5_list[10])].sort_values(by='mean_hours' ,ascending=False)
df12 = data_df[data_df.new_state.isin(top5_list[11])].sort_values(by='mean_hours' ,ascending=False)
df13 = data_df[data_df.new_state.isin(top5_list[12])].sort_values(by='mean_hours' ,ascending=False)
df14 = data_df[data_df.new_state.isin(top5_list[13])].sort_values(by='mean_hours' ,ascending=False)
df15 = data_df[data_df.new_state.isin(top5_list[14])].sort_values(by='mean_hours' ,ascending=False)
df16 = data_df[data_df.new_state.isin(top5_list[15])].sort_values(by='mean_hours' ,ascending=False)
df17 = data_df[data_df.new_state.isin(top5_list[16])].sort_values(by='mean_hours' ,ascending=False)

l1 = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17]

# %%
df9 = pd.concat(l1, ignore_index=True)

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df9
# Out:
#       state     city  visit_cnt  cctv_cnt  sclight_cnt  smalight_cnt  \
# 0       강원도      정선군    8151609     515.0       4391.0          13.0
# 1       강원도      평창군   13399820     190.0       6747.0          46.0
# 2       강원도      홍천군   15125927     428.0       1191.0          37.0
# 3       강원도      양구군    1828609     296.0        190.0          22.0
# 4       강원도      고성군   11612683     422.0       4391.0          94.0
# 5       경기도      가평군   22165414     425.0       9119.0         206.0
# 6       경기도      연천군    5752900     530.0       4675.0         147.0
# 7       경기도      평택시   24993680    2321.0      10561.0        1740.0
# 8       경기도      포천시   21473221    1400.0      10000.0          34.0
# 9       경기도      화성시   52221879   11327.0      17499.0          46.0
# 10     경상남도      거제시   17161520     695.0       8562.0          75.0
# 11     경상남도      남해군    8308463     840.0       6154.0          56.0
# 12     경상남도      함양군    4254845     584.0       5037.0          49.0
# ...

# %%
df9.to_csv?

# %%
df9.to_csv('./df_security_concat_9.csv', encoding='cp949', index=False)

# %%
df3.to_csv('./df_security_concat-4.csv',encoding='cp949')

# %%
# end_of_file
