# %% [markdown]
# <h1>목차<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#보안등" data-toc-modified-id="보안등-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>보안등</a></span></li><li><span><a href="#개별-데이터-전처리-(서울-~-충청북도)" data-toc-modified-id="개별-데이터-전처리-(서울-~-충청북도)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>개별 데이터 전처리 (서울 ~ 충청북도)</a></span><ul class="toc-item"><li><span><a href="#서울" data-toc-modified-id="서울-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>서울</a></span></li><li><span><a href="#세종" data-toc-modified-id="세종-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>세종</a></span></li><li><span><a href="#울산" data-toc-modified-id="울산-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>울산</a></span></li><li><span><a href="#인천" data-toc-modified-id="인천-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>인천</a></span></li><li><span><a href="#전라남도" data-toc-modified-id="전라남도-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>전라남도</a></span></li><li><span><a href="#전라북도" data-toc-modified-id="전라북도-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>전라북도</a></span></li><li><span><a href="#제주도" data-toc-modified-id="제주도-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>제주도</a></span></li><li><span><a href="#충청남도" data-toc-modified-id="충청남도-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>충청남도</a></span></li><li><span><a href="#충청북도" data-toc-modified-id="충청북도-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>충청북도</a></span></li></ul></li><li><span><a href="#데이터-합치기-(서울-~-충청북도)" data-toc-modified-id="데이터-합치기-(서울-~-충청북도)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>데이터 합치기 (서울 ~ 충청북도)</a></span></li><li><span><a href="#전체-데이터-오류-확인" data-toc-modified-id="전체-데이터-오류-확인-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>전체 데이터 오류 확인</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#state-명-확인-및-지역-고윳값으로만-통일" data-toc-modified-id="state-명-확인-및-지역-고윳값으로만-통일-4.0.1"><span class="toc-item-num">4.0.1&nbsp;&nbsp;</span>state 명 확인 및 지역 고윳값으로만 통일</a></span></li><li><span><a href="#위도-경도-관련-drop할-행-확인" data-toc-modified-id="위도-경도-관련-drop할-행-확인-4.0.2"><span class="toc-item-num">4.0.2&nbsp;&nbsp;</span>위도 경도 관련 drop할 행 확인</a></span></li><li><span><a href="#'city,-state,-lat,-long'-경우의-수-제거" data-toc-modified-id="'city,-state,-lat,-long'-경우의-수-제거-4.0.3"><span class="toc-item-num">4.0.3&nbsp;&nbsp;</span>'city, state, lat, long' 경우의 수 제거</a></span></li></ul></li></ul></li><li><span><a href="#시도별-Group_by" data-toc-modified-id="시도별-Group_by-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>시도별 Group_by</a></span></li><li><span><a href="#EDA:-시도별-보안등-개수" data-toc-modified-id="EDA:-시도별-보안등-개수-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>EDA: 시도별 보안등 개수</a></span><ul class="toc-item"><li><span><a href="#Bar-Graph" data-toc-modified-id="Bar-Graph-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Bar Graph</a></span></li></ul></li><li><span><a href="#(추가)-EDA:-인구밀도-대비-보안등-개수" data-toc-modified-id="(추가)-EDA:-인구밀도-대비-보안등-개수-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>(추가) EDA: 인구밀도 대비 보안등 개수</a></span><ul class="toc-item"><li><span><a href="#Folium-지도-시각화" data-toc-modified-id="Folium-지도-시각화-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Folium 지도 시각화</a></span></li></ul></li><li><span><a href="#지도-띄우기" data-toc-modified-id="지도-띄우기-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>지도 띄우기</a></span></li><li><span><a href="#'state'가-잘못-들어간-아이들-추출-및-drop-진행" data-toc-modified-id="'state'가-잘못-들어간-아이들-추출-및-drop-진행-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>'state'가 잘못 들어간 아이들 추출 및 drop 진행</a></span></li><li><span><a href="#강원도-~-부산광역시-파일-한번에-읽고-합치기" data-toc-modified-id="강원도-~-부산광역시-파일-한번에-읽고-합치기-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>강원도 ~ 부산광역시 파일 한번에 읽고 합치기</a></span></li><li><span><a href="#필요없는-컬럼-drop-['보안등위치명',-'설치연도',-'설치형태',-'관리기관전화번호',-'관리기관명']" data-toc-modified-id="필요없는-컬럼-drop-['보안등위치명',-'설치연도',-'설치형태',-'관리기관전화번호',-'관리기관명']-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>필요없는 컬럼 drop ['보안등위치명', '설치연도', '설치형태', '관리기관전화번호', '관리기관명']</a></span></li><li><span><a href="#지번주소가-없을땐-도로명주소를-참고하여-합친-새로운-'주소'-컬럼-생성" data-toc-modified-id="지번주소가-없을땐-도로명주소를-참고하여-합친-새로운-'주소'-컬럼-생성-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>지번주소가 없을땐 도로명주소를 참고하여 합친 새로운 '주소' 컬럼 생성</a></span></li><li><span><a href="#df_sclight1-컬럼명-영문-변환" data-toc-modified-id="df_sclight1-컬럼명-영문-변환-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>df_sclight1 컬럼명 영문 변환</a></span></li><li><span><a href="#city,-lat,-long-하나만-있는-경우-혹은-둘다-없는-경우-모두-drop" data-toc-modified-id="city,-lat,-long-하나만-있는-경우-혹은-둘다-없는-경우-모두-drop-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>city, lat, long 하나만 있는 경우 혹은 둘다 없는 경우 모두 drop</a></span></li><li><span><a href="#NGD를-통한-전처리" data-toc-modified-id="NGD를-통한-전처리-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>NGD를 통한 전처리</a></span></li><li><span><a href="#인구-밀도-데이터-확인-및-state별-평균인구밀도-집계" data-toc-modified-id="인구-밀도-데이터-확인-및-state별-평균인구밀도-집계-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>인구 밀도 데이터 확인 및 state별 평균인구밀도 집계</a></span></li><li><span><a href="#df_sclight1과-평균인구밀도-데이터-합치기" data-toc-modified-id="df_sclight1과-평균인구밀도-데이터-합치기-17"><span class="toc-item-num">17&nbsp;&nbsp;</span>df_sclight1과 평균인구밀도 데이터 합치기</a></span></li><li><span><a href="#위도-&amp;-경도만-있는-주소는-전체-데이터의-10%-미만이므로-drop-진행" data-toc-modified-id="위도-&amp;-경도만-있는-주소는-전체-데이터의-10%-미만이므로-drop-진행-18"><span class="toc-item-num">18&nbsp;&nbsp;</span>위도 &amp; 경도만 있는 주소는 전체 데이터의 10% 미만이므로 drop 진행</a></span><ul class="toc-item"><li><span><a href="#----df_sclight1-전처리-완료----" data-toc-modified-id="----df_sclight1-전처리-완료-----18.1"><span class="toc-item-num">18.1&nbsp;&nbsp;</span>--- df_sclight1 전처리 완료 ---</a></span></li></ul></li><li><span><a href="#df_sclight1과-df_sclight2-합치기---1.-파일-읽고-불필요-컬럼-drop" data-toc-modified-id="df_sclight1과-df_sclight2-합치기---1.-파일-읽고-불필요-컬럼-drop-19"><span class="toc-item-num">19&nbsp;&nbsp;</span>df_sclight1과 df_sclight2 합치기 - 1. 파일 읽고 불필요 컬럼 drop</a></span></li><li><span><a href="#df_sclight2-'city'-잘못-들어간-데이터-수정-및-평균인구밀도-데이터와-합치기" data-toc-modified-id="df_sclight2-'city'-잘못-들어간-데이터-수정-및-평균인구밀도-데이터와-합치기-20"><span class="toc-item-num">20&nbsp;&nbsp;</span>df_sclight2 'city' 잘못 들어간 데이터 수정 및 평균인구밀도 데이터와 합치기</a></span></li><li><span><a href="#위도-&amp;-경도만-있는-주소는-전체-데이터의-약-12%정도이므로-drop-진행" data-toc-modified-id="위도-&amp;-경도만-있는-주소는-전체-데이터의-약-12%정도이므로-drop-진행-21"><span class="toc-item-num">21&nbsp;&nbsp;</span>위도 &amp; 경도만 있는 주소는 전체 데이터의 약 12%정도이므로 drop 진행</a></span></li><li><span><a href="#df_sclight1과-df_sclight2-concat하여-최종본-df_sclight-생성" data-toc-modified-id="df_sclight1과-df_sclight2-concat하여-최종본-df_sclight-생성-22"><span class="toc-item-num">22&nbsp;&nbsp;</span>df_sclight1과 df_sclight2 concat하여 최종본 df_sclight 생성</a></span><ul class="toc-item"><li><span><a href="#install_cnt-type-정수형으로-통일" data-toc-modified-id="install_cnt-type-정수형으로-통일-22.1"><span class="toc-item-num">22.1&nbsp;&nbsp;</span>install_cnt type 정수형으로 통일</a></span></li><li><span><a href="#중복값-확인하려-했으나-실제로-같은-주소에-보안등이-2개-이상-있는-경우가-있어-따로-제거하지-않기로-결정" data-toc-modified-id="중복값-확인하려-했으나-실제로-같은-주소에-보안등이-2개-이상-있는-경우가-있어-따로-제거하지-않기로-결정-22.2"><span class="toc-item-num">22.2&nbsp;&nbsp;</span>중복값 확인하려 했으나 실제로 같은 주소에 보안등이 2개 이상 있는 경우가 있어 따로 제거하지 않기로 결정</a></span></li></ul></li><li><span><a href="#최종본(df_sclight).csv로-저장,-해당-파일-read시-encoding='cp949'-지정-필수" data-toc-modified-id="최종본(df_sclight).csv로-저장,-해당-파일-read시-encoding='cp949'-지정-필수-23"><span class="toc-item-num">23&nbsp;&nbsp;</span>최종본(df_sclight).csv로 저장, 해당 파일 read시 encoding='cp949' 지정 필수</a></span><ul class="toc-item"><li><span><a href="#df_sclight와-저장된-df_sclight와-차이가-있는지-확인-=>-결과:-차이-없음" data-toc-modified-id="df_sclight와-저장된-df_sclight와-차이가-있는지-확인-=>-결과:-차이-없음-23.1"><span class="toc-item-num">23.1&nbsp;&nbsp;</span>df_sclight와 저장된 df_sclight와 차이가 있는지 확인 =&gt; 결과: 차이 없음</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## 보안등

# %%
# 라이브러리 호출
import pandas as pd
import numpy as np

# %% [markdown]
# ## 개별 데이터 전처리 (서울 ~ 충청북도)

# %% [markdown]
# ### 서울

# %%
# 파일 리스트 확인 (주의: 파일명 반복문으로 돌릴 수 있게 규칙성 있는 파일명으로 통일)
import os
os.listdir('C:/Users/samsung/TIL/DS/project/miniPJ/01_pj/data/rawdata/rawdata_보안등/rawdata/서울')
# Out:
# ['서울특별시_강남구.csv',
#  '서울특별시_강동구.csv',
#  '서울특별시_강북구.csv',
#  '서울특별시_강서구.csv',
#  '서울특별시_관악구.csv',
#  '서울특별시_광진구.csv',
#  '서울특별시_구로구.csv',
#  '서울특별시_금천구.csv',
#  '서울특별시_노원구.csv',
#  '서울특별시_도봉구.csv',
#  '서울특별시_동작구.csv',
#  '서울특별시_마포구.csv',
#  '서울특별시_서대문구.csv',
#  '서울특별시_서초구.csv',
#  '서울특별시_성동구.csv',
#  '서울특별시_성북구.csv',
#  '서울특별시_송파구.csv',
#  '서울특별시_양천구.csv',
#  '서울특별시_영등포구.csv',
#  '서울특별시_용산구.csv',
#  '서울특별시_은평구.csv',
#  '서울특별시_종로구.csv',
#  '서울특별시_중구.csv',
#  '서울특별시_중랑구.csv']

# %%
# 파일 여러개 한 번에 불러오기
## 1. 파일 리스트 저장
seouls = os.listdir('C:/Users/samsung/TIL/DS/project/miniPJ/01_pj/data/rawdata/rawdata_보안등/rawdata/서울')

## 2. 현재 작업 위치로 이동
os.chdir('C:/Users/samsung/TIL/DS/project/miniPJ/01_pj/data/rawdata/rawdata_보안등/rawdata/서울')

## 3. 데이터 프레임 생성하고 모든 파일 합치기
# 새로운 데이터프레임 생성
df_all_seoul = pd.DataFrame()

for seoul in seouls:
    df = pd.read_csv(seoul, encoding='cp949')
    df_all_seoul = pd.concat([df_all_seoul, df])

df_all_seoul = df_all_seoul.reset_index(drop=True)
df_all_seoul
# Out:
#              보안등위치명  설치개수 소재지도로명주소                소재지지번주소         위도  \
# 0           개포1동001     1      NaN      서울특별시 강남구 개포동 570  37.476065
# 1           개포1동002     1      NaN    서울특별시 강남구 개포동 571-1  37.476065
# 2           개포1동003     1      NaN    서울특별시 강남구 개포동 572-1  37.477803
# 3           개포1동004     1      NaN    서울특별시 강남구 개포동 571-1  37.476065
# 4           개포1동005     1      NaN      서울특별시 강남구 개포동 570  37.476065
# ...             ...   ...      ...                    ...        ...
# 195679  중화2동 413-55     1      NaN  서울특별시 중랑구 중화2동 413-55        NaN
# 195680   중화2동 429-7     1      NaN   서울특별시 중랑구 중화2동 429-7        NaN
# 195681   중화2동 64-11     1      NaN   서울특별시 중랑구 중화2동 64-11        NaN
# 195682   중화2동 384-2     1      NaN   서울특별시 중랑구 중화2동 384-2        NaN
# 195683  중화2동 208-15     1      NaN  서울특별시 중랑구 중화2동 208-15        NaN
#
#                 경도    설치연도 설치형태      관리기관전화번호       관리기관명     데이터기준일자  설치년도
# ...

# %%
# 필요한 칼럼만 남기기
df_seoul = df_all_seoul[['설치개수','소재지도로명주소', '소재지지번주소', '위도', '경도', '데이터기준일자']]
df_seoul
# Out:
#         설치개수 소재지도로명주소                소재지지번주소         위도          경도  \
# 0          1      NaN      서울특별시 강남구 개포동 570  37.476065  127.067286
# 1          1      NaN    서울특별시 강남구 개포동 571-1  37.476065  127.067286
# 2          1      NaN    서울특별시 강남구 개포동 572-1  37.477803  127.065296
# 3          1      NaN    서울특별시 강남구 개포동 571-1  37.476065  127.067286
# 4          1      NaN      서울특별시 강남구 개포동 570  37.476065  127.067286
# ...      ...      ...                    ...        ...         ...
# 195679     1      NaN  서울특별시 중랑구 중화2동 413-55        NaN         NaN
# 195680     1      NaN   서울특별시 중랑구 중화2동 429-7        NaN         NaN
# 195681     1      NaN   서울특별시 중랑구 중화2동 64-11        NaN         NaN
# 195682     1      NaN   서울특별시 중랑구 중화2동 384-2        NaN         NaN
# 195683     1      NaN  서울특별시 중랑구 중화2동 208-15        NaN         NaN
#
#            데이터기준일자
# 0       2023-01-03
# 1       2023-01-03
# 2       2023-01-03
# 3       2023-01-03
# 4       2023-01-03
# ...            ...
# ...

# %%
# 결측값 확인
df_seoul.isnull().sum()
# Out:
# 설치개수            0
# 소재지도로명주소    74448
# 소재지지번주소      1425
# 위도          37245
# 경도          37282
# 데이터기준일자         0
# dtype: int64

# %%
# 도로명주소 + 지번주소 합치기 -> '주소'
df_seoul['주소'] = np.where(pd.notnull(df_seoul['소재지도로명주소']) == True, df_seoul['소재지도로명주소'], df_seoul['소재지지번주소'])
df_seoul['주소'].isna().sum()
# Out:
# C:\Users\samsung\AppData\Local\Temp\ipykernel_17912\1128158213.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_seoul['주소'] = np.where(pd.notnull(df_seoul['소재지도로명주소']) == True, df_seoul['소재지도로명주소'], df_seoul['소재지지번주소'])
# 0

# %%
# 도로명주소 + 지번주소 drop
## 도로명주소 + 지번주소 제외한 나머지 
df_seoul_2 = df_seoul[df_seoul.columns.difference(['소재지도로명주소', '소재지지번주소'])]
# 칼럼 순서 바꾸기
df_seoul_2 = df_seoul_2[['주소', '위도', '경도', '설치개수', '데이터기준일자']]
# 칼럼명 변경
df_seoul_2 = df_seoul_2.rename(columns={"주소": "address", 
                                        "위도": "lat", 
                                        "경도": "long",
                                       "설치개수": "install_cnt",
                                       "데이터기준일자": "date"})
df_seoul_2
# Out:
#                       address        lat        long  install_cnt        date
# 0           서울특별시 강남구 개포동 570  37.476065  127.067286            1  2023-01-03
# 1         서울특별시 강남구 개포동 571-1  37.476065  127.067286            1  2023-01-03
# 2         서울특별시 강남구 개포동 572-1  37.477803  127.065296            1  2023-01-03
# 3         서울특별시 강남구 개포동 571-1  37.476065  127.067286            1  2023-01-03
# 4           서울특별시 강남구 개포동 570  37.476065  127.067286            1  2023-01-03
# ...                       ...        ...         ...          ...         ...
# 195679  서울특별시 중랑구 중화2동 413-55        NaN         NaN            1  2023-02-15
# 195680   서울특별시 중랑구 중화2동 429-7        NaN         NaN            1  2023-02-15
# 195681   서울특별시 중랑구 중화2동 64-11        NaN         NaN            1  2023-02-15
# 195682   서울특별시 중랑구 중화2동 384-2        NaN         NaN            1  2023-02-15
# 195683  서울특별시 중랑구 중화2동 208-15        NaN         NaN            1  2023-02-15
#
# [195684 rows x 5 columns]

# %%
# 주소 분리 -> 시/도
## 공백 기준으로 분리
df_seoul_2['state'] = df_seoul_2['address'].str.split().str[0]
df_seoul_2['city'] = df_seoul_2['address'].str.split().str[1]
# 칼럼 순서 바꾸기
df_seoul_2 = df_seoul_2[['address', 'state', 'city', 'lat', 'long', 'install_cnt', 'date']]
df_seoul_2
# Out:
#                       address  state city        lat        long  install_cnt  \
# 0           서울특별시 강남구 개포동 570  서울특별시  강남구  37.476065  127.067286            1
# 1         서울특별시 강남구 개포동 571-1  서울특별시  강남구  37.476065  127.067286            1
# 2         서울특별시 강남구 개포동 572-1  서울특별시  강남구  37.477803  127.065296            1
# 3         서울특별시 강남구 개포동 571-1  서울특별시  강남구  37.476065  127.067286            1
# 4           서울특별시 강남구 개포동 570  서울특별시  강남구  37.476065  127.067286            1
# ...                       ...    ...  ...        ...         ...          ...
# 195679  서울특별시 중랑구 중화2동 413-55  서울특별시  중랑구        NaN         NaN            1
# 195680   서울특별시 중랑구 중화2동 429-7  서울특별시  중랑구        NaN         NaN            1
# 195681   서울특별시 중랑구 중화2동 64-11  서울특별시  중랑구        NaN         NaN            1
# 195682   서울특별시 중랑구 중화2동 384-2  서울특별시  중랑구        NaN         NaN            1
# 195683  서울특별시 중랑구 중화2동 208-15  서울특별시  중랑구        NaN         NaN            1
#
#               date
# ...

# %%
df_seoul_2.state.unique()
# Out:
# array(['서울특별시', '서울틀별시', '한양', ..., '연서로48길33-7', '진관로36삼천사입구',
#        '통일로961(신도교'], dtype=object)

# %%
df_seoul_2.loc[~df_seoul_2.state.str.contains('서울특별시'), 'state'].unique()
# Out:
# array(['서울틀별시', '한양', '산', ..., '연서로48길33-7', '진관로36삼천사입구', '통일로961(신도교'],
#       dtype=object)

# %%
df_seoul_unique = df_seoul_2.loc[~df_seoul_2.state.str.contains('서울특별시'), 'state'].unique()
for i in df_seoul_unique:
    print(i)
# Out:
# 서울틀별시
# 한양
# 산
# 안산초교위
# 환의사올라가는길
# 레미안
# 건축물
# 금호어울림옆길
# 쌍등
# 청련사입구
# 무
# 무궁화동산
# 환희사
# 환의사가는길
# 무악재청구아파트옆
# 수도사업소
# 홍제동힐스테이트108동
# 환희사길
# 없음
# 홍제교하부
# 홍제천길
# 홍제천변
# 홍은대교산책로
# 세무서길97
# 세무서길
# 세무서2길
# 간호대로35-24
# 세검정로
# 세검정로3길
# 간호대로35-34
# 세검정로3길52-3
# 세정검정로3길56
# 간호대로
# 세검정로46-7
# 세무서길84
# 간호대로35-10
# 간호대로3길
# 세검정로3길8
# 간호대로46-7
# 간호대로4길29
# 세무서
# 간호대로37
# 세무서길78
# 간호대로4길27
# 세무서길82-7
# 세무서길88-9
# 간호대로4길
# 세무서10길8
# 간호대로4길26
# 간호대로25-24
# 간호대로4길10
# 세검정로72-8
# 세무서길98-6
# 간호대로3길23
# 통일로36나길
# 세무서10길
# 세무서길106-7
# 간호대로4길26-10
# 간호대로4길20
# 세무서8길
# 세무서길106-35
# 간호대로4길16
# 문화촌아파트입구
# 간호대로1길
# 간호대로4길20-8
# 세무서길106-45
# 세무서10길51
# 세검정로64-1
# 간호대로11-23
# 간호대로4길16-5
# 간호대로11-24
# 문화촌길
# 세무서6길
# 간호대로20
# 문화촌길20
# 세검정로66-7
# 세검정로70-4
# 세무서10길24
# 세무서10길23-9
# 간호대로11-12
# 세무서10길23-5
# 간호대로4길16-9
# 포방터길6
# 세검정로66-13
# 세무서10길23-11
# 포방터길14
# 세검정로78-10
# 세무서8길39
# 포방터길18
# 세무서10길27-1
# 세검정로4길
# 간호대로12-6
# 세무서8길41
# 문화촌길6-22
# 포방터길20
# 포방터길
# 세무서2가길
# 간호대로2길17
# 세검정로4가길21-27
# 홍제내2길67
# 간호대로2길4
# ...

# %%
# 주소에 '서울'이 포함된 주소만 남기고, '서울인조별서유기비서울인조별서유기비' 행의 state와 city 값은 null 처리
df_seoul_2[~df_seoul_2.state.str.contains('서울특별시')]
# df_seoul_2[df_seoul_2.state.str.contains('서울')]
# Out:
#                       address       state  city        lat        long  \
# 67106   서울틀별시 금천구 독산로64길 70-7       서울틀별시   금천구  37.466687  126.906342
# 103825                한양 아파트앞          한양  아파트앞        NaN         NaN
# 103859                      산           산   NaN        NaN         NaN
# 103861                  안산초교위       안산초교위   NaN        NaN         NaN
# 103866               환의사올라가는길    환의사올라가는길   NaN        NaN         NaN
# ...                       ...         ...   ...        ...         ...
# 172099             연서로48길33-7  연서로48길33-7   NaN        NaN         NaN
# 172100             진관로36삼천사입구  진관로36삼천사입구   NaN        NaN         NaN
# 172101             진관로36삼천사입구  진관로36삼천사입구   NaN        NaN         NaN
# 172102         통일로961(신도교 뒤편)  통일로961(신도교   뒤편)  37.628792  126.918639
# 172103         통일로961(신도교 뒤편)  통일로961(신도교   뒤편)  37.628792  126.918639
#
#         install_cnt        date
# 67106             1  2022-02-26
# 103825            1  2020-01-01
# ...

# %%
# 바꿔야 할 데이터들의 행 인덱스 저장해서 바꾸기
seoul_error_list = df_seoul_2[~df_seoul_2.state.str.contains('서울특별시')].index
seoul_error_list
# Out:
# Int64Index([ 67106, 103825, 103859, 103861, 103866, 103871, 103877, 103894,
#             103948, 103949,
#             ...
#             172094, 172095, 172096, 172097, 172098, 172099, 172100, 172101,
#             172102, 172103],
#            dtype='int64', length=11999)

# %%
df_seoul_2.loc[67106]
# Out:
# address        서울틀별시 금천구 독산로64길 70-7
# state                          서울틀별시
# city                             금천구
# lat                        37.466687
# long                      126.906342
# install_cnt                        1
# date                      2022-02-26
# Name: 67106, dtype: object

# %%
for i in seoul_error_list:
    if i not in [67106]:
        df_seoul_2.at[i, 'state'] = np.nan
        df_seoul_2.at[i, 'city'] = np.nan
    else:
         df_seoul_2.at[i, 'state'] = '서울특별시'

df_seoul_2.loc[seoul_error_list]
# Out:
#                       address  state city        lat        long  install_cnt  \
# 67106   서울틀별시 금천구 독산로64길 70-7  서울특별시  금천구  37.466687  126.906342            1
# 103825                한양 아파트앞    NaN  NaN        NaN         NaN            1
# 103859                      산    NaN  NaN        NaN         NaN            1
# 103861                  안산초교위    NaN  NaN        NaN         NaN            1
# 103866               환의사올라가는길    NaN  NaN        NaN         NaN            1
# ...                       ...    ...  ...        ...         ...          ...
# 172099             연서로48길33-7    NaN  NaN        NaN         NaN            1
# 172100             진관로36삼천사입구    NaN  NaN        NaN         NaN            1
# 172101             진관로36삼천사입구    NaN  NaN        NaN         NaN            1
# 172102         통일로961(신도교 뒤편)    NaN  NaN  37.628792  126.918639            1
# 172103         통일로961(신도교 뒤편)    NaN  NaN  37.628792  126.918639            1
#
#               date
# ...

# %%
# df_seoul_3 = df_seoul_2[df_seoul_2['state'].str.contains('서울')]
# # df_seoul_3 = df_seoul_2[df_seoul_2['state'].str.contains('서울')].state.unique()  # ['서울특별시', '서울틀별시', '서울시', '서울인조별서유기비서울인조별서유기비']
# df_seoul_3 = df_seoul_3[~df_seoul_3['state'].str.contains('서울인조별서유기비서울인조별서유기비')]
df_seoul_2.state.unique()
# Out:
# array(['서울특별시', nan], dtype=object)

# %%
# state 오류난 것 수정
# df_seoul_3.loc[~df_seoul_3.state.str.contains('서울특별시'), 'state'] = '서울특별시'
# df_seoul_3.state.unique()

# %%
# df_seoul_3.info()

# %% [markdown]
# ### 세종

# %%
# 파일 리스트 확인 (주의: 파일명 반복문으로 돌릴 수 있게 규칙성 있는 파일명으로 통일)
import os
os.listdir('C:/Users/samsung/TIL/DS/project/miniPJ/01_pj/data/rawdata/rawdata_보안등/rawdata/세종')
# Out:
# ['세종특별자치시.csv']

# %%
# 파일 여러개 한 번에 불러오기
## 1. 파일 리스트 저장
sejongs = os.listdir('C:/Users/samsung/TIL/DS/project/miniPJ/01_pj/data/rawdata/rawdata_보안등/rawdata/세종')

## 2. 현재 작업 위치로 이동
os.chdir('C:/Users/samsung/TIL/DS/project/miniPJ/01_pj/data/rawdata/rawdata_보안등/rawdata/세종')

## 3. 데이터 프레임 생성하고 모든 파일 합치기
# 새로운 데이터프레임 생성
df_all_sejong = pd.DataFrame()

for sejong in sejongs:
    df = pd.read_csv(sejong, encoding='cp949')
    df_all_sejong = pd.concat([df_all_sejong, df])

df_all_sejong = df_all_sejong.reset_index(drop=True)
df_all_sejong
# Out:
#             보안등위치명  설치개수  소재지도로명주소               소재지지번주소         위도  \
# 0     금남면 감성리 64-2     1       NaN  세종특별자치시 금남면 감성리 64-2  36.443246
# 1      금남면 감성리 267     1       NaN   세종특별자치시 금남면 감성리 267  36.442060
# 2     금남면 감성리 40-1     1       NaN  세종특별자치시 금남면 감성리 40-1  36.444200
# 3       금남면 감성리 26     1       NaN    세종특별자치시 금남면 감성리 26  36.444455
# 4     금남면 감성리 41-3     1       NaN  세종특별자치시 금남면 감성리 41-3  36.443741
# ...            ...   ...       ...                   ...        ...
# 8024   조치원읍 평리 4-1     1       NaN   세종특별자치시 조치원읍 평리 4-1  36.607553
# 8025   조치원읍 평리 5-2     1       NaN   세종특별자치시 조치원읍 평리 5-2  36.607314
# 8026   조치원읍 평리 125     1       NaN   세종특별자치시 조치원읍 평리 125  36.607557
# 8027  조치원읍 평리 12-9     1       NaN  세종특별자치시 조치원읍 평리 12-9  36.606143
# 8028    조치원읍 평리 83     1       NaN    세종특별자치시 조치원읍 평리 83  36.603528
#
#               경도  설치연도 설치형태      관리기관전화번호     관리기관명     데이터기준일자
# 0     127.287690   NaN  한전주  044-301-3733  세종특별자치시청  2023-01-27
# ...

# %%
# 필요한 칼럼만 남기기
df_sejong = df_all_sejong[['설치개수','소재지도로명주소', '소재지지번주소', '위도', '경도', '데이터기준일자']]
df_sejong
# Out:
#       설치개수  소재지도로명주소               소재지지번주소         위도          경도     데이터기준일자
# 0        1       NaN  세종특별자치시 금남면 감성리 64-2  36.443246  127.287690  2023-01-27
# 1        1       NaN   세종특별자치시 금남면 감성리 267  36.442060  127.290660  2023-01-27
# 2        1       NaN  세종특별자치시 금남면 감성리 40-1  36.444200  127.289261  2023-01-27
# 3        1       NaN    세종특별자치시 금남면 감성리 26  36.444455  127.290182  2023-01-27
# 4        1       NaN  세종특별자치시 금남면 감성리 41-3  36.443741  127.289463  2023-01-27
# ...    ...       ...                   ...        ...         ...         ...
# 8024     1       NaN   세종특별자치시 조치원읍 평리 4-1  36.607553  127.299616  2023-01-27
# 8025     1       NaN   세종특별자치시 조치원읍 평리 5-2  36.607314  127.298928  2023-01-27
# 8026     1       NaN   세종특별자치시 조치원읍 평리 125  36.607557  127.299620  2023-01-27
# 8027     1       NaN  세종특별자치시 조치원읍 평리 12-9  36.606143  127.301459  2023-01-27
# 8028     1       NaN    세종특별자치시 조치원읍 평리 83  36.603528  127.304721  2023-01-27
#
# [8029 rows x 6 columns]

# %%
# 결측값 확인
df_sejong.isnull().sum()
# Out:
# 설치개수           0
# 소재지도로명주소    8029
# 소재지지번주소        0
# 위도          1092
# 경도          1092
# 데이터기준일자        0
# dtype: int64

# %%
# 도로명주소 + 지번주소 합치기 -> '주소'
df_sejong['주소'] = np.where(pd.notnull(df_sejong['소재지도로명주소']) == True, df_sejong['소재지도로명주소'], df_sejong['소재지지번주소'])
df_sejong['주소'].isna().sum()
# Out:
# C:\Users\samsung\AppData\Local\Temp\ipykernel_17912\793634115.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sejong['주소'] = np.where(pd.notnull(df_sejong['소재지도로명주소']) == True, df_sejong['소재지도로명주소'], df_sejong['소재지지번주소'])
# 0

# %%
# 도로명주소 + 지번주소 drop
## 도로명주소 + 지번주소 제외한 나머지 
df_sejong_2 = df_sejong[df_sejong.columns.difference(['소재지도로명주소', '소재지지번주소'])]
# 칼럼 순서 바꾸기
df_sejong_2 = df_sejong_2[['주소', '위도', '경도', '설치개수', '데이터기준일자']]
# 칼럼명 변경
df_sejong_2 = df_sejong_2.rename(columns={"주소": "address", 
                                        "위도": "lat", 
                                        "경도": "long",
                                       "설치개수": "install_cnt",
                                       "데이터기준일자": "date"})
df_sejong_2
# Out:
#                    address        lat        long  install_cnt        date
# 0     세종특별자치시 금남면 감성리 64-2  36.443246  127.287690            1  2023-01-27
# 1      세종특별자치시 금남면 감성리 267  36.442060  127.290660            1  2023-01-27
# 2     세종특별자치시 금남면 감성리 40-1  36.444200  127.289261            1  2023-01-27
# 3       세종특별자치시 금남면 감성리 26  36.444455  127.290182            1  2023-01-27
# 4     세종특별자치시 금남면 감성리 41-3  36.443741  127.289463            1  2023-01-27
# ...                    ...        ...         ...          ...         ...
# 8024   세종특별자치시 조치원읍 평리 4-1  36.607553  127.299616            1  2023-01-27
# 8025   세종특별자치시 조치원읍 평리 5-2  36.607314  127.298928            1  2023-01-27
# 8026   세종특별자치시 조치원읍 평리 125  36.607557  127.299620            1  2023-01-27
# 8027  세종특별자치시 조치원읍 평리 12-9  36.606143  127.301459            1  2023-01-27
# 8028    세종특별자치시 조치원읍 평리 83  36.603528  127.304721            1  2023-01-27
#
# [8029 rows x 5 columns]

# %%
# 주소 분리 -> 시/도
## 공백 기준으로 분리
df_sejong_2['state'] = df_sejong_2['address'].str.split().str[0]
df_sejong_2['city'] = df_sejong_2['address'].str.split().str[1]
# 칼럼 순서 바꾸기
df_sejong_2 = df_sejong_2[['address', 'state', 'city', 'lat', 'long', 'install_cnt', 'date']]
df_sejong_2
# Out:
#                    address    state  city        lat        long  install_cnt  \
# 0     세종특별자치시 금남면 감성리 64-2  세종특별자치시   금남면  36.443246  127.287690            1
# 1      세종특별자치시 금남면 감성리 267  세종특별자치시   금남면  36.442060  127.290660            1
# 2     세종특별자치시 금남면 감성리 40-1  세종특별자치시   금남면  36.444200  127.289261            1
# 3       세종특별자치시 금남면 감성리 26  세종특별자치시   금남면  36.444455  127.290182            1
# 4     세종특별자치시 금남면 감성리 41-3  세종특별자치시   금남면  36.443741  127.289463            1
# ...                    ...      ...   ...        ...         ...          ...
# 8024   세종특별자치시 조치원읍 평리 4-1  세종특별자치시  조치원읍  36.607553  127.299616            1
# 8025   세종특별자치시 조치원읍 평리 5-2  세종특별자치시  조치원읍  36.607314  127.298928            1
# 8026   세종특별자치시 조치원읍 평리 125  세종특별자치시  조치원읍  36.607557  127.299620            1
# 8027  세종특별자치시 조치원읍 평리 12-9  세종특별자치시  조치원읍  36.606143  127.301459            1
# 8028    세종특별자치시 조치원읍 평리 83  세종특별자치시  조치원읍  36.603528  127.304721            1
#
#             date
# ...

# %%
df_sejong_2.state.unique()
# # df_incheon_2.loc[~df_incheon_2.state.str.contains('전라남도'), 'state'] = '전라남도'
# df_ulsan_2[df_ulsan_2['address'].str.startswith('울산광역시')]
# # df_incheon_2.drop(2583, axis=0, inplace=True)
# df_ulsan_2.state.unique()
# Out:
# array(['세종특별자치시'], dtype=object)

# %% [markdown]
# ### 울산

# %%
# 파일 여러개 한 번에 불러오기
## 1. 파일 리스트 저장
ulsans = os.listdir('C:/Users/samsung/TIL/DS/project/miniPJ/01_pj/data/rawdata/rawdata_보안등/rawdata/울산')

## 2. 현재 작업 위치로 이동
os.chdir('C:/Users/samsung/TIL/DS/project/miniPJ/01_pj/data/rawdata/rawdata_보안등/rawdata/울산')

## 3. 데이터 프레임 생성하고 모든 파일 합치기
# 새로운 데이터프레임 생성
df_all_ulsan = pd.DataFrame()

for ulsan in ulsans:
    df = pd.read_csv(ulsan, encoding='cp949')
    df_all_ulsan = pd.concat([df_all_ulsan, df])

df_all_ulsan = df_all_ulsan.reset_index(drop=True)
df_all_ulsan
# Out:
#                보안등위치명  설치개수                소재지도로명주소                소재지지번주소  \
# 0                 달동1     1   울산광역시 남구 달동 삼산로67번길 5     울산광역시 남구 달동 886-10
# 1                 옥동1     1   울산광역시 남구 옥동 법대로14번길 6      울산광역시 남구 옥동 285-8
# 2                대현동1     1    울산광역시 남구 야음동 대암로 125       울산광역시 남구 야음동 593
# 3                무거동1     1  울산광역시 남구 무거동 대학로1번길 13    울산광역시 남구 무거동 1003-8
# 4                삼산동1     1   울산광역시 남구 삼산동 삼신로6번길 3  울산광역시 남구 삼산동 1377-102
# ...               ...   ...                     ...                    ...
# 32444   학성동 327[5-27]     1       울산광역시 중구 학성공원7길12                    NaN
# 32445   학성동 328[6-31]     1       울산광역시 중구 학성가구거리30                    NaN
# 32446   학성동 329[4-27]     1         울산광역시 중구 옥교로 91                    NaN
# 32447  학성동 330[68-34]     1        울산광역시 중구 화합로 285                    NaN
# 32448   학성동 435[5-26]     1      울산광역시 중구 중구 내황7길43                    NaN
#
# ...

# %%
# 필요한 칼럼만 남기기
df_ulsan = df_all_ulsan[['설치개수','소재지도로명주소', '소재지지번주소', '위도', '경도', '데이터기준일자']]

# 결측값 확인
df_ulsan.isnull().sum()
# Out:
# 설치개수            0
# 소재지도로명주소    20559
# 소재지지번주소      5230
# 위도            730
# 경도            735
# 데이터기준일자         0
# dtype: int64

# %%
# 도로명주소 + 지번주소 합치기 -> '주소'
df_ulsan['주소'] = np.where(pd.notnull(df_ulsan['소재지도로명주소']) == True, df_ulsan['소재지도로명주소'], df_ulsan['소재지지번주소'])
df_ulsan['주소'].isna().sum()
# Out:
# C:\Users\samsung\AppData\Local\Temp\ipykernel_17912\3679938108.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ulsan['주소'] = np.where(pd.notnull(df_ulsan['소재지도로명주소']) == True, df_ulsan['소재지도로명주소'], df_ulsan['소재지지번주소'])
# 0

# %%
# 도로명주소 + 지번주소 drop
## 도로명주소 + 지번주소 제외한 나머지 
df_ulsan_2 = df_ulsan[df_ulsan.columns.difference(['소재지도로명주소', '소재지지번주소'])]
# 칼럼 순서 바꾸기
df_ulsan_2 = df_ulsan_2[['주소', '위도', '경도', '설치개수', '데이터기준일자']]
# 칼럼명 변경
df_ulsan_2 = df_ulsan_2.rename(columns={"주소": "address", 
                                        "위도": "lat", 
                                        "경도": "long",
                                       "설치개수": "install_cnt",
                                       "데이터기준일자": "date"})
# 주소 분리 -> 시/도
## 공백 기준으로 분리
df_ulsan_2['state'] = df_ulsan_2['address'].str.split().str[0]
df_ulsan_2['city'] = df_ulsan_2['address'].str.split().str[1]
# 칼럼 순서 바꾸기
df_ulsan_2 = df_ulsan_2[['address', 'state', 'city', 'lat', 'long', 'install_cnt', 'date']]

df_ulsan_2
# Out:
#                       address  state city        lat        long  install_cnt  \
# 0       울산광역시 남구 달동 삼산로67번길 5  울산광역시   남구  35.534791  129.314712            1
# 1       울산광역시 남구 옥동 법대로14번길 6  울산광역시   남구  35.537194  129.284165            1
# 2        울산광역시 남구 야음동 대암로 125  울산광역시   남구  35.529848  129.329032            1
# 3      울산광역시 남구 무거동 대학로1번길 13  울산광역시   남구  35.536894  129.252501            1
# 4       울산광역시 남구 삼산동 삼신로6번길 3  울산광역시   남구  35.548757  129.324073            1
# ...                       ...    ...  ...        ...         ...          ...
# 32444       울산광역시 중구 학성공원7길12  울산광역시   중구  35.552197  129.339439            1
# 32445       울산광역시 중구 학성가구거리30  울산광역시   중구  35.554234  129.336578            1
# 32446         울산광역시 중구 옥교로 91  울산광역시   중구  35.551981  129.333923            1
# 32447        울산광역시 중구 화합로 285  울산광역시   중구  35.551387  129.340255            1
# 32448      울산광역시 중구 중구 내황7길43  울산광역시   중구  35.551424  129.339567            1
#
#              date
# ...

# %%
df_ulsan_2.state.unique()
# # df_incheon_2.loc[~df_incheon_2.state.str.contains('전라남도'), 'state'] = '전라남도'
# df_ulsan_2[df_ulsan_2['address'].str.startswith('울산광역시')]
# # df_incheon_2.drop(2583, axis=0, inplace=True)
# df_ulsan_2.state.unique()
# Out:
# array(['울산광역시'], dtype=object)

# %% [markdown]
# ### 인천

# %%
# 파일 여러개 한 번에 불러오기
## 1. 파일 리스트 저장
incheons = os.listdir('C:/Users/samsung/TIL/DS/project/miniPJ/01_pj/data/rawdata/rawdata_보안등/rawdata/인천')

## 2. 현재 작업 위치로 이동
os.chdir('C:/Users/samsung/TIL/DS/project/miniPJ/01_pj/data/rawdata/rawdata_보안등/rawdata/인천')

## 3. 데이터 프레임 생성하고 모든 파일 합치기
# 새로운 데이터프레임 생성
df_all_incheon = pd.DataFrame()

for incheon in incheons:
    df = pd.read_csv(incheon, encoding='cp949')
    df_all_incheon = pd.concat([df_all_incheon, df])

df_all_incheon = df_all_incheon.reset_index(drop=True)
df_all_incheon
# Out:
#             보안등위치명  설치개수                  소재지도로명주소                   소재지지번주소  \
# 0      20200305-01     1                       NaN  인천광역시 강화군 서도면 주문도리 703-3
# 1      20200305-02     1                       NaN  인천광역시 강화군 서도면 볼음도리 564-2
# 2           갑곳리001     1      인천광역시 강화군 강화읍 대월로 16     인천광역시 강화군 강화읍 갑곳리 190
# 3           갑곳리002     1      인천광역시 강화군 강화읍 대월로 12     인천광역시 강화군 강화읍 갑곳리 189
# 4           갑곳리003     1  인천광역시 강화군 강화읍 강화대로 322-1   인천광역시 강화군 강화읍 갑곳리 182-6
# ...            ...   ...                       ...                       ...
# 48998      율목동5267     1        인천광역시 중구 율목로32번길 9                       NaN
# 48999      율목동5270     1    인천광역시 중구 개항로96번길 30-11                       NaN
# 49000      율목동5273     1        인천광역시 중구 율목로8번길 30                       NaN
# 49001      율목동5274     1       인천광역시 중구 율목로30번길 32                       NaN
# 49002       해안1223     1      인천광역시 중구 인중로144번길 31                       NaN
#
# ...

# %%
# 필요한 칼럼만 남기기
df_incheon = df_all_incheon[['설치개수','소재지도로명주소', '소재지지번주소', '위도', '경도', '데이터기준일자']]

# 결측값 확인
df_incheon.isnull().sum()

# 도로명주소 + 지번주소 합치기 -> '주소'
df_incheon['주소'] = np.where(pd.notnull(df_incheon['소재지도로명주소']) == True, df_incheon['소재지도로명주소'], df_incheon['소재지지번주소'])
df_incheon['주소'].isna().sum()
# Out:
# C:\Users\samsung\AppData\Local\Temp\ipykernel_17912\3767331613.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_incheon['주소'] = np.where(pd.notnull(df_incheon['소재지도로명주소']) == True, df_incheon['소재지도로명주소'], df_incheon['소재지지번주소'])
# 0

# %%
# 도로명주소 + 지번주소 drop
## 도로명주소 + 지번주소 제외한 나머지 
df_incheon_2 = df_incheon[df_incheon.columns.difference(['소재지도로명주소', '소재지지번주소'])]
# 칼럼 순서 바꾸기
df_incheon_2 = df_incheon_2[['주소', '위도', '경도', '설치개수', '데이터기준일자']]
# 칼럼명 변경
df_incheon_2 = df_incheon_2.rename(columns={"주소": "address", 
                                        "위도": "lat", 
                                        "경도": "long",
                                       "설치개수": "install_cnt",
                                       "데이터기준일자": "date"})
# 주소 분리 -> 시/도
## 공백 기준으로 분리
df_incheon_2['state'] = df_incheon_2['address'].str.split().str[0]
df_incheon_2['city'] = df_incheon_2['address'].str.split().str[1]
# 칼럼 순서 바꾸기
df_incheon_2 = df_incheon_2[['address', 'state', 'city', 'lat', 'long', 'install_cnt', 'date']]

df_incheon_2
# Out:
#                         address  state city        lat        long  \
# 0      인천광역시 강화군 서도면 주문도리 703-3  인천광역시  강화군        NaN         NaN
# 1      인천광역시 강화군 서도면 볼음도리 564-2  인천광역시  강화군        NaN         NaN
# 2          인천광역시 강화군 강화읍 대월로 16  인천광역시  강화군        NaN         NaN
# 3          인천광역시 강화군 강화읍 대월로 12  인천광역시  강화군        NaN         NaN
# 4      인천광역시 강화군 강화읍 강화대로 322-1  인천광역시  강화군        NaN         NaN
# ...                         ...    ...  ...        ...         ...
# 48998        인천광역시 중구 율목로32번길 9  인천광역시   중구  37.469895  126.633724
# 48999    인천광역시 중구 개항로96번길 30-11  인천광역시   중구  37.470660  126.634111
# 49000        인천광역시 중구 율목로8번길 30  인천광역시   중구  37.469938  126.634730
# 49001       인천광역시 중구 율목로30번길 32  인천광역시   중구  37.469575  126.635388
# 49002      인천광역시 중구 인중로144번길 31  인천광역시   중구  37.467309  126.629106
#
#        install_cnt        date
# 0                1  2021-09-03
# 1                1  2021-09-03
# 2                1  2021-09-03
# 3                1  2021-09-03
# ...

# %%
# 주소에 '인천'이 포함된 주소만 남기고, '경기도' 행은 삭제
df_incheon_2.loc[~df_incheon_2.state.str.contains('인천'), 'state'].unique()
# Out:
# array(['경기도'], dtype=object)

# %%
df_incheon_2.state.unique()  # 경기도 데이터 1개 들어가 있음. -> 삭제

df_incheon_2[df_incheon_2['address'].str.startswith('경기도')]
df_incheon_2.drop(12502, axis=0, inplace=True)
df_incheon_2.state.unique()
# Out:
# array(['인천광역시'], dtype=object)

# %% [markdown]
# ### 전라남도

# %%
# 파일 여러개 한 번에 불러오기
## 1. 파일 리스트 저장
jns = os.listdir('C:/Users/samsung/TIL/DS/project/miniPJ/01_pj/data/rawdata/rawdata_보안등/rawdata/전라남도')

## 2. 현재 작업 위치로 이동
os.chdir('C:/Users/samsung/TIL/DS/project/miniPJ/01_pj/data/rawdata/rawdata_보안등/rawdata/전라남도')

## 3. 데이터 프레임 생성하고 모든 파일 합치기
# 새로운 데이터프레임 생성
df_all_jn = pd.DataFrame()

for jn in jns:
    df = pd.read_csv(jn, encoding='cp949')
    df_all_jn = pd.concat([df_all_jn, df])

df_all_jn = df_all_jn.reset_index(drop=True)
df_all_jn
# Out:
#               보안등위치명  설치개수 소재지도로명주소                 소재지지번주소         위도  \
# 0       03-4257-8543     1      NaN    전라남도 강진군 강진읍 교촌리 544        NaN
# 1       03-4243-9310     1      NaN     전라남도 강진군 병영면 상고길 21        NaN
# 2       03-4243-9276     1      NaN    전라남도 강진군 군동면 덕천2길 41        NaN
# 3       03-4243-9258     1      NaN  전라남도 강진군 군동면 덕천2길 26-1        NaN
# 4       03-4243-9212     1      NaN  전라남도 강진군 군동면 덕천1길 22-7        NaN
# ...              ...   ...      ...                     ...        ...
# 164017           화순읍     1      NaN   전라남도 화순군 화순읍 대리 514-7  35.046932
# 164018           화순읍     1      NaN   전라남도 화순군 화순읍 대리 514-7  35.046845
# 164019           화순읍     1      NaN   전라남도 화순군 화순읍 대리 514-7  35.046772
# 164020           화순읍     1      NaN   전라남도 화순군 화순읍 대리 513-9  35.046694
# 164021           화순읍     1      NaN   전라남도 화순군 화순읍 대리 513-9  35.046614
#
#                 경도    설치연도 설치형태      관리기관전화번호      관리기관명     데이터기준일자  설치년도
# ...

# %%
# 필요한 칼럼만 남기기
df_jn = df_all_jn[['설치개수','소재지도로명주소', '소재지지번주소', '위도', '경도', '데이터기준일자']]

# 결측값 확인
df_jn.isnull().sum()

# 도로명주소 + 지번주소 합치기 -> '주소'
df_jn['주소'] = np.where(pd.notnull(df_jn['소재지도로명주소']) == True, df_jn['소재지도로명주소'], df_jn['소재지지번주소'])
df_jn['주소'].isna().sum()
# Out:
# C:\Users\samsung\AppData\Local\Temp\ipykernel_17912\518872940.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_jn['주소'] = np.where(pd.notnull(df_jn['소재지도로명주소']) == True, df_jn['소재지도로명주소'], df_jn['소재지지번주소'])
# 0

# %%
# 도로명주소 + 지번주소 drop
## 도로명주소 + 지번주소 제외한 나머지 
df_jn_2 = df_jn[df_jn.columns.difference(['소재지도로명주소', '소재지지번주소'])]
# 칼럼 순서 바꾸기
df_jn_2 = df_jn_2[['주소', '위도', '경도', '설치개수', '데이터기준일자']]
# 칼럼명 변경
df_jn_2 = df_jn_2.rename(columns={"주소": "address", 
                                        "위도": "lat", 
                                        "경도": "long",
                                       "설치개수": "install_cnt",
                                       "데이터기준일자": "date"})
# 주소 분리 -> 시/도
## 공백 기준으로 분리
df_jn_2['state'] = df_jn_2['address'].str.split().str[0]
df_jn_2['city'] = df_jn_2['address'].str.split().str[1]
# 칼럼 순서 바꾸기
df_jn_2 = df_jn_2[['address', 'state', 'city', 'lat', 'long', 'install_cnt', 'date']]

df_jn_2
# Out:
#                        address state city        lat        long  install_cnt  \
# 0         전라남도 강진군 강진읍 교촌리 544  전라남도  강진군        NaN         NaN            1
# 1          전라남도 강진군 병영면 상고길 21  전라남도  강진군        NaN         NaN            1
# 2         전라남도 강진군 군동면 덕천2길 41  전라남도  강진군        NaN         NaN            1
# 3       전라남도 강진군 군동면 덕천2길 26-1  전라남도  강진군        NaN         NaN            1
# 4       전라남도 강진군 군동면 덕천1길 22-7  전라남도  강진군        NaN         NaN            1
# ...                        ...   ...  ...        ...         ...          ...
# 164017   전라남도 화순군 화순읍 대리 514-7  전라남도  화순군  35.046932  126.966061            1
# 164018   전라남도 화순군 화순읍 대리 514-7  전라남도  화순군  35.046845  126.965730            1
# 164019   전라남도 화순군 화순읍 대리 514-7  전라남도  화순군  35.046772  126.965451            1
# 164020   전라남도 화순군 화순읍 대리 513-9  전라남도  화순군  35.046694  126.965166            1
# 164021   전라남도 화순군 화순읍 대리 513-9  전라남도  화순군  35.046614  126.964881            1
#
#               date
# ...

# %%
# 주소에 '전라남도'이 포함된 주소만 남기고, '경기도' 행은 삭제
df_jn_2.loc[~df_jn_2.state.str.contains('전라남도'), 'state'].unique()
# Out:
# array(['경기도', '영암읍교회', '영암읍', '엉암읍', '덕진', '금정면', '시종면', '덕진면', '도포면',
#        '미암면', '서호면', '군서면', '신북면', '학산면', '영암초등학교', '잠곡동길', '삼호읍',
#        '역리사거리~터미널', '공용주차장', '80W설치', '하정웅미술관', '영암읍송평로334',
#        '대봉간336L4R17L18', '영암성당(영암읍)', '영암로', '남', '함평군'], dtype=object)

# %%
# df_jn_2[df_jn_2.state != '전라남도']
# df_jn_2[df_jn_2.state != '전라남도'].state.unique()

# %%
# 경기도 삭제
df_jn_3 = df_jn_2[~df_jn_2['state'].str.contains('경기도')].reset_index(inplace=False)
df_jn_3 = df_jn_3.drop(['index'], axis=1)
df_jn_3[df_jn_3.state != '전라남도'].state.unique()
# Out:
# array(['영암읍교회', '영암읍', '엉암읍', '덕진', '금정면', '시종면', '덕진면', '도포면', '미암면',
#        '서호면', '군서면', '신북면', '학산면', '영암초등학교', '잠곡동길', '삼호읍', '역리사거리~터미널',
#        '공용주차장', '80W설치', '하정웅미술관', '영암읍송평로334', '대봉간336L4R17L18',
#        '영암성당(영암읍)', '영암로', '남', '함평군'], dtype=object)

# %%
df_jn_3[df_jn_3.state != '전라남도']
# df_jn_3[df_jn_3.state == '역리사거리~터미널']
# Out:
#                       address  state    city  lat        long  install_cnt  \
# 109020               영암읍교회 골목  영암읍교회      골목  NaN         NaN            1
# 109021            영암읍 배날리길 46    영암읍    배날리길  NaN         NaN            1
# 109022               엉암읍 파출소옆    엉암읍    파출소옆  NaN         NaN            1
# 109023            덕진 우도마을회관 앞     덕진  우도마을회관  NaN         NaN            1
# 109024         금정면 남송리 718-18    금정면     남송리  NaN         NaN            1
# ...                       ...    ...     ...  ...         ...          ...
# 109640      군서면 서구림리 1295-2번지    군서면    서구림리  NaN         NaN            1
# 109641          군서면 마산리 822번지    군서면     마산리  NaN         NaN            1
# 109642          삼호읍 산호리 314-1    삼호읍     산호리  NaN         NaN            1
# 114726      남 완도군 완도읍 군내길 256      남     완도군  NaN         NaN            1
# 139008  함평군 함평군 엄다면 성천리 492-2    함평군     함평군  NaN  126.510979            1
#
#               date
# 109020  2021-11-05
# 109021  2021-11-05
# ...

# %%
'''
['영암읍교회', '영암읍', '엉암읍', '덕진', '금정면', '시종면', '덕진면', '도포면', '미암면',
       '서호면', '군서면', '신북면', '학산면', '영암초등학교', '잠곡동길', '삼호읍', ('역리사거리~터미널'),
       ('공용주차장', '80W설치'), '하정웅미술관', '영암읍송평로334', ('대봉간336L4R17L18'),
       '영암성당(영암읍)', '영암로', '남', '함평군']
'''
# 수정
jn_error_list = df_jn_3[df_jn_3.state != '전라남도'].index
# jn_error_list
for i in jn_error_list:
    if i not in [114726, 139008]:
        df_jn_3.at[i, 'state'] = '전라남도'
        df_jn_3.at[i, 'city'] = '영암군'    
    else:
        df_jn_3.at[i, 'state'] = '전라남도'
# ()표시한 부분은 nan 처리 (정확한 위치 파악 어렵기 때문)
for j in [109195, 109216, 109529, 109123]:
    df_jn_3.at[j, 'state'] = np.nan
    df_jn_3.at[j, 'city'] = np.nan
    
df_jn_3.loc[jn_error_list]
# print(df_jn_3.loc[[jn_error_list]])
df_jn_3[df_jn_3.state.isnull()]
# Out:
#                address state city  lat  long  install_cnt        date
# 109123       역리사거리~터미널   NaN  NaN  NaN   NaN            1  2021-11-05
# 109195        공용주차장 점등   NaN  NaN  NaN   NaN            1  2021-11-05
# 109216           80W설치   NaN  NaN  NaN   NaN            1  2021-11-05
# 109529  대봉간336L4R17L18   NaN  NaN  NaN   NaN            1  2021-11-05

# %%
df_jn_3.state.unique()
# df_jn_2.loc[~df_jn_2.state.str.contains('전라남도'), 'state'] = '전라남도'
# # df_jn_2[~df_jb_2['address'].str.startswith('전라북도')]
# df_jn_2.state.unique()
# Out:
# array(['전라남도', nan], dtype=object)

# %% [markdown]
# ### 전라북도

# %%
# 파일 여러개 한 번에 불러오기
## 1. 파일 리스트 저장
jbs = os.listdir('C:/Users/samsung/TIL/DS/project/miniPJ/01_pj/data/rawdata/rawdata_보안등/rawdata/전라북도')

## 2. 현재 작업 위치로 이동
os.chdir('C:/Users/samsung/TIL/DS/project/miniPJ/01_pj/data/rawdata/rawdata_보안등/rawdata/전라북도')

## 3. 데이터 프레임 생성하고 모든 파일 합치기
# 새로운 데이터프레임 생성
df_all_jb = pd.DataFrame()

for jb in jbs:
    df = pd.read_csv(jb, encoding='cp949')
    df_all_jb = pd.concat([df_all_jb, df])

df_all_jb = df_all_jb.reset_index(drop=True)
df_all_jb
# Out:
#            보안등위치명  설치개수                   소재지도로명주소                   소재지지번주소  \
# 0       야동교 옆 삼거리     1  전라북도 고창군 흥덕면 선운대로 3714-81    전라북도 고창군 흥덕면 흥덕리 산20-1
# 1          아바헤어 앞     1         전라북도 고창군 흥덕면 서삼길 8    전라북도 고창군 흥덕면 흥덕리 602-2
# 2          광성빌라 앞     1        전라북도 고창군 흥덕면 서삼길 18      전라북도 고창군 흥덕면 흥덕리 574
# 3          광성빌라 앞     1        전라북도 고창군 흥덕면 서삼길 18      전라북도 고창군 흥덕면 흥덕리 549
# 4           흥덕중학교     3        전라북도 고창군 흥덕면 잿말길 21      전라북도 고창군 흥덕면 흥덕리 436
# ...           ...   ...                        ...                       ...
# 103836   동향면 7005     1      전라북도 진안군 동향면 장전길 15-3      전라북도 진안군 동향면 성산리 944
# 103837   동향면 7004     1      전라북도 진안군 동향면 장전길 15-3    전라북도 진안군 동향면 성산리 924-1
# 103838   동향면 7003     1      전라북도 진안군 동향면 장전길 16-3    전라북도 진안군 동향면 성산리 867-4
# 103839   동향면 7002     1                        NaN    전라북도 진안군 동향면 성산리 911-6
# 103840    군상리 811     1                        NaN  전라북도 진안군 진안읍 군상리 1162-16
#
# ...

# %%
# 필요한 칼럼만 남기기
df_jb = df_all_jb[['설치개수','소재지도로명주소', '소재지지번주소', '위도', '경도', '데이터기준일자']]

# 결측값 확인
df_jb.isnull().sum()

# 도로명주소 + 지번주소 합치기 -> '주소'
df_jb['주소'] = np.where(pd.notnull(df_jb['소재지도로명주소']) == True, df_jb['소재지도로명주소'], df_jb['소재지지번주소'])
df_jb['주소'].isna().sum()
# Out:
# C:\Users\samsung\AppData\Local\Temp\ipykernel_17912\2439395029.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_jb['주소'] = np.where(pd.notnull(df_jb['소재지도로명주소']) == True, df_jb['소재지도로명주소'], df_jb['소재지지번주소'])
# 0

# %%
# 도로명주소 + 지번주소 drop
## 도로명주소 + 지번주소 제외한 나머지 
df_jb_2 = df_jb[df_jb.columns.difference(['소재지도로명주소', '소재지지번주소'])]
# 칼럼 순서 바꾸기
df_jb_2 = df_jb_2[['주소', '위도', '경도', '설치개수', '데이터기준일자']]
# 칼럼명 변경
df_jb_2 = df_jb_2.rename(columns={"주소": "address", 
                                        "위도": "lat", 
                                        "경도": "long",
                                       "설치개수": "install_cnt",
                                       "데이터기준일자": "date"})
# 주소 분리 -> 시/도
## 공백 기준으로 분리
df_jb_2['state'] = df_jb_2['address'].str.split().str[0]
df_jb_2['city'] = df_jb_2['address'].str.split().str[1]
# 칼럼 순서 바꾸기
df_jb_2 = df_jb_2[['address', 'state', 'city', 'lat', 'long', 'install_cnt', 'date']]

df_jb_2
# Out:
#                           address state city        lat        long  \
# 0       전라북도 고창군 흥덕면 선운대로 3714-81  전라북도  고창군  35.513142  126.698881
# 1              전라북도 고창군 흥덕면 서삼길 8  전라북도  고창군  35.518014  126.699397
# 2             전라북도 고창군 흥덕면 서삼길 18  전라북도  고창군  35.517411  126.698679
# 3             전라북도 고창군 흥덕면 서삼길 18  전라북도  고창군  35.519236  126.699456
# 4             전라북도 고창군 흥덕면 잿말길 21  전라북도  고창군  35.523162  126.701473
# ...                           ...   ...  ...        ...         ...
# 103836      전라북도 진안군 동향면 장전길 15-3  전라북도  진안군  35.818647  127.525745
# 103837      전라북도 진안군 동향면 장전길 15-3  전라북도  진안군  35.818631  127.525745
# 103838      전라북도 진안군 동향면 장전길 16-3  전라북도  진안군  35.818169  127.526158
# 103839     전라북도 진안군 동향면 성산리 911-6  전라북도  진안군  35.818220  127.524675
# 103840   전라북도 진안군 진안읍 군상리 1162-16  전라북도  진안군  35.798132  127.419874
#
#         install_cnt        date
# 0                 1  2020-07-31
# 1                 1  2020-07-31
# 2                 1  2020-07-31
# ...

# %%
# 주소에 '전라북도'이 포함된 주소만 남기고, '전주시' 행 확인 후 필요없으면 삭제
df_jb_2.loc[~df_jb_2.state.str.contains('전라북도'), 'state'].unique()
# Out:
# array(['전주시'], dtype=object)

# %%
df_jb_2[df_jb_2.state.str.contains('전주시')]
# Out:
#                         address state city        lat        long  \
# 64107     전주시 완산구 서노송동 기린대로 242   전주시  완산구  35.827972         NaN
# 64108  전주시 완산구 서노송동 기린대로 240-12   전주시  완산구  35.828233  127.144933
# 64109  전주시 완산구 서노송동 기린대로 240-11   전주시  완산구  35.828278  127.144833
# 64110   전주시 완산구 서노송동 기린대로 248-7   전주시  완산구  35.828519  127.144509
# 64111     전주시 완산구 서노송동 반촌로 5-13   전주시  완산구  35.828593  127.144752
# ...                         ...   ...  ...        ...         ...
# 85022             전주시 덕진구 호성동2가   전주시  덕진구  35.873074  127.143880
# 85023             전주시 덕진구 호성동3가   전주시  덕진구  35.898308  127.134926
# 85024             전주시 덕진구 호성동3가   전주시  덕진구  35.882119  127.135145
# 85025             전주시 덕진구 호성동1가   전주시  덕진구  35.856797  127.153341
# 85026             전주시 덕진구 호성동1가   전주시  덕진구  35.856862  127.153120
#
#        install_cnt        date
# 64107            1  2021-08-31
# 64108            1  2021-08-31
# 64109            1  2021-08-31
# 64110            1  2021-08-31
# ...

# %%
df_jb_2.loc[df_jb_2.state == '전주시', 'city'] = "전주시"
df_jb_2.loc[df_jb_2.city == '전주시', 'state'] = '전라북도'
df_jb_2.loc[df_jb_2.city == '전주시']
df_jb_2.state.unique()
# Out:
# array(['전라북도', '전북전라북도'], dtype=object)

# %%
# state == '전북전라북도' 확인 --> state명 변경 (전북전라북도 -> 전라북도)
df_jb_2[df_jb_2.state == '전북전라북도']
# Out:
#                   address   state city  lat  long  install_cnt        date
# 19374  전북전라북도 남원시 황산로 823  전북전라북도  남원시  NaN   NaN            1  2022-06-16

# %%
# --> state명 변경 (전북전라북도 -> 전라북도)
df_jb_2.loc[df_jb_2.state == '전북전라북도', 'state'] = "전라북도"
df_jb_2.state.unique()
# Out:
# array(['전라북도'], dtype=object)

# %%
# df_jb_2.state.unique()

# df_jb_2.loc[df_jb_2.state.str.contains('전라북도'), 'state'] = '전라북도'
# df_jb_2[~df_jb_2['address'].str.startswith('전라북도')]
# df_jb_2.state.unique()

# %% [markdown]
# ### 제주도

# %%
# 파일 여러개 한 번에 불러오기
## 1. 파일 리스트 저장
jejus = os.listdir('C:/Users/samsung/TIL/DS/project/miniPJ/01_pj/data/rawdata/rawdata_보안등/rawdata/제주도')

## 2. 현재 작업 위치로 이동
os.chdir('C:/Users/samsung/TIL/DS/project/miniPJ/01_pj/data/rawdata/rawdata_보안등/rawdata/제주도')

## 3. 데이터 프레임 생성하고 모든 파일 합치기
# 새로운 데이터프레임 생성
df_all_jeju = pd.DataFrame()

for jeju in jejus:
    df = pd.read_csv(jeju, encoding='cp949')
    df_all_jeju = pd.concat([df_all_jeju, df])

df_all_jeju = df_all_jeju.reset_index(drop=True)
df_all_jeju
# Out:
#             보안등위치명  설치개수 소재지도로명주소                  소재지지번주소         위도  \
# 0       하예로 1-30-1     1      NaN  제주특별자치도 서귀포시 하예동 1125-5  33.243772
# 1        선반로 96-12     1      NaN  제주특별자치도 서귀포시 강정동 2281-1  33.242087
# 2        동홍로 286-5     1      NaN  제주특별자치도 서귀포시 동홍동 928-14  33.273757
# 3        동홍로 286-7     1      NaN  제주특별자치도 서귀포시 동홍동 928-14  33.273757
# 4        예래로 426-3     1      NaN  제주특별자치도 서귀포시 하예동 1850-1  33.236185
# ...            ...   ...      ...                      ...        ...
# 33257  화북일동 4668-5     1      NaN  제주특별자치도 제주시 화북일동 4668-5  33.515438
# 33258   회천동 2866-6     1      NaN   제주특별자치도 제주시 회천동 2866-6  33.496864
# 33259   회천동 2866-6     1      NaN   제주특별자치도 제주시 회천동 2866-6  33.496864
# 33260     회천동 3270     1      NaN     제주특별자치도 제주시 회천동 3270  33.496963
# 33261     회천동 3270     1      NaN     제주특별자치도 제주시 회천동 3270  33.496963
#
#                경도  설치연도 설치형태      관리기관전화번호          관리기관명     데이터기준일자
# ...

# %%
# 필요한 칼럼만 남기기
df_jeju = df_all_jeju[['설치개수','소재지도로명주소', '소재지지번주소', '위도', '경도', '데이터기준일자']]

# 결측값 확인
df_jeju.isnull().sum()

# 도로명주소 + 지번주소 합치기 -> '주소'
df_jeju['주소'] = np.where(pd.notnull(df_jeju['소재지도로명주소']) == True, df_jeju['소재지도로명주소'], df_jeju['소재지지번주소'])
df_jeju['주소'].isna().sum()
# Out:
# C:\Users\samsung\AppData\Local\Temp\ipykernel_17912\34350087.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_jeju['주소'] = np.where(pd.notnull(df_jeju['소재지도로명주소']) == True, df_jeju['소재지도로명주소'], df_jeju['소재지지번주소'])
# 0

# %%
# 도로명주소 + 지번주소 drop
## 도로명주소 + 지번주소 제외한 나머지 
df_jeju_2 = df_jeju[df_jeju.columns.difference(['소재지도로명주소', '소재지지번주소'])]
# 칼럼 순서 바꾸기
df_jeju_2 = df_jeju_2[['주소', '위도', '경도', '설치개수', '데이터기준일자']]
# 칼럼명 변경
df_jeju_2 = df_jeju_2.rename(columns={"주소": "address", 
                                        "위도": "lat", 
                                        "경도": "long",
                                       "설치개수": "install_cnt",
                                       "데이터기준일자": "date"})
# 주소 분리 -> 시/도
## 공백 기준으로 분리
df_jeju_2['state'] = df_jeju_2['address'].str.split().str[0]
df_jeju_2['city'] = df_jeju_2['address'].str.split().str[1]
# 칼럼 순서 바꾸기
df_jeju_2 = df_jeju_2[['address', 'state', 'city', 'lat', 'long', 'install_cnt', 'date']]

df_jeju_2
# Out:
#                        address    state  city        lat        long  \
# 0      제주특별자치도 서귀포시 하예동 1125-5  제주특별자치도  서귀포시  33.243772  126.383005
# 1      제주특별자치도 서귀포시 강정동 2281-1  제주특별자치도  서귀포시  33.242087  126.495897
# 2      제주특별자치도 서귀포시 동홍동 928-14  제주특별자치도  서귀포시  33.273757  126.568191
# 3      제주특별자치도 서귀포시 동홍동 928-14  제주특별자치도  서귀포시  33.273757  126.568191
# 4      제주특별자치도 서귀포시 하예동 1850-1  제주특별자치도  서귀포시  33.236185  126.372330
# ...                        ...      ...   ...        ...         ...
# 33257  제주특별자치도 제주시 화북일동 4668-5  제주특별자치도   제주시  33.515438  126.557533
# 33258   제주특별자치도 제주시 회천동 2866-6  제주특별자치도   제주시  33.496864  126.605736
# 33259   제주특별자치도 제주시 회천동 2866-6  제주특별자치도   제주시  33.496864  126.605736
# 33260     제주특별자치도 제주시 회천동 3270  제주특별자치도   제주시  33.496963  126.606064
# 33261     제주특별자치도 제주시 회천동 3270  제주특별자치도   제주시  33.496963  126.606064
#
#        install_cnt        date
# 0                1  2022-12-15
# 1                1  2022-12-15
# 2                1  2022-12-15
# ...

# %%
df_jeju_2.state.unique()
# df_jeju_2.loc[~df_jeju_2.state.str.contains('제주특별자치도'), 'state'] = '제주특별자치도'
# df_jeju_2[~df_jeju_2['address'].str.startswith('제주특별자치도')]
# Out:
# array(['제주특별자치도'], dtype=object)

# %% [markdown]
# ### 충청남도

# %%
# 파일 여러개 한 번에 불러오기
## 1. 파일 리스트 저장
chungns = os.listdir('C:/Users/samsung/TIL/DS/project/miniPJ/01_pj/data/rawdata/rawdata_보안등/rawdata/충청남도')

## 2. 현재 작업 위치로 이동
os.chdir('C:/Users/samsung/TIL/DS/project/miniPJ/01_pj/data/rawdata/rawdata_보안등/rawdata/충청남도')

## 3. 데이터 프레임 생성하고 모든 파일 합치기
# 새로운 데이터프레임 생성
df_all_chungn = pd.DataFrame()

for chungn in chungns:
    df = pd.read_csv(chungn, encoding='cp949')
    df_all_chungn = pd.concat([df_all_chungn, df])

df_all_chungn = df_all_chungn.reset_index(drop=True)
df_all_chungn
# Out:
#            보안등위치명  설치개수              소재지도로명주소                 소재지지번주소  \
# 0          두마면264     1                   NaN  충청남도 계룡시 두마면 입암리 471-2
# 1          두마면263     1                   NaN  충청남도 계룡시 두마면 입암리 471-2
# 2          두마면261     1                   NaN    충청남도 계룡시 두마면 입암리 461
# 3          두마면258     1                   NaN    충청남도 계룡시 두마면 입암리 448
# 4          두마면257     1                   NaN    충청남도 계룡시 두마면 입암리 447
# ...           ...   ...                   ...                     ...
# 147150   홍성읍L1023     1  충청남도 홍성군 충절로975번길 19  충청남도 홍성군 홍성읍 고암리 626-4
# 147151   홍성읍L1024     1                   NaN     충청남도 홍성군 홍성읍 오관리 86
# 147152    홍성읍남장공원     1                   NaN  충청남도 홍성군 홍성읍 남장리 111-9
# 147153  홍성읍월산리111     1                   NaN  충청남도 홍성군 홍성읍 월산리 109-4
# 147154    홍장북로244     1                   NaN    충청남도 홍성군 홍성읍 고암리 921
#
#                위도          경도  설치년도 설치형태      관리기관전화번호      관리기관명     데이터기준일자  \
# ...

# %%
# 필요한 칼럼만 남기기
df_chungn = df_all_chungn[['설치개수','소재지도로명주소', '소재지지번주소', '위도', '경도', '데이터기준일자']]

# 결측값 확인
df_chungn.isnull().sum()

# df_chungn
# 도로명주소 + 지번주소 합치기 -> '주소'
df_chungn['주소'] = np.where(pd.notnull(df_chungn['소재지도로명주소']) == True, df_chungn['소재지도로명주소'], df_chungn['소재지지번주소'])
df_chungn['주소'].isna().sum()

# df_chungn
# Out:
# C:\Users\samsung\AppData\Local\Temp\ipykernel_17912\2810960791.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chungn['주소'] = np.where(pd.notnull(df_chungn['소재지도로명주소']) == True, df_chungn['소재지도로명주소'], df_chungn['소재지지번주소'])
# 0

# %%
# 도로명주소 + 지번주소 drop
## 도로명주소 + 지번주소 제외한 나머지 
df_chungn_2 = df_chungn[df_chungn.columns.difference(['소재지도로명주소', '소재지지번주소'])]
# 칼럼 순서 바꾸기
df_chungn_2 = df_chungn_2[['주소', '위도', '경도', '설치개수', '데이터기준일자']]
# 칼럼명 변경
df_chungn_2 = df_chungn_2.rename(columns={"주소": "address", 
                                        "위도": "lat", 
                                        "경도": "long",
                                       "설치개수": "install_cnt",
                                       "데이터기준일자": "date"})
# 주소 분리 -> 시/도
# 공백 기준으로 분리
df_chungn_2['state'] = df_chungn_2['address'].str.split().str[0]
df_chungn_2['city'] = df_chungn_2['address'].str.split().str[1]


# 칼럼 순서 바꾸기
df_chungn_2 = df_chungn_2[['address', 'state', 'city', 'lat', 'long', 'install_cnt', 'date']]

df_chungn_2
# Out:
#                        address state city        lat        long  install_cnt  \
# 0       충청남도 계룡시 두마면 입암리 471-2  충청남도  계룡시  36.238987  127.246979            1
# 1       충청남도 계룡시 두마면 입암리 471-2  충청남도  계룡시  36.238987  127.246979            1
# 2         충청남도 계룡시 두마면 입암리 461  충청남도  계룡시  36.240156  127.247117            1
# 3         충청남도 계룡시 두마면 입암리 448  충청남도  계룡시  36.241320  127.247609            1
# 4         충청남도 계룡시 두마면 입암리 447  충청남도  계룡시  36.241355  127.247841            1
# ...                        ...   ...  ...        ...         ...          ...
# 147150    충청남도 홍성군 충절로975번길 19  충청남도  홍성군  36.595328  126.671305            1
# 147151     충청남도 홍성군 홍성읍 오관리 86  충청남도  홍성군  36.602057  126.661837            1
# 147152  충청남도 홍성군 홍성읍 남장리 111-9  충청남도  홍성군  36.591833  126.665072            1
# 147153  충청남도 홍성군 홍성읍 월산리 109-4  충청남도  홍성군  36.603757  126.645163            1
# 147154    충청남도 홍성군 홍성읍 고암리 921  충청남도  홍성군  36.578090  126.674231            1
#
#               date
# ...

# %%
# state 값 제대로 들어가 있는지 확인
df_chungn_2.state.unique()
# Out:
# array(['충청남도', '엘지사택→대산항해상교통관제센터', '화곡리', '부춘동'], dtype=object)

# %%
df_chungn_2[~df_chungn_2.state.str.contains('충청남도')]
# 확인 결과, 아래 모든 행들은 '충청남도 서산시'에 해당됨. -> state & city 값 바꿔주기
# Out:
#                       address             state  city        lat        long  \
# 61822        엘지사택→대산항해상교통관제센터  엘지사택→대산항해상교통관제센터   NaN  36.974348  126.390496
# 61823        엘지사택→대산항해상교통관제센터  엘지사택→대산항해상교통관제센터   NaN  36.974733  126.390000
# 61824        엘지사택→대산항해상교통관제센터  엘지사택→대산항해상교통관제센터   NaN  36.975426  126.389062
# 62094        화곡리 삼길포 은골→대산항방면               화곡리   삼길포  37.007186  126.439964
# 62095        화곡리 삼길포 은골→대산항방면               화곡리   삼길포  37.007638  126.436558
# 65177  부춘동 충청남도 서산시 갈산동 408-2               부춘동  충청남도  36.793957  126.432376
# 65178  부춘동 충청남도 서산시 갈산동 407-2               부춘동  충청남도  36.794732  126.431602
#
#        install_cnt        date
# 61822            1  2021-07-28
# 61823            1  2021-07-28
# 61824            1  2021-07-28
# 62094            1  2021-07-28
# 62095            1  2021-07-28
# 65177            1  2021-07-28
# 65178            1  2021-07-28

# %%
chn_error_list = df_chungn_2[~df_chungn_2.state.str.contains('충청남도')].index
# chn_error_list
for l in chn_error_list:
    df_chungn_2.at[l, 'state'] = '충청남도'
    df_chungn_2.at[l, 'city'] = '서산시'
    
df_chungn_2.state.unique()

df_chungn_2[~df_chungn_2.address.str.contains('충청남도')]
# Out:
#                 address state city        lat        long  install_cnt  \
# 61822  엘지사택→대산항해상교통관제센터  충청남도  서산시  36.974348  126.390496            1
# 61823  엘지사택→대산항해상교통관제센터  충청남도  서산시  36.974733  126.390000            1
# 61824  엘지사택→대산항해상교통관제센터  충청남도  서산시  36.975426  126.389062            1
# 62094  화곡리 삼길포 은골→대산항방면  충청남도  서산시  37.007186  126.439964            1
# 62095  화곡리 삼길포 은골→대산항방면  충청남도  서산시  37.007638  126.436558            1
#
#              date
# 61822  2021-07-28
# 61823  2021-07-28
# 61824  2021-07-28
# 62094  2021-07-28
# 62095  2021-07-28

# %%
df_chungn_2[df_chungn_2.address == '부춘동 충청남도 서산시 갈산동 407-2']
# Out:
#                       address state city        lat        long  install_cnt  \
# 65178  부춘동 충청남도 서산시 갈산동 407-2  충청남도  서산시  36.794732  126.431602            1
#
#              date
# 65178  2021-07-28

# %% [markdown]
# ### 충청북도

# %%
# 파일 여러개 한 번에 불러오기
## 1. 파일 리스트 저장
chungbs = os.listdir('C:/Users/samsung/TIL/DS/project/miniPJ/01_pj/data/rawdata/rawdata_보안등/rawdata/충청북도')

## 2. 현재 작업 위치로 이동
os.chdir('C:/Users/samsung/TIL/DS/project/miniPJ/01_pj/data/rawdata/rawdata_보안등/rawdata/충청북도')

## 3. 데이터 프레임 생성하고 모든 파일 합치기
# 새로운 데이터프레임 생성
df_all_chungb = pd.DataFrame()

for chungb in chungbs:
    df = pd.read_csv(chungb, encoding='cp949')
    df_all_chungb = pd.concat([df_all_chungb, df])

df_all_chungb = df_all_chungb.reset_index(drop=True)
df_all_chungb
# Out:
#                  보안등위치명  설치개수 소재지도로명주소                       소재지지번주소  \
# 0               난계로 24      1      NaN          충청북도 영동군 심천면 각계길 입구
# 1               난계로 25      1      NaN            충청북도 영동군 심천면 난계로
# 2               난계로 26      1      NaN           충청북도 영동군 심천면 난계 1로
# 3               난계로 27      1      NaN  충청북도 영동군 심천면 난계로_SK심천주유소 인근
# 4               난계로 28      1      NaN            충청북도 영동군 심천면 난계로
# ...                 ...   ...      ...                           ...
# 92707   110-5 조선호텔뒤 사거리     1      NaN       충청북도 충주시 수안보면 온천리 111-2
# 92708       135-3 조선호텔옆     1      NaN       충청북도 충주시 수안보면 온천리 131-2
# 92709  수안보면645-1 수안보초교앞     1      NaN        충청북도 충주시 수안보면 온천리 산2-3
# 92710    수안보면577 수안보초교앞     1      NaN       충청북도 충주시 수안보면 안보리 산1-12
# 92711     수안보면 동진이1길 49     1      NaN       충청북도 충주시 수안보면 안보리 579-2
#
#               위도          경도        설치년도 설치형태      관리기관전화번호      관리기관명  \
# 0            NaN         NaN         NaN  한전주  043-740-3503  충청북도 영동군청
# ...

# %%
# 필요한 칼럼만 남기기
df_chungb = df_all_chungb[['설치개수','소재지도로명주소', '소재지지번주소', '위도', '경도', '데이터기준일자']]

# 결측값 확인
df_chungn.isnull().sum()

# df_chungn
# 도로명주소 + 지번주소 합치기 -> '주소'
df_chungb['주소'] = np.where(pd.notnull(df_chungb['소재지도로명주소']) == True, df_chungb['소재지도로명주소'], df_chungb['소재지지번주소'])
df_chungb['주소'].isna().sum()

df_chungb
# Out:
# C:\Users\samsung\AppData\Local\Temp\ipykernel_17912\1964038897.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chungb['주소'] = np.where(pd.notnull(df_chungb['소재지도로명주소']) == True, df_chungb['소재지도로명주소'], df_chungb['소재지지번주소'])
#        설치개수 소재지도로명주소                       소재지지번주소         위도          경도  \
# 0         1      NaN          충청북도 영동군 심천면 각계길 입구         NaN         NaN
# 1         1      NaN            충청북도 영동군 심천면 난계로          NaN   36.171270
# 2         1      NaN           충청북도 영동군 심천면 난계 1로         NaN         NaN
# 3         1      NaN  충청북도 영동군 심천면 난계로_SK심천주유소 인근         NaN         NaN
# 4         1      NaN            충청북도 영동군 심천면 난계로          NaN   36.171270
# ...

# %%
# 도로명주소 + 지번주소 drop
## 도로명주소 + 지번주소 제외한 나머지 
df_chungb_2 = df_chungb[df_chungb.columns.difference(['소재지도로명주소', '소재지지번주소'])]
# 칼럼 순서 바꾸기
df_chungb_2 = df_chungb_2[['주소', '위도', '경도', '설치개수', '데이터기준일자']]
# 칼럼명 변경
df_chungb_2 = df_chungb_2.rename(columns={"주소": "address", 
                                        "위도": "lat", 
                                        "경도": "long",
                                       "설치개수": "install_cnt",
                                       "데이터기준일자": "date"})
# 주소 분리 -> 시/도
## 공백 기준으로 분리
df_chungb_2['state'] = df_chungb_2['address'].str.split().str[0]
df_chungb_2['city'] = df_chungb_2['address'].str.split().str[1]
# 칼럼 순서 바꾸기
df_chungb_2 = df_chungb_2[['address', 'state', 'city', 'lat', 'long', 'install_cnt', 'date']]

df_chungb_2
# Out:
#                             address state city        lat        long  \
# 0              충청북도 영동군 심천면 각계길 입구   충청북도  영동군        NaN         NaN
# 1                충청북도 영동군 심천면 난계로    충청북도  영동군        NaN   36.171270
# 2               충청북도 영동군 심천면 난계 1로   충청북도  영동군        NaN         NaN
# 3      충청북도 영동군 심천면 난계로_SK심천주유소 인근   충청북도  영동군        NaN         NaN
# 4                충청북도 영동군 심천면 난계로    충청북도  영동군        NaN   36.171270
# ...                             ...   ...  ...        ...         ...
# 92707       충청북도 충주시 수안보면 온천리 111-2  충청북도  충주시  36.845823  127.994736
# 92708       충청북도 충주시 수안보면 온천리 131-2  충청북도  충주시  36.845097  127.994223
# 92709        충청북도 충주시 수안보면 온천리 산2-3  충청북도  충주시  36.845238  127.999317
# 92710       충청북도 충주시 수안보면 안보리 산1-12  충청북도  충주시  36.845208  128.000003
# 92711       충청북도 충주시 수안보면 안보리 579-2  충청북도  충주시  36.844581  128.001291
#
#        install_cnt        date
# 0                1  2016-09-23
# 1                1  2016-09-23
# ...

# %%
df_chungb_2.state.unique()  # ['충청북도', '경상북도', '서울특별시']

# df_chungb_2.loc[~df_chungb_2.state.str.contains('서울특별시'), 'state'] = '서울특별시'
df_chungb_2[df_chungb_2['address'].str.startswith('경상북도')]  # 1개
df_chungb_2[df_chungb_2['address'].str.startswith('서울특별시')]  # 1개
df_chungb_2.drop([5252, 5253], axis=0, inplace=True)
df_chungb_2.state.unique()
# Out:
# array(['충청북도'], dtype=object)

# %% [markdown]
# ## 데이터 합치기 (서울 ~ 충청북도)

# %%
# [df_seoul_2, df_sejong_2, df_ulsan_2, df_incheon_2, df_jn_3, df_jb_2, df_jeju_2, df_chungn_2, df_chungb_2]
df_incheon_2.state.unique()
# Out:
# array(['인천광역시'], dtype=object)

# %%
df_sclight_2 = pd.concat([df_seoul_2, df_sejong_2, df_ulsan_2, df_incheon_2, df_jn_3, df_jb_2, df_jeju_2, df_chungn_2, df_chungb_2], ignore_index=True)
df_sclight_2
# Out:
#                         address  state city        lat        long  \
# 0             서울특별시 강남구 개포동 570  서울특별시  강남구  37.476065  127.067286
# 1           서울특별시 강남구 개포동 571-1  서울특별시  강남구  37.476065  127.067286
# 2           서울특별시 강남구 개포동 572-1  서울특별시  강남구  37.477803  127.065296
# 3           서울특별시 강남구 개포동 571-1  서울특별시  강남구  37.476065  127.067286
# 4             서울특별시 강남구 개포동 570  서울특별시  강남구  37.476065  127.067286
# ...                         ...    ...  ...        ...         ...
# 826147  충청북도 충주시 수안보면 온천리 111-2   충청북도  충주시  36.845823  127.994736
# 826148  충청북도 충주시 수안보면 온천리 131-2   충청북도  충주시  36.845097  127.994223
# 826149   충청북도 충주시 수안보면 온천리 산2-3   충청북도  충주시  36.845238  127.999317
# 826150  충청북도 충주시 수안보면 안보리 산1-12   충청북도  충주시  36.845208  128.000003
# 826151  충청북도 충주시 수안보면 안보리 579-2   충청북도  충주시  36.844581  128.001291
#
#         install_cnt        date
# 0                 1  2023-01-03
# 1                 1  2023-01-03
# 2                 1  2023-01-03
# ...

# %%
df_sclight_2.state.unique()
# Out:
# array(['서울특별시', nan, '세종특별자치시', '울산광역시', '인천광역시', '전라남도', '전라북도',
#        '제주특별자치도', '충청남도', '충청북도'], dtype=object)

# %%
df_sclight_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 826152 entries, 0 to 826151
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   address      826152 non-null  object
#  1   state        814150 non-null  object
#  2   city         814150 non-null  object
#  3   lat          690449 non-null  float64
#  4   long         695742 non-null  float64
#  5   install_cnt  826152 non-null  int64
#  6   date         826152 non-null  object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 44.1+ MB

# %% [markdown]
# ## 전체 데이터 오류 확인

# %%
df_sclight_2.isnull().sum()
# Out:
# address             0
# state           12002
# city            12002
# lat            135703
# long           130410
# install_cnt         0
# date                0
# dtype: int64

# %% [markdown]
# #### state 명 확인 및 지역 고윳값으로만 통일

# %%
# # city 결측값 인덱스 추출 (리스트로 저장)
# sclight2_city_null = df_sclight2.loc[df_sclight2['city'].isnull()].index.tolist()

# # lat 결측값 인덱스 추출 (리스트로 저장)
# sclight2_lat_null = df_sclight2.loc[df_sclight2['lat'].isnull()].index.tolist()

# # long 결측값 인덱스 추출 (리스트로 저장)
# sclight2_long_null = df_sclight2.loc[df_sclight2['long'].isnull()].index.tolist()

# # 위 3개의 결측값 인덱스 리스트를 딕셔너리로 만들기
# dict_sclight2_null = {'city': sclight2_city_null, 'lat': sclight2_lat_null, 'long': sclight2_long_null}
# dict_sclight2_null

# # 보기 좋게 출력
# import pprint
# pprint.pprint(dict_sclight2_null)

# %%
## 주소명 이상하게 들어가 있는 부분 찾기
df_sclight_2.state.value_counts()
df_sclight_2.state.unique().tolist()
# Out:
# ['서울특별시',
#  nan,
#  '세종특별자치시',
#  '울산광역시',
#  '인천광역시',
#  '전라남도',
#  '전라북도',
#  '제주특별자치도',
#  '충청남도',
#  '충청북도']

# %%
df_sclight_2.city.unique().tolist()
# Out:
# ['강남구',
#  '강동구',
#  '강북구',
#  '강서구',
#  '관악구',
#  '동작구',
#  '광진구',
#  '구로구',
#  '금천구',
#  '노원구',
#  '도봉구',
#  '마포구',
#  '서대문구',
#  '서대문구통일로39다길',
#  '서대문구통일로39길',
#  '서대문구통일로37나길34',
#  nan,
#  '서초구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '양천구',
#  '영등포구',
#  '용산구',
#  '종로구',
#  '중구',
#  '중랑구',
#  '금남면',
#  '부강면',
#  '소정면',
#  '연기면',
#  '연동면',
#  '연서면',
#  '장군면',
#  '전동면',
#  '전의면',
#  '조치원읍',
#  '남구',
#  '동구',
#  '북구',
#  '울주군',
#  '강화군',
#  '계양구',
#  '부평구',
#  '남동구',
#  '미추홀구',
#  '서구',
#  '연수구',
#  '강진군',
#  '곡성군',
#  '광양시',
#  '구례군',
#  '나주시',
#  '담양군',
#  '목포시',
#  '무안군',
#  '함평군',
#  '순천시',
#  '신안군',
#  '여수시',
#  '영광군',
#  '영암군',
#  '완도군',
#  '장성군',
#  '장흥군',
#  '장흥읍',
#  '용산면',
#  '진도군',
#  '해남군',
#  '화순군',
#  '고창군',
#  '공음면',
#  '군산시',
#  '익산시',
#  '김제시',
#  '남원시',
#  '무주군',
#  '부안군',
#  '정읍시',
#  '순창군',
#  '완주군',
#  '임실군',
#  '진안군',
#  '장수군',
#  '전주시',
#  '서귀포시',
#  '제주시',
#  '계룡시',
#  '공주시',
#  '금산군',
#  '논산시',
#  '당진시',
#  '보령시',
#  '부여군',
#  '서산시',
#  '운산면',
#  '아산시',
# ...

# %% [markdown]
# #### 위도 경도 관련 drop할 행 확인

# %%
df_sclight_2.columns
# Out:
# Index(['address', 'state', 'city', 'lat', 'long', 'install_cnt', 'date'], dtype='object')

# %%
df_sclight_2
# Out:
#                         address  state city        lat        long  \
# 0             서울특별시 강남구 개포동 570  서울특별시  강남구  37.476065  127.067286
# 1           서울특별시 강남구 개포동 571-1  서울특별시  강남구  37.476065  127.067286
# 2           서울특별시 강남구 개포동 572-1  서울특별시  강남구  37.477803  127.065296
# 3           서울특별시 강남구 개포동 571-1  서울특별시  강남구  37.476065  127.067286
# 4             서울특별시 강남구 개포동 570  서울특별시  강남구  37.476065  127.067286
# ...                         ...    ...  ...        ...         ...
# 826147  충청북도 충주시 수안보면 온천리 111-2   충청북도  충주시  36.845823  127.994736
# 826148  충청북도 충주시 수안보면 온천리 131-2   충청북도  충주시  36.845097  127.994223
# 826149   충청북도 충주시 수안보면 온천리 산2-3   충청북도  충주시  36.845238  127.999317
# 826150  충청북도 충주시 수안보면 안보리 산1-12   충청북도  충주시  36.845208  128.000003
# 826151  충청북도 충주시 수안보면 안보리 579-2   충청북도  충주시  36.844581  128.001291
#
#         install_cnt        date
# 0                 1  2023-01-03
# 1                 1  2023-01-03
# 2                 1  2023-01-03
# ...

# %% [markdown]
# ####  'city, state, lat, long' 경우의 수 제거

# %%
# 모두 없음
df_sclight_2[df_sclight_2['state'].isna() & df_sclight_2['city'].isna() & df_sclight_2['lat'].isna() & df_sclight_2['long'].isna()].info()
# 위도만 있음
df_sclight_2[df_sclight_2['state'].isna() & df_sclight_2['city'].isna() & df_sclight_2['lat'].notnull() & df_sclight_2['long'].isna()].info()
# 경도만 있음
df_sclight_2[df_sclight_2['state'].isna() & df_sclight_2['city'].isna() & df_sclight_2['lat'].isna() & df_sclight_2['long'].notnull()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1806 entries, 103825 to 394693
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   address      1806 non-null   object
#  1   state        0 non-null      object
#  2   city         0 non-null      object
#  3   lat          0 non-null      float64
#  4   long         0 non-null      float64
#  5   install_cnt  1806 non-null   int64
#  6   date         1806 non-null   object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 112.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28 entries, 104165 to 106367
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   address      28 non-null     object
#  1   state        0 non-null      object
#  2   city         0 non-null      object
#  3   lat          28 non-null     float64
#  4   long         0 non-null      float64
# ...

# %%
# ['city', 'state', 'lat', 'long']
# 경우의 수: [X X X X] [X X O X] [X X X O]
# --> 제거할 행의 인덱스를 저장해서 전체 데이터에서 제거해보자.

# 모두 없음
null_all = df_sclight_2[df_sclight_2['state'].isna() & df_sclight_2['city'].isna() & df_sclight_2['lat'].isna() & df_sclight_2['long'].isna()].index.tolist()
# 위도만 있음
notnull_lat = df_sclight_2[df_sclight_2['state'].isna() & df_sclight_2['city'].isna() & df_sclight_2['lat'].notnull() & df_sclight_2['long'].isna()].index.tolist()
# 경도만 있음
notnull_long = df_sclight_2[df_sclight_2['state'].isna() & df_sclight_2['city'].isna() & df_sclight_2['lat'].isna() & df_sclight_2['long'].notnull()].index.tolist()

# 정보 확인
len(null_all), len(notnull_lat), len(notnull_long)
# Out:
# (1806, 28, 21)

# %%
# 삭제할 행 인덱스 저장할 빈 리스트 생성
null_rows = null_all + notnull_lat + notnull_long

# 중복값 삭제
null_rows = list(set(null_rows))

# 정렬
null_rows.sort()

len(null_rows)
null_rows
# Out:
# [103825,
#  103859,
#  103861,
#  103866,
#  103871,
#  103877,
#  103894,
#  103948,
#  103978,
#  103979,
#  104103,
#  104105,
#  104112,
#  104115,
#  104116,
#  104122,
#  104124,
#  104162,
#  104165,
#  104226,
#  104232,
#  104361,
#  104377,
#  104382,
#  104384,
#  104385,
#  104386,
#  104388,
#  104391,
#  104393,
#  104394,
#  104395,
#  104396,
#  104397,
#  104398,
#  104399,
#  104400,
#  104401,
#  104402,
#  104403,
#  104404,
#  104405,
#  104406,
#  104407,
#  104408,
#  104409,
#  104410,
#  104411,
#  104412,
#  104413,
#  104414,
#  104415,
#  104416,
#  104417,
#  104418,
#  104419,
#  104420,
#  104421,
#  104422,
#  104423,
#  104424,
#  104425,
#  104426,
#  104427,
#  104428,
#  104429,
#  104430,
#  104431,
#  104432,
#  104433,
#  104434,
#  104435,
#  104436,
#  104437,
#  104438,
#  104439,
#  104440,
#  104441,
#  104442,
#  104443,
#  104444,
#  104445,
#  104446,
#  104447,
#  104448,
#  104449,
#  104450,
#  104451,
#  104452,
#  104453,
# ...

# %%
# 원래 데이터셋에서 삭제할 행 인데스로 제거하기
df_sclight2 = df_sclight_2.drop(null_rows, axis=0, inplace=False)
# index 초기화
df_sclight2 = df_sclight2.reset_index(drop=True)

# %%
# 최종본
df_sclight2
# Out:
#                         address  state city        lat        long  \
# 0             서울특별시 강남구 개포동 570  서울특별시  강남구  37.476065  127.067286
# 1           서울특별시 강남구 개포동 571-1  서울특별시  강남구  37.476065  127.067286
# 2           서울특별시 강남구 개포동 572-1  서울특별시  강남구  37.477803  127.065296
# 3           서울특별시 강남구 개포동 571-1  서울특별시  강남구  37.476065  127.067286
# 4             서울특별시 강남구 개포동 570  서울특별시  강남구  37.476065  127.067286
# ...                         ...    ...  ...        ...         ...
# 824292  충청북도 충주시 수안보면 온천리 111-2   충청북도  충주시  36.845823  127.994736
# 824293  충청북도 충주시 수안보면 온천리 131-2   충청북도  충주시  36.845097  127.994223
# 824294   충청북도 충주시 수안보면 온천리 산2-3   충청북도  충주시  36.845238  127.999317
# 824295  충청북도 충주시 수안보면 안보리 산1-12   충청북도  충주시  36.845208  128.000003
# 824296  충청북도 충주시 수안보면 안보리 579-2   충청북도  충주시  36.844581  128.001291
#
#         install_cnt        date
# 0                 1  2023-01-03
# 1                 1  2023-01-03
# 2                 1  2023-01-03
# ...

# %%
# 파일 저장
df_sclight2.to_csv("C:/Users/samsung/TIL/DS/project/miniPJ/01_pj/data/df_sclight2.csv", index=False, encoding='utf-8-sig')

# %%
df_sclight2.state.unique()
# Out:
# array(['서울특별시', nan, '세종특별자치시', '울산광역시', '인천광역시', '전라남도', '전라북도',
#        '제주특별자치도', '충청남도', '충청북도'], dtype=object)

# %%
df_sclight2.city.unique()
# Out:
# array(['강남구', '강동구', '강북구', '강서구', '관악구', '동작구', '광진구', '구로구', '금천구',
#        '노원구', '도봉구', '마포구', '서대문구', '서대문구통일로39다길', '서대문구통일로39길',
#        '서대문구통일로37나길34', nan, '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구',
#        '용산구', '종로구', '중구', '중랑구', '금남면', '부강면', '소정면', '연기면', '연동면',
#        '연서면', '장군면', '전동면', '전의면', '조치원읍', '남구', '동구', '북구', '울주군', '강화군',
#        '계양구', '부평구', '남동구', '미추홀구', '서구', '연수구', '강진군', '곡성군', '광양시',
#        '구례군', '나주시', '담양군', '목포시', '무안군', '함평군', '순천시', '신안군', '여수시',
#        '영광군', '영암군', '완도군', '장성군', '장흥군', '장흥읍', '용산면', '진도군', '해남군',
#        '화순군', '고창군', '공음면', '군산시', '익산시', '김제시', '남원시', '무주군', '부안군',
#        '정읍시', '순창군', '완주군', '임실군', '진안군', '장수군', '전주시', '서귀포시', '제주시',
#        '계룡시', '공주시', '금산군', '논산시', '당진시', '보령시', '부여군', '서산시', '운산면',
#        '아산시', '서천군', '예산군', '천안시', '청양군', '태안군', '홍성군', '영동군', '괴산군',
#        '단양군', '보은군', '옥천군', '음성군', '제천시', '증평군', '청주시', '충주시'],
#       dtype=object)

# %%
df_sclight2.info()
# df_sclight2[df_sclight2.state.isna()]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 824297 entries, 0 to 824296
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   address      824297 non-null  object
#  1   state        814150 non-null  object
#  2   city         814150 non-null  object
#  3   lat          690421 non-null  float64
#  4   long         695721 non-null  float64
#  5   install_cnt  824297 non-null  int64
#  6   date         824297 non-null  object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 44.0+ MB

# %% [markdown]
# ## 시도별 Group_by

# %%
# 보안등 개수 sum 필요
df_sclight2.install_cnt.unique()
# Out:
# array([   1,    2,    3,    6,    8,    5,    4,    7,    9,   16,   31,
#          24,   15,   10,   17,   22,   11,   20,   30,   59,   39,   12,
#          21,   19,   40,   42,  651,  689,  647,  704,  436,  617,  535,
#         560,  724, 1060,  667,  578,  833,  410,  858,  885,  480,  895,
#         643, 2231, 1378, 1151,  730,  794, 1180, 1160, 1034,  691,  836,
#         525,  350,    0,   13,   35,   76,  130,   43,  168,   78,   49,
#          23,   79,   64,   58,   25,   34,   56,   14,   28,   46,   98,
#          18,  219,   70,   65,   68,   88,   45,   47,   60,   37,   26,
#          29], dtype=int64)

# %%
# 데이터프레임 크기 조절
# pd.set_option('display.max.colwidth', 100)

df_sclight2.head()
# Out:
#                address  state city        lat        long  install_cnt  \
# 0    서울특별시 강남구 개포동 570  서울특별시  강남구  37.476065  127.067286            1
# 1  서울특별시 강남구 개포동 571-1  서울특별시  강남구  37.476065  127.067286            1
# 2  서울특별시 강남구 개포동 572-1  서울특별시  강남구  37.477803  127.065296            1
# 3  서울특별시 강남구 개포동 571-1  서울특별시  강남구  37.476065  127.067286            1
# 4    서울특별시 강남구 개포동 570  서울특별시  강남구  37.476065  127.067286            1
#
#          date
# 0  2023-01-03
# 1  2023-01-03
# 2  2023-01-03
# 3  2023-01-03
# 4  2023-01-03

# %%
# 시도/군구별 평균값 
df_sclight2.groupby(['state', 'city']).mean()
# Out:
# C:\Users\samsung\AppData\Local\Temp\ipykernel_17912\2600763840.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_sclight2.groupby(['state', 'city']).mean()
#                   lat        long  install_cnt
# state city
# 서울특별시 강남구   37.504638  127.046228     1.000098
#       강동구   37.542813  127.140163     1.000000
#       강북구   37.632728  127.021495     1.047012
#       강서구   37.549689  126.839589     1.002086
#       관악구   37.478536  126.937684     1.000000
# ...               ...         ...          ...
# 충청북도  음성군   36.972177  127.599888     1.042739
#       제천시         NaN         NaN     1.000333
#       증평군         NaN         NaN     1.000000
#       청주시   36.632170  127.474492     1.000000
#       충주시   36.996392  127.913774     1.060000
#
# [115 rows x 3 columns]

# %%
# 시도/군구별 
# ['lat', 'long']: 평균값
# ['install_cnt']: 합계

df_sclight2_StCi = df_sclight2.groupby(['state', 'city']).agg({
    'lat': 'mean',
    'long': 'mean',
    'install_cnt': 'sum'}).reset_index()

# df_sclight2_StCi.info()
df_sclight2_StCi
# Out:
#      state city        lat        long  install_cnt
# 0    서울특별시  강남구  37.504638  127.046228        10211
# 1    서울특별시  강동구  37.542813  127.140163         7534
# 2    서울특별시  강북구  37.632728  127.021495         9777
# 3    서울특별시  강서구  37.549689  126.839589         8646
# 4    서울특별시  관악구  37.478536  126.937684        12401
# ..     ...  ...        ...         ...          ...
# 110   충청북도  음성군  36.972177  127.599888        21397
# 111   충청북도  제천시        NaN         NaN         9024
# 112   충청북도  증평군        NaN         NaN         3869
# 113   충청북도  청주시  36.632170  127.474492        25432
# 114   충청북도  충주시  36.996392  127.913774        10600
#
# [115 rows x 5 columns]

# %% [markdown]
# ## EDA: 시도별 보안등 개수

# %% [markdown]
# ### Bar Graph

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib
# 한글 꺠짐 방지 
matplotlib.rcParams['font.family'] ='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
df_sclight2_StCi.columns
# Out:
# Index(['state', 'city', 'lat', 'long', 'install_cnt'], dtype='object')

# %% [markdown]
# - 참고: https://hleecaster.com/python-seaborn-color/

# %%
g_state = df_sclight2_StCi.groupby(['state'])['install_cnt'].sum().reset_index()
g_state
# Out:
#      state  install_cnt
# 0    서울특별시       186533
# 1  세종특별자치시         8029
# 2    울산광역시        32470
# 3    인천광역시        49065
# 4     전라남도       164749
# 5     전라북도       129963
# 6  제주특별자치도        33542
# 7     충청남도       151292
# 8     충청북도        94190

# %%
# import warnings
# # 경고 메시지를 무시하고 숨기기
# warnings.filterwarnings(action='ignore')
# 숨기기했던 경고 메시지를 다시 보이게
# warnings.filterwarnings(action='default')
colors = ['black','dimgray','dimgrey', 'grey','darkgray','silver','lightgray', 'lightgrey', 'gainsboro'] # 색상 지정

title_font = {
    'fontsize': 25,
    'fontweight': 'bold',
}

lable_font = {
    'fontsize': 15,
    'fontweight': 'bold',
    
}

plt.figure(figsize=(16,8))
plt.bar(g_state['state'], g_state['install_cnt'], color=colors)
plt.xlabel('시도명', fontdict=lable_font, labelpad=10)
plt.ylabel('보안등 개수', fontdict=lable_font, labelpad=10)
plt.title('시도별 보안등 개수 현황', fontdict=title_font, pad=30)
plt.grid(True,color='gray', alpha=0.3, linestyle='--')
# plt.rc('font', family="Malgun Gothic") #그래프 내부의 한글 깨짐 처리
plt.show()

# %%
sns.set(font='Malgun Gothic', rc={'axes.unicode_minus':False}, style='darkgrid')
# sns.set_theme(style='whitegrid')

# qualitative_colors = sns.color_palette("Set3", 10)
# sns.palplot(qualitative_colors)

sns.barplot(data=g_state,
            x='install_cnt', 
            y='state',
           orient='h',
           palette='BuGn',
           )
# Out:
# <AxesSubplot: xlabel='install_cnt', ylabel='state'>

# %% [markdown]
# ## (추가) EDA: 인구밀도 대비 보안등 개수

# %%
# 현재 작업 디렉토리 출력
print(os.getcwd())
# Out:
# C:\Users\samsung\TIL\DS\project\miniPJ\01_pj\data\rawdata\rawdata_보안등\rawdata\충청북도

# %%
# 작업 디렉토리 변경
os.chdir("C:/Users/samsung/TIL/DS/project/miniPJ/01_pj/data/rawdata/")

# %%
# 데이터 불러오기
df_pd = pd.read_csv('인구밀도.csv', encoding='cp949')
df_pd
# Out:
#     행정구역별    시점      데이터
# 0   서울특별시  2017  16095.8
# 1   서울특별시  2018  15983.7
# 2   서울특별시  2019  15926.9
# 3   서울특별시  2020  15839.0
# 4   서울특별시  2021  15650.1
# ..    ...   ...      ...
# 80    제주도  2017    346.9
# 81    제주도  2018    355.8
# 82    제주도  2019    359.4
# 83    제주도  2020    362.6
# 84    제주도  2021    363.8
#
# [85 rows x 3 columns]

# %%
# 변수명 변경
df_pd.rename(columns = {"행정구역별": "state", "시점": "year", "데이터": "pop_density" }, inplace = True)
df_pd.drop(['year'], axis=1, inplace=True)
df_pd
# Out:
#     state  pop_density
# 0   서울특별시      16095.8
# 1   서울특별시      15983.7
# 2   서울특별시      15926.9
# 3   서울특별시      15839.0
# 4   서울특별시      15650.1
# ..    ...          ...
# 80    제주도        346.9
# 81    제주도        355.8
# 82    제주도        359.4
# 83    제주도        362.6
# 84    제주도        363.8
#
# [85 rows x 2 columns]

# %%
df_pd.state.unique()
# Out:
# array(['서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시', '울산광역시',
#        '세종특별자치시', '경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도', '경상북도',
#        '경상남도', '제주도'], dtype=object)

# %%
# 시도별 5개년 평균 인구밀도
df_pd_group = df_pd.groupby(['state'], as_index=False).mean()
df_pd_group
# Out:
#       state  pop_density
# 0       강원도        90.36
# 1       경기도      1303.40
# 2      경상남도       316.54
# 3      경상북도       139.72
# 4     광주광역시      2964.74
# 5     대구광역시      2744.80
# 6     대전광역시      2781.58
# 7     부산광역시      4378.44
# 8     서울특별시     15899.10
# 9   세종특별자치시       708.64
# 10    울산광역시      1074.94
# 11    인천광역시      2765.64
# 12     전라남도       144.78
# 13     전라북도       224.08
# 14      제주도       357.70
# 15     충청남도       264.24
# 16     충청북도       219.20

# %%
# 시도별 5개년 평균 인구밀도 (최민정 파트 시도만 자르기)

df_pd_2 = df_pd_group.drop([0, 1, 2, 3, 4, 5, 6, 7], axis='rows').reset_index()
df_pd_2.drop('index', axis=1, inplace=True)
df_pd_2
# Out:
#      state  pop_density
# 0    서울특별시     15899.10
# 1  세종특별자치시       708.64
# 2    울산광역시      1074.94
# 3    인천광역시      2765.64
# 4     전라남도       144.78
# 5     전라북도       224.08
# 6      제주도       357.70
# 7     충청남도       264.24
# 8     충청북도       219.20

# %%
g_state.state.unique()
# Out:
# array(['서울특별시', '세종특별자치시', '울산광역시', '인천광역시', '전라남도', '전라북도', '제주특별자치도',
#        '충청남도', '충청북도'], dtype=object)

# %%
df_pd_2
# Out:
#      state  pop_density
# 0    서울특별시     15899.10
# 1  세종특별자치시       708.64
# 2    울산광역시      1074.94
# 3    인천광역시      2765.64
# 4     전라남도       144.78
# 5     전라북도       224.08
# 6      제주도       357.70
# 7     충청남도       264.24
# 8     충청북도       219.20

# %%
df_pd_2.loc[df_pd_2.state == '제주도', 'state'] = '제주특별자치도'
df_pd_2
# Out:
#      state  pop_density
# 0    서울특별시     15899.10
# 1  세종특별자치시       708.64
# 2    울산광역시      1074.94
# 3    인천광역시      2765.64
# 4     전라남도       144.78
# 5     전라북도       224.08
# 6  제주특별자치도       357.70
# 7     충청남도       264.24
# 8     충청북도       219.20

# %%
# 전처리한 데이터와 합치기
df_result = pd.merge(df_pd_2, g_state, how='outer', on='state')
df_result
# Out:
#      state  pop_density  install_cnt
# 0    서울특별시     15899.10       186533
# 1  세종특별자치시       708.64         8029
# 2    울산광역시      1074.94        32470
# 3    인천광역시      2765.64        49065
# 4     전라남도       144.78       164749
# 5     전라북도       224.08       129963
# 6  제주특별자치도       357.70        33542
# 7     충청남도       264.24       151292
# 8     충청북도       219.20        94190

# %%
# 인구밀도 대비 비상등 개수 비율 계산
df_result['cnt_density'] = round(df_result['install_cnt']/df_result['pop_density'], 2)

df_result
# Out:
#      state  pop_density  install_cnt  cnt_density
# 0    서울특별시     15899.10       186533        11.73
# 1  세종특별자치시       708.64         8029        11.33
# 2    울산광역시      1074.94        32470        30.21
# 3    인천광역시      2765.64        49065        17.74
# 4     전라남도       144.78       164749      1137.93
# 5     전라북도       224.08       129963       579.98
# 6  제주특별자치도       357.70        33542        93.77
# 7     충청남도       264.24       151292       572.56
# 8     충청북도       219.20        94190       429.70

# %%
## EDA

sns.set(font='Malgun Gothic', rc={'axes.unicode_minus':False}, style='darkgrid')
# sns.set_theme(style='whitegrid')

# qualitative_colors = sns.color_palette("Set3", 10)
# sns.palplot(qualitative_colors)

graph1 = sns.barplot(data=df_result,
            x='cnt_density', 
            y='state',
           orient='h',
           palette='PuBuGn',
            
           )

# graph1.set(xlabel = '인구밀도 대비 보안등 개수', ylabel = '시/도')

# %%
# EDA 비교차 위에꺼 그대로 가져왔음.

sns.set(font='Malgun Gothic', rc={'axes.unicode_minus':False}, style='darkgrid')
# sns.set_theme(style='whitegrid')

# qualitative_colors = sns.color_palette("Set3", 10)
# sns.palplot(qualitative_colors)

sns.barplot(data=g_state,
            x='install_cnt', 
            y='state',
           orient='h',
           palette='BuGn',
           )
# Out:
# <AxesSubplot: xlabel='install_cnt', ylabel='state'>

# %% [markdown]
# ### Folium 지도 시각화

# %% [markdown]
# # 위경도 있는 데이터만 저장
# # df_sclight_g = df_sclight2.dropna(subset=['lat', 'long'], inplace=False)
# df_sclight_g = df_sclight2.dropna(inplace=False)
# df_sclight_g = df_sclight_g.reset_index(drop=True)
# df_sclight_g.info()

# %% [markdown]
# # 라이브러리 설치
# # !pip install folium

# %% [markdown]
# # 라이브러리 호출
# import folium as g

# %% [markdown]
# # city, 위도, 경도 데이터만 따로 저장
# sclight_city = df_sclight_g['city']
# sclight_x = df_sclight_g['lat']
# sclight_y = df_sclight_g['long']

# %% [markdown]
# #지도의 중심을 지정하기 위해 위도와 경도의 평균 구하기
# mean_lat = df_sclight_g['lat'].mean()
# mean_long = df_sclight_g['long'].mean()
#
# print(mean_lat, mean_long)

# %% [markdown]
# ## 지도 띄우기
#
# # Map 함수에서 location으로 처음 화면이 나오는 부분 설정
# # zoom_start: 처음 지도를 봤을 때 확대 정도
# m = g.Map([mean_lat, mean_long], zoom_start = 9)

# %% [markdown]
# coords = []
#
# for i in range(len(df_sclight_g)):
#     x = sclight_x[i]
#     y = sclight_y[i]
#     coords.append([x, y])
#
# for i in range(len(coords)):
#     g.Circle(
#         location = coords[i],
#         radius = 50,
#         color = '#000000',
#         fill = 'crimson',
#     ).add_to(m)
#
# m.save('C:/Users/samsung/TIL/DS/project/miniPJ/01_pj/results/map.html')

# %% [markdown]
# # Case 2
#
# '''
# - x, y 좌표와 city를 받아서 dict 형태로 만들고
# - x, y 좌표를 QGIS 지도 좌표계에 맞게 변환 (to EPSG:3857)
# - 후에 point들을 .shp로 내보내기
# '''
#
# TRAN_4326_TO_3857 = Transformer.from_crs("EPSG:4326", "EPSG:3857")
#     # EPSG:3857좌표계로 변환
#     # "ESPG:3857"을 다른 좌표계로 바꾸면 무한하게 응용 가능
#
# points = []
# ttareung = []
#
# for i in range(len(df_sclight_g)): # 마지막 인덱스에 NaN이 존재해서 -1
#
#     idx = sclight_city[i]
#     x_coord = sclight_x[i]
#     y_coord = sclight_y[i]
#
#     xx, yy = TRAN_4326_TO_3857.transform(x_coord, y_coord) # 변환하는 과정
#     sclight_dict = {'ID': idx, 'x_coord': xx, 'y_coord': yy}
#
#     if i % 20 == 0:
#         print(f'{i}th station is working...')
#
#     points.append(point(xx, yy))
#     ttareung.append(sclight_dict)
#
# points = gpd.GeoDataFrame(geometry = points)
# points.to_file('C:/Users/samsung/TIL/DS/project/miniPJ/01_pj/results/tta_points.shp', driver="Shapefile")

# %%
# end-of-file

# %%
# 저장한 파일 불러오기 테스트
test = pd.read_csv('C:/Users/samsung/TIL/DS/project/miniPJ/01_pj/data/df_sclight2.csv')
test
# Out:
#                         address  state city        lat        long  \
# 0             서울특별시 강남구 개포동 570  서울특별시  강남구  37.476065  127.067286
# 1           서울특별시 강남구 개포동 571-1  서울특별시  강남구  37.476065  127.067286
# 2           서울특별시 강남구 개포동 572-1  서울특별시  강남구  37.477803  127.065296
# 3           서울특별시 강남구 개포동 571-1  서울특별시  강남구  37.476065  127.067286
# 4             서울특별시 강남구 개포동 570  서울특별시  강남구  37.476065  127.067286
# ...                         ...    ...  ...        ...         ...
# 824292  충청북도 충주시 수안보면 온천리 111-2   충청북도  충주시  36.845823  127.994736
# 824293  충청북도 충주시 수안보면 온천리 131-2   충청북도  충주시  36.845097  127.994223
# 824294   충청북도 충주시 수안보면 온천리 산2-3   충청북도  충주시  36.845238  127.999317
# 824295  충청북도 충주시 수안보면 안보리 산1-12   충청북도  충주시  36.845208  128.000003
# 824296  충청북도 충주시 수안보면 안보리 579-2   충청북도  충주시  36.844581  128.001291
#
#         install_cnt        date
# 0                 1  2023-01-03
# 1                 1  2023-01-03
# 2                 1  2023-01-03
# ...

# %%
# 파일 읽어오기 함수화

# %%
import os 
import glob
import pandas as pd
import numpy as np

folder_path = 'C:/Users/miinn/보안등'
files_path = 'C:/Users/miinn/보안등'
read_files = glob.glob(os.path.join(files_path, '*.csv'))
file_names = []
    
for files in read_files:
    file_names.append(files)
    
global file_names

# %%
def f_sclight1(x):
    
    np_array_values = []
    security_light = pd.read_csv(file_names[x], encoding = 'cp949', header= 0)
    np_array_values.append(security_light)
    merge_values = np.vstack(np_array_values)
    df_sclight1 = pd.DataFrame(merge_values)
    df_sclight1.columns = security_light.columns
    df_sclight1_1 = df_sclight1.drop(['보안등위치명', '설치연도', '설치형태', '관리기관전화번호', '관리기관명'], axis = 1)
    df_sclight1_1['주소'] = np.where(pd.notnull(df_sclight1_1['소재지지번주소'])==True, df_sclight1_1['소재지지번주소'], df_sclight1['소재지도로명주소'])
    df_sclight1_2 = df_sclight1_1.drop(['소재지도로명주소', '소재지지번주소'], axis = 1)
    df_sclight1_2 = df_sclight1_2[['주소', '위도', '경도', '설치개수', '데이터기준일자']]
    df_sclight1_2.rename(columns={'주소': 'address', '위도': 'lat', '경도':'long', '설치개수':'install_cnt', '데이터기준일자':'date'}, inplace=True)
    df_sclight1_2['state'] = df_sclight1_2['address'].str.split().str[0]
    df_sclight1_2['city'] = df_sclight1_2['address'].str.split().str[1]
    df_sclight1_2 = df_sclight1_2[['address', 'state', 'city', 'lat', 'long', 'install_cnt', 'date']]
    
    print(f'last page: {len(file_names)-1}')
    return pd.DataFrame(df_sclight1_2)

# %%
for i in range(len(file_names)):
    print(f_sclight1(i)['state'].unique())
# Out:
# last page: 114
# ['강원도']
# last page: 114
# ['강원도']
# last page: 114
# ['강원도']
# last page: 114
# ['강원도']
# last page: 114
# ['강원도']
# last page: 114
# ['강원도']
# last page: 114
# ['강원도']
# last page: 114
# ['강원도']
# last page: 114
# ['강원도' '강원' '경기']
# last page: 114
# ['강원도']
# last page: 114
# ['강원도']
# last page: 114
# ['강원도']
# last page: 114
# ['강원도']
# last page: 114
# ['강원도']
# last page: 114
# ['경기도']
# last page: 114
# ['경기도' '191224' '송산로174번길' '덕이로' '덕이로292번길' '신덕로2번길' '송산로334번길' '송산로266번길']
# last page: 114
# ['경기도']
# last page: 114
# ['경기도']
# last page: 114
# ['경기도']
# last page: 114
# ['경기도']
# last page: 114
# ['경기도']
# last page: 114
# ['경기도']
# last page: 114
# ['경기도']
# last page: 114
# ['경기도']
# last page: 114
# ['경기도']
# last page: 114
# ['경기도']
# last page: 114
# ['경기도' '권선구' '장안구']
# last page: 114
# ['경기도']
# last page: 114
# ['경기도']
# last page: 114
# ['경기도' '충청북도' '충청남도']
# last page: 114
# ['경기도']
# last page: 114
# ['경기도']
# last page: 114
# ['경기도']
# ...

# %% [markdown]
# ## 'state'가 잘못 들어간 아이들 추출 및 drop 진행

# %%
prob_list = [8, 15, 26, 29, 37, 40, 44, 48, 67, 72, 75, 79, 85, 87, 93, 109]

for i in prob_list:
    print(file_names[i])
# Out:
# C:/Users/miinn/보안등\강원도_철원군청_보안등정보_20211021_1634862601055_359608.csv
# C:/Users/miinn/보안등\경기도_고양시_보안등정보_20210927_1632975501220_1552009.csv
# C:/Users/miinn/보안등\경기도_수원시_보안등정보_20220527.csv
# C:/Users/miinn/보안등\경기도_안성시_보안등정보_20210315_1615815438485_2410370.csv
# C:/Users/miinn/보안등\경기도_의정부시_보안등정보_20220930.csv
# C:/Users/miinn/보안등\경기도_평택시_보안등정보_20220613.csv
# C:/Users/miinn/보안등\경상남도_거제시_보안등정보_20220719.csv
# C:/Users/miinn/보안등\경상남도_남해군_보안등정보_20220329_1648529076592_861886.csv
# C:/Users/miinn/보안등\경상북도_봉화군_보안등정보_20220527.csv
# C:/Users/miinn/보안등\경상북도_영양군_보안등정보_20201224_1608773990416_461155.csv
# C:/Users/miinn/보안등\경상북도_울진군_보안등정보_20221130.csv
# C:/Users/miinn/보안등\경상북도_포항시_보안등정보_20211007_1634115913168_2134153.csv
# C:/Users/miinn/보안등\대구광역시_남구_보안등정보_20220804.csv
# C:/Users/miinn/보안등\대구광역시_달성군_보안등정보_20220608.csv
# C:/Users/miinn/보안등\대전광역시_대덕구_보안등정보_20220614.csv
# C:/Users/miinn/보안등\부산광역시_서구_보안등정보_20220916.csv

# %%
prob_list = [8, 15, 26, 29, 37, 40, 44, 48, 67, 72, 75, 79, 85, 87, 93, 109]

for i in prob_list:
     print(f_sclight1(i)['state'].unique())
# Out:
# last page: 114
# ['강원도' '강원' '경기']
# last page: 114
# ['경기도' '191224' '송산로174번길' '덕이로' '덕이로292번길' '신덕로2번길' '송산로334번길' '송산로266번길']
# last page: 114
# ['경기도' '권선구' '장안구']
# last page: 114
# ['경기도' '충청북도' '충청남도']
# last page: 114
# ['경기도' '서울특별시']
# last page: 114
# ['경기도' '충청남도']
# last page: 114
# ['경상남도' '동부면' '둔덕면' '경남' '수월동' '거제시']
# last page: 114
# ['경상남도' '겅상남도' '경사남도']
# last page: 114
# ['경상북도' '강원도']
# last page: 114
# ['경상북도' '경북']
# last page: 114
# ['경상북도' '강원도']
# last page: 114
# ['경상북도' '신광면']
# last page: 114
# ['대구광역시' '대구']
# last page: 114
# ['대구광역시' '35.873161183' '대구']
# last page: 114
# ['대전광역시' '1684-7' '1695-5' '267-1' '267-3' '1694-3' '113-3' '장동209-32번지'
#  '487-6']
# last page: 114
# ['부산광역시' '부상광역시']

# %%
f_sclight1(8)[f_sclight1(8)['state']=='강원'].index
# Out:
# last page: 114
# last page: 114
# Int64Index([1494, 3740, 3747, 3748, 3749, 3750, 3751, 3752, 3755, 3757, 3773], dtype='int64')

# %%
f_sclight1(8).loc[[1494, 3740, 3747, 3748, 3749, 3750, 3751, 3752, 3755, 3757, 3773], :]['address'].str.replace('강원', '강원도')
# Out:
# last page: 114
# 1494          강원도 근남면 육단리 287-6
# 3740           강원도 철원읍 화지리 40-2
# 3747            강원도 철원읍 화지리 950
# 3748          강원도 철원읍 화지리 28-88
# 3749            강원도 철원읍 화지리 920
# 3750          강원도 철원읍 화지리 18-40
# 3751           강원도 철원읍 화지리 1023
# 3752    강원도 철원읍 화지리995(화지리1025)
# 3755            강원도 철원읍 화지리 925
# 3757          강원도 철원읍 화지리 48-83
# 3773           강원도 철원읍 화지리 95-3
# Name: address, dtype: object

# %%
f_sclight1(8)[f_sclight1(8)['state']=='경기'].dropna(inplace=True)
# Out:
# last page: 114
# last page: 114

# %%
f_df_sclight = f_sclight1(8).copy()
# Out:
# last page: 114

# %%
f_df_sclight.drop(1974,axis=0, inplace=True)

# %%
f_df_sclight[f_df_sclight['state']=='경기']
# Out:
# Empty DataFrame
# Columns: [address, state, city, lat, long, install_cnt, date]
# Index: []

# %%
f_sclight1(8)[f_sclight1(8)['state']=='경기']
# Out:
# last page: 114
# last page: 114
#                   address state city  lat long install_cnt        date
# 1974  경기 포천시 관인면 초과리 44-0    경기  포천시  NaN  NaN           1  2021-10-21

# %% [markdown]
# ## 강원도 ~ 부산광역시 파일 한번에 읽고 합치기

# %%
import os 
import glob
import pandas as pd
import numpy as np

folder_path = 'C:/Users/miinn/보안등'
files_path = 'C:/Users/miinn/보안등'
read_files = glob.glob(os.path.join(files_path, '*.csv'))

# %%
np_array_values = []
file_names = []
for files in read_files:
    security_light = pd.read_csv(files, encoding = 'cp949', header= 0)
    np_array_values.append(security_light)
    file_names.append(files)
#     print(files)

# %%
"""

import shutil
import os

src_folder = "보안등"
dst_folder = "보안등3"

files = file_names3
folders = file_names5

src_path_list = []

for file in files:
    src_path = os.path.join(src_folder, file) # 파일경로
    src_path_list.append(src_path)
    
src_path_list

"""
# Out:
# '\n\nimport shutil\nimport os\n\nsrc_folder = "보안등"\ndst_folder = "보안등3"\n\nfiles = file_names3\nfolders = file_names5\n\nsrc_path_list = []\n\nfor file in files:\n    src_path = os.path.join(src_folder, file) # 파일경로\n    src_path_list.append(src_path)\n    \nsrc_path_list\n\n'

# %%
"""
dst_path_list = []

for folder in folders:
    os.makedirs(os.path.join(dst_folder, folder), exist_ok=True) # 폴더 생성
    dst_path = os.path.join(dst_folder, folder) #이동폴더경로
    dst_path_list.append(dst_path)
    
    
for i in range(len(src_path_list)):
    shutil.copy(src_path_list[i], dst_path_list[i])
"""
# Out:
# '\ndst_path_list = []\n\nfor folder in folders:\n    os.makedirs(os.path.join(dst_folder, folder), exist_ok=True) # 폴더 생성\n    dst_path = os.path.join(dst_folder, folder) #이동폴더경로\n    dst_path_list.append(dst_path)\n    \n    \nfor i in range(len(src_path_list)):\n    shutil.copy(src_path_list[i], dst_path_list[i])\n'

# %%
security_light.columns
# Out:
# Index(['보안등위치명', '설치개수', '소재지도로명주소', '소재지지번주소', '위도', '경도', '설치연도', '설치형태',
#        '관리기관전화번호', '관리기관명', '데이터기준일자'],
#       dtype='object')

# %%
np_array_values[0]
# Out:
#        보안등위치명  설치개수 소재지도로명주소             소재지지번주소         위도          경도  설치연도  \
# 0        강남동1     1      NaN   강원도 강릉시 장현동 463-1  37.728580  128.887487   NaN
# 1        강남동2     1      NaN    강원도 강릉시 장현동 40-1  37.732262  128.900575   NaN
# 2        강남동3     1      NaN    강원도 강릉시 장현동 97-2  37.730126  128.900761   NaN
# 3        강남동4     1      NaN    강원도 강릉시 담산동 55-1  37.717822  128.904406   NaN
# 4        강남동5     1      NaN    강원도 강릉시 담산동 55-1  37.717822  128.904406   NaN
# ...       ...   ...      ...                 ...        ...         ...   ...
# 12248  홍제동398     1      NaN   강원도 강릉시 홍제동 921-3  37.747866  128.858246   NaN
# 12249  홍제동399     1      NaN     강원도 강릉시 홍제동 606        NaN         NaN   NaN
# 12250  홍제동400     1      NaN  강원도 강릉시 홍제동 산249-1        NaN         NaN   NaN
# 12251  홍제동401     1      NaN   강원도 강릉시 홍제동 481-1        NaN         NaN   NaN
# 12252  홍제동402     1      NaN   강원도 강릉시 홍제동 96-37        NaN         NaN   NaN
#
# ...

# %%
merge_values = np.vstack(np_array_values)
security_light_data = pd.DataFrame(merge_values)
security_light_data.columns = security_light.columns
security_light_data
# Out:
#          보안등위치명 설치개수                   소재지도로명주소                소재지지번주소  \
# 0          강남동1    1                        NaN      강원도 강릉시 장현동 463-1
# 1          강남동2    1                        NaN       강원도 강릉시 장현동 40-1
# 2          강남동3    1                        NaN       강원도 강릉시 장현동 97-2
# 3          강남동4    1                        NaN       강원도 강릉시 담산동 55-1
# 4          강남동5    1                        NaN       강원도 강릉시 담산동 55-1
# ...         ...  ...                        ...                    ...
# 874257      한전주    1       부산광역시 해운대구 좌동순환로 387                    NaN
# 874258  전용주(강관)    1       부산광역시 해운대구 좌동순환로 387                    NaN
# 874259      벽부주    1       부산광역시 해운대구 좌동순환로 379                    NaN
# 874260  전용주(강관)    1                        NaN  부산광역시 해운대구 중동 1520-17
# 874261  전용주(강관)    1  부산광역시 해운대구 우동2로32번길 43-17                    NaN
#
#                위도          경도 설치연도 설치형태      관리기관전화번호            관리기관명  \
# ...

# %% [markdown]
# ## 필요없는 컬럼 drop ['보안등위치명', '설치연도', '설치형태', '관리기관전화번호', '관리기관명']

# %%
security_light_clean = security_light_data.drop(['보안등위치명', '설치연도', '설치형태', '관리기관전화번호', '관리기관명'], axis = 1)

# %% [markdown]
# ## 지번주소가 없을땐 도로명주소를 참고하여 합친 새로운 '주소' 컬럼 생성

# %%
security_light_clean['주소'] = np.where(pd.notnull(security_light_clean['소재지지번주소'])==True, security_light_clean['소재지지번주소'], security_light_clean['소재지도로명주소'])
security_light_clean
# Out:
#        설치개수                   소재지도로명주소                소재지지번주소         위도  \
# 0         1                        NaN      강원도 강릉시 장현동 463-1   37.72858
# 1         1                        NaN       강원도 강릉시 장현동 40-1  37.732262
# 2         1                        NaN       강원도 강릉시 장현동 97-2  37.730126
# 3         1                        NaN       강원도 강릉시 담산동 55-1  37.717822
# 4         1                        NaN       강원도 강릉시 담산동 55-1  37.717822
# ...     ...                        ...                    ...        ...
# 874257    1       부산광역시 해운대구 좌동순환로 387                    NaN    35.1623
# 874258    1       부산광역시 해운대구 좌동순환로 387                    NaN    35.1623
# 874259    1       부산광역시 해운대구 좌동순환로 379                    NaN  35.162776
# 874260    1                        NaN  부산광역시 해운대구 중동 1520-17  35.163319
# 874261    1  부산광역시 해운대구 우동2로32번길 43-17                    NaN  35.169074
#
#                 경도     데이터기준일자                         주소
# ...

# %%
security_light_clean
# Out:
#        설치개수                   소재지도로명주소                소재지지번주소         위도  \
# 0         1                        NaN      강원도 강릉시 장현동 463-1   37.72858
# 1         1                        NaN       강원도 강릉시 장현동 40-1  37.732262
# 2         1                        NaN       강원도 강릉시 장현동 97-2  37.730126
# 3         1                        NaN       강원도 강릉시 담산동 55-1  37.717822
# 4         1                        NaN       강원도 강릉시 담산동 55-1  37.717822
# ...     ...                        ...                    ...        ...
# 874257    1       부산광역시 해운대구 좌동순환로 387                    NaN    35.1623
# 874258    1       부산광역시 해운대구 좌동순환로 387                    NaN    35.1623
# 874259    1       부산광역시 해운대구 좌동순환로 379                    NaN  35.162776
# 874260    1                        NaN  부산광역시 해운대구 중동 1520-17  35.163319
# 874261    1  부산광역시 해운대구 우동2로32번길 43-17                    NaN  35.169074
#
#                 경도     데이터기준일자                         주소
# ...

# %%
security_light_clean.isna().sum() # 10개는 둘다 없는것 - 날려야함
# Out:
# 설치개수             0
# 소재지도로명주소    525507
# 소재지지번주소      57969
# 위도          134401
# 경도          134752
# 데이터기준일자          0
# 주소              10
# dtype: int64

# %%
df_sclight1 = security_light_clean.drop(['소재지도로명주소', '소재지지번주소'], axis = 1)

# %%
df_sclight1.isna().sum()
# Out:
# 설치개수            0
# 위도         134401
# 경도         134752
# 데이터기준일자         0
# 주소             10
# dtype: int64

# %%
df_sclight1
# Out:
#        설치개수         위도          경도     데이터기준일자                         주소
# 0         1   37.72858  128.887487  2022-07-20          강원도 강릉시 장현동 463-1
# 1         1  37.732262  128.900575  2022-07-20           강원도 강릉시 장현동 40-1
# 2         1  37.730126  128.900761  2022-07-20           강원도 강릉시 장현동 97-2
# 3         1  37.717822  128.904406  2022-07-20           강원도 강릉시 담산동 55-1
# 4         1  37.717822  128.904406  2022-07-20           강원도 강릉시 담산동 55-1
# ...     ...        ...         ...         ...                        ...
# 874257    1    35.1623  129.178351  2022-06-02       부산광역시 해운대구 좌동순환로 387
# 874258    1    35.1623  129.178351  2022-06-02       부산광역시 해운대구 좌동순환로 387
# 874259    1  35.162776  129.179117  2022-06-02       부산광역시 해운대구 좌동순환로 379
# 874260    1  35.163319  129.179676  2022-06-02      부산광역시 해운대구 중동 1520-17
# 874261    1  35.169074  129.159843  2022-06-02  부산광역시 해운대구 우동2로32번길 43-17
#
# [874262 rows x 5 columns]

# %%
df_sclight1.loc[df_sclight1['주소'].isnull()] # 도로가 없는 데이터는 위도, 경도가 모두 있으므로 살림
# Out:
#        설치개수         위도          경도     데이터기준일자   주소
# 286646    1  37.322221  127.098055  2019-07-11  NaN
# 286649    1  37.347595  127.074637  2019-07-11  NaN
# 286653    1  37.352356  127.051022  2019-07-11  NaN
# 286654    1  37.347878  127.075029  2019-07-11  NaN
# 286655    1  37.352292  127.050989  2019-07-11  NaN
# 286656    1  37.352541  127.061822  2019-07-11  NaN
# 287211    1  37.344997  127.061633  2019-07-11  NaN
# 287472    1  37.309964  127.076666  2019-07-11  NaN
# 287558    1  37.319594  127.056815  2019-07-11  NaN
# 287695    1   37.33267  127.057069  2019-07-11  NaN

# %%
df_sclight1 = df_sclight1[['주소', '위도', '경도', '설치개수', '데이터기준일자']]
df_sclight1
# Out:
#                                주소         위도          경도 설치개수     데이터기준일자
# 0               강원도 강릉시 장현동 463-1   37.72858  128.887487    1  2022-07-20
# 1                강원도 강릉시 장현동 40-1  37.732262  128.900575    1  2022-07-20
# 2                강원도 강릉시 장현동 97-2  37.730126  128.900761    1  2022-07-20
# 3                강원도 강릉시 담산동 55-1  37.717822  128.904406    1  2022-07-20
# 4                강원도 강릉시 담산동 55-1  37.717822  128.904406    1  2022-07-20
# ...                           ...        ...         ...  ...         ...
# 874257       부산광역시 해운대구 좌동순환로 387    35.1623  129.178351    1  2022-06-02
# 874258       부산광역시 해운대구 좌동순환로 387    35.1623  129.178351    1  2022-06-02
# 874259       부산광역시 해운대구 좌동순환로 379  35.162776  129.179117    1  2022-06-02
# 874260      부산광역시 해운대구 중동 1520-17  35.163319  129.179676    1  2022-06-02
# 874261  부산광역시 해운대구 우동2로32번길 43-17  35.169074  129.159843    1  2022-06-02
#
# [874262 rows x 5 columns]

# %% [markdown]
# ## df_sclight1 컬럼명 영문 변환

# %%
df_sclight1.rename(columns={'주소': 'address', '위도': 'lat', '경도':'long', '설치개수':'install_cnt', '데이터기준일자':'date'}, inplace=True)

# %%
df_sclight1['state'] = df_sclight1['address'].str.split().str[0]
df_sclight1['city'] = df_sclight1['address'].str.split().str[1]

# %%
df_sclight1 = df_sclight1[['address', 'state', 'city', 'lat', 'long', 'install_cnt', 'date']]
df_sclight1
# Out:
#                           address  state  city        lat        long  \
# 0               강원도 강릉시 장현동 463-1    강원도   강릉시   37.72858  128.887487
# 1                강원도 강릉시 장현동 40-1    강원도   강릉시  37.732262  128.900575
# 2                강원도 강릉시 장현동 97-2    강원도   강릉시  37.730126  128.900761
# 3                강원도 강릉시 담산동 55-1    강원도   강릉시  37.717822  128.904406
# 4                강원도 강릉시 담산동 55-1    강원도   강릉시  37.717822  128.904406
# ...                           ...    ...   ...        ...         ...
# 874257       부산광역시 해운대구 좌동순환로 387  부산광역시  해운대구    35.1623  129.178351
# 874258       부산광역시 해운대구 좌동순환로 387  부산광역시  해운대구    35.1623  129.178351
# 874259       부산광역시 해운대구 좌동순환로 379  부산광역시  해운대구  35.162776  129.179117
# 874260      부산광역시 해운대구 중동 1520-17  부산광역시  해운대구  35.163319  129.179676
# 874261  부산광역시 해운대구 우동2로32번길 43-17  부산광역시  해운대구  35.169074  129.159843
#
#        install_cnt        date
# 0                1  2022-07-20
# 1                1  2022-07-20
# ...

# %% [markdown]
# ## city, lat, long 하나만 있는 경우 혹은 둘다 없는 경우 모두 drop

# %%
df_sclight1.isna().sum()
# Out:
# address            10
# state              10
# city               24
# lat            134401
# long           134752
# install_cnt         0
# date                0
# dtype: int64

# %%
df_sclight1_check = df_sclight1.loc[df_sclight1['city'].isnull()]

# %%
nolat_index = df_sclight1_check.loc[df_sclight1_check['lat'].isnull()].index
nolat_index
# Out:
# Int64Index([97724, 98471, 98488, 98532, 98653, 98740, 744600, 744601, 744605,
#             744607],
#            dtype='int64')

# %%
nolong_index = df_sclight1_check.loc[df_sclight1_check['long'].isnull()].index
nolong_index
# Out:
# Int64Index([97724, 98471, 98488, 98532, 98653, 98740, 744600, 744601, 744605,
#             744607],
#            dtype='int64')

# %%
df_sclight1.drop([86933,  87001,  87089,  97724,  98471,  98488,  98532,  98653,
             98740, 744600, 744601, 744605, 744607, 86903,  86952,  87096], axis =0, inplace = True)
# Out:
# C:\Users\miinn\AppData\Local\Temp\ipykernel_30260\2739583584.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sclight1.drop([86933,  87001,  87089,  97724,  98471,  98488,  98532,  98653,

# %%
df_sclight1.loc[df_sclight1['city'].isnull() & df_sclight1['address'].isnull()]
# Out:
#        address state city        lat        long install_cnt        date
# 286646     NaN   NaN  NaN  37.322221  127.098055           1  2019-07-11
# 286649     NaN   NaN  NaN  37.347595  127.074637           1  2019-07-11
# 286653     NaN   NaN  NaN  37.352356  127.051022           1  2019-07-11
# 286654     NaN   NaN  NaN  37.347878  127.075029           1  2019-07-11
# 286655     NaN   NaN  NaN  37.352292  127.050989           1  2019-07-11
# 286656     NaN   NaN  NaN  37.352541  127.061822           1  2019-07-11
# 287211     NaN   NaN  NaN  37.344997  127.061633           1  2019-07-11
# 287472     NaN   NaN  NaN  37.309964  127.076666           1  2019-07-11
# 287558     NaN   NaN  NaN  37.319594  127.056815           1  2019-07-11
# 287695     NaN   NaN  NaN   37.33267  127.057069           1  2019-07-11

# %%
df_sclight1.loc[df_sclight1['lat'].isnull() & df_sclight1['long'].isnull()]
# Out:
#                      address  state city  lat long install_cnt        date
# 5          강원도 강릉시 담산동 322-3    강원도  강릉시  NaN  NaN           1  2022-07-20
# 6            강원도 강릉시 박월동 370    강원도  강릉시  NaN  NaN           1  2022-07-20
# 13         강원도 강릉시 노암동 217-1    강원도  강릉시  NaN  NaN           1  2022-07-20
# 21           강원도 강릉시 장현동 224    강원도  강릉시  NaN  NaN           1  2022-07-20
# 22           강원도 강릉시 장현동 282    강원도  강릉시  NaN  NaN           1  2022-07-20
# ...                      ...    ...  ...  ...  ...         ...         ...
# 858027   부산광역시 서구 토성동5가 19-1  부산광역시   서구  NaN  NaN           1  2022-09-16
# 858028   부산광역시 서구 토성동5가 38-1  부산광역시   서구  NaN  NaN           1  2022-09-16
# 858029   부산광역시 서구 토성동5가 39-7  부산광역시   서구  NaN  NaN           1  2022-09-16
# 858030   부산광역시 서구 토성동5가 48-3  부산광역시   서구  NaN  NaN           1  2022-09-16
# 858031  부산광역시 서구 토성동5가 57-13  부산광역시   서구  NaN  NaN           1  2022-09-16
#
# [132207 rows x 7 columns]

# %%
df_sclight1.loc[df_sclight1['lat'].isnull() & df_sclight1['long'].isnull() & df_sclight1['address'].isnull()]
# Out:
# Empty DataFrame
# Columns: [address, state, city, lat, long, install_cnt, date]
# Index: []

# %%
df_sclight1.loc[df_sclight1['city'].isnull()]
# Out:
#              address         state city        lat        long install_cnt  \
# 286646           NaN           NaN  NaN  37.322221  127.098055           1
# 286649           NaN           NaN  NaN  37.347595  127.074637           1
# 286653           NaN           NaN  NaN  37.352356  127.051022           1
# 286654           NaN           NaN  NaN  37.347878  127.075029           1
# 286655           NaN           NaN  NaN  37.352292  127.050989           1
# 286656           NaN           NaN  NaN  37.352541  127.061822           1
# 287211           NaN           NaN  NaN  37.344997  127.061633           1
# 287472           NaN           NaN  NaN  37.309964  127.076666           1
# 287558           NaN           NaN  NaN  37.319594  127.056815           1
# 287695           NaN           NaN  NaN   37.33267  127.057069           1
# 689475  35.873161183  35.873161183  NaN  35.873006  128.498271           1
# ...

# %%
df_sclight1[df_sclight1['city']=='가평군']
# Out:
#                       address state city        lat        long install_cnt  \
# 77987    경기도 가평군 조종면 현리 491-2   경기도  가평군  37.807959  127.353412           1
# 77988   경기도 가평군 조종면 현리 483-11   경기도  가평군  37.808687  127.353019           1
# 77989   경기도 가평군 조종면 현리 477-35   경기도  가평군   37.80923  127.352399           1
# 77990  경기도 가평군 가평읍 읍내리 496-12   경기도  가평군  37.830829  127.511255           1
# 77991   경기도 가평군 가평읍 읍내리 337-1   경기도  가평군  37.828171   127.51289           1
# ...                       ...   ...  ...        ...         ...         ...
# 87106    경기도 가평군 북면 백둔리 산90-1   경기도  가평군  37.910919  127.472228           1
# 87107    경기도 가평군 북면 소법리 563-1   경기도  가평군  37.892497  127.547572           1
# 87108    경기도 가평군 북면 소법리 542-3   경기도  가평군   37.89556  127.550562           1
# 87109       경기도 가평군 북면 소법리 72   경기도  가평군  37.911466  127.564362           1
# 87110   경기도 가평군 북면 화악리 794-23   경기도  가평군   37.93703  127.543055           1
#
#              date
# 77987  2021-08-24
# ...

# %% [markdown]
# ## NGD를 통한 전처리

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
df_sclight1.drop(45781,axis=0, inplace=True) # 강원도 데이터에 있는 경기도 데이터 제거
df_sclight1.drop(97721,axis=0, inplace=True) # 주소 불분명 (대산전기) 제거
df_sclight1.drop(294640,axis=0, inplace=True) # 경기도 의정부시에 있는 서울특별시 데이터 제거
df_sclight1.drop(744603,axis=0, inplace=True) # 대전광역시_대덕구에 있는 주소 불분명 (267-1) 제거
df_sclight1.drop(744604,axis=0, inplace=True) # 대전광역시_대덕구에 있는 주소 불분명 (267-1) 제거
df_sclight1.loc[df_sclight1['state']=='강원', 'address'] = df_sclight1.loc[df_sclight1['state']=='강원', 'address'].str.replace("강원", '강원도')
df_sclight1.loc[df_sclight1['state']=='겅상남도', 'address'] = df_sclight1.loc[df_sclight1['state']=='겅상남도', 'address'].str.replace("겅상남도", '경상남도')
df_sclight1.loc[df_sclight1['state']=='경사남도', 'address'] = df_sclight1.loc[df_sclight1['state']=='경사남도', 'address'].str.replace("경사남도", '경상남도')
df_sclight1.loc[df_sclight1['state']=='부상광역시', 'address'] = df_sclight1.loc[df_sclight1['state']=='부상광역시', 'address'].str.replace("부상광역시", '부산광역시')
df_sclight1.loc[df_sclight1['state']=='경북', 'address'] = df_sclight1.loc[df_sclight1['state']=='경북', 'address'].str.replace("경북", '경상북도')
df_sclight1.loc[df_sclight1['state']=='경남', 'address'] = df_sclight1.loc[df_sclight1['state']=='경남', 'address'].str.replace("경남", '경상남도')
df_sclight1.loc[df_sclight1['state']=='대구', 'address'] = df_sclight1.loc[df_sclight1['state']=='대구', 'address'].str.replace("대구", '대구광역시')
df_sclight1.loc[df_sclight1['state']=='권선구', 'address'] = df_sclight1.loc[df_sclight1['state']=='권선구', 'address'].str.replace("권선구", '경기도 수원시 권선구')
df_sclight1.loc[df_sclight1['state']=='장안구', 'address'] = df_sclight1.loc[df_sclight1['state']=='장안구', 'address'].str.replace("장안구", '경기도 수원시 장안구')
df_sclight1.loc[df_sclight1['state']=='거제시', 'address'] = df_sclight1.loc[df_sclight1['state']=='거제시', 'address'].str.replace("거제시", '경상남도 거제시')
df_sclight1.loc[df_sclight1['state']=='덕이로', 'address'] = df_sclight1.loc[df_sclight1['state']=='덕이로', 'address'].str.replace("덕이로", '경기도 고양시 덕이로')
df_sclight1.loc[df_sclight1['state']=='동부면', 'address'] = df_sclight1.loc[df_sclight1['state']=='동부면', 'address'].str.replace("동부면", '경상남도 거제시 동부면')
df_sclight1.loc[df_sclight1['state']=='둔덕면', 'address'] = df_sclight1.loc[df_sclight1['state']=='둔덕면', 'address'].str.replace("둔덕면", '경상남도 거제시 둔덕면')
df_sclight1.loc[df_sclight1['state']=='수월동', 'address'] = df_sclight1.loc[df_sclight1['state']=='수월동', 'address'].str.replace("수월동", '경상남도 거제시 수월동')
df_sclight1.loc[df_sclight1['state']=='신광면', 'address'] = df_sclight1.loc[df_sclight1['state']=='신광면', 'address'].str.replace("신광면", '경상북도 포항시 신광면')
df_sclight1.loc[df_sclight1['state']=='장동209-32번지', 'address'] = df_sclight1.loc[df_sclight1['state']=='장동209-32번지', 'address'].str.replace("장동209-32번지", '대전광역시 대덕구 장동 209-32')
df_sclight1.loc[df_sclight1['city']=='경상남도', 'address'] = df_sclight1.loc[df_sclight1['city']=='경상남도', 'address'].str.replace('경상남도 경상남도 거제시', '경상남도 거제시')
df_sclight1.loc[df_sclight1['city']=='시흥시군자동561-1', 'address'] = df_sclight1.loc[df_sclight1['city']=='시흥시군자동561-1', 'address'].str.replace('시흥시군자동561-1', '시흥시 군자동 561-1')
df_sclight1.loc[df_sclight1['city']=='양주시광적면', 'address'] = df_sclight1.loc[df_sclight1['city']=='양주시광적면', 'address'].str.replace('양주시광적면', '양주시 광적면')
df_sclight1.loc[df_sclight1['city']=='거제시상동동', 'address'] = df_sclight1.loc[df_sclight1['city']=='거제시상동동', 'address'].str.replace('거제시상동동', '거제시 상동동')
df_sclight1.loc[df_sclight1['city']=='거제시연초면', 'address'] = df_sclight1.loc[df_sclight1['city']=='거제시연초면', 'address'].str.replace('거제시연초면', '거제시 연초면')
df_sclight1.loc[df_sclight1['city']=='남햄군', 'address'] = df_sclight1.loc[df_sclight1['city']=='남햄군', 'address'].str.replace('남햄군', '남해군')
df_sclight1.loc[df_sclight1['city']=='달성군유가읍', 'address'] = df_sclight1.loc[df_sclight1['city']=='달성군유가읍', 'address'].str.replace('달성군유가읍', '달성군 유가읍')
df_sclight1.loc[df_sclight1['city']=='유성궁', 'address'] = df_sclight1.loc[df_sclight1['city']=='유성궁', 'address'].str.replace('유성궁', '유성군')
df_sclight1.loc[df_sclight1['city']=='해운대구좌동', 'address'] = df_sclight1.loc[df_sclight1['city']=='해운대구좌동', 'address'].str.replace('해운대구좌동', '해운대구 좌동')

# %%
df_sclight1['state'] = df_sclight1['address'].str.split().str[0]
df_sclight1['city'] = df_sclight1['address'].str.split().str[1]

# %%
df_sclight1['state'].unique()
# Out:
# array(['강원도', '경기도', '충청북도', '충청남도', nan, '경상남도', '경상북도', '광주광역시',
#        '대구광역시', '35.873161183', '대전광역시', '113-3', '487-6', '부산광역시'],
#       dtype=object)

# %%
df_sclight1[df_sclight1['state']=='충청남도']
# Out:
#                            address state city        lat        long  \
# 212039  충청남도 천안시 서북구 입장면 연곡리 204-1  충청남도  천안시  36.953348  127.189561
# 215156  충청남도 천안시 서북구 입장면 도림리 산20-6  충청남도  천안시  36.906394  127.278579
# 215565  충청남도 천안시 서북구 입장면 도림리 54-15  충청남도  천안시  36.914114  127.261631
# 222039  충청남도 천안시 서북구 입장면 연곡리 204-1  충청남도  천안시  36.953348  127.189561
# 225156  충청남도 천안시 서북구 입장면 도림리 산20-6  충청남도  천안시  36.906394  127.278579
# 225565  충청남도 천안시 서북구 입장면 도림리 54-15  충청남도  천안시  36.914114  127.261631
# 319409     충청남도 아산시 둔포면 둔포리 494-13  충청남도  아산시  36.930092  127.034798
# 320083  충청남도 천안시 서북구 성환읍 와룡리 30-12  충청남도  천안시  36.957108  127.096519
# 320084   충청남도 천안시 서북구 성환읍 와룡리 25-4  충청남도  천안시  36.957916  127.096596
# 320085   충청남도 천안시 서북구 성환읍 와룡리 25-4  충청남도  천안시  36.958294  127.096611
# 320578     충청남도 천안시 서북구 성환읍 와룡리 24  충청남도  천안시  36.959393  127.096428
#
#        install_cnt        date
# 212039           1  2021-03-15
# 215156           1  2021-03-15
# 215565           1  2021-03-15
# ...

# %%
df_sclight1['city'].unique()
# Out:
# array(['강릉시', '동해시', '삼척시', '속초시', '양구군', '양양군', '원주시', '인제군', '철원군',
#        '근남면', '철원읍', '춘천시', '태백시', '평창군', '홍천군', '횡성군', '가평군', '고양시',
#        '파주시', '과천시', '광명시', '광주시', '구리시', '군포시', '김포시', '남양주시', '동두천시',
#        '부천시', '성남시', '수원시', '용인시', '시흥시', '안산시', '안성시', '평택시', '진천군',
#        '천안시', '양주시', '의정부시', '양평군', '여주시', '연천군', '오산시', '화성시', nan,
#        '의왕시', '이천시', '아산시', '포천시', '하남시', '거제시', '거제면', '거창군', '고성군',
#        '김해시', '창원시', '진영읍', '남해군', '밀양시', '산청군', '양산시', '의령군', '진주시',
#        '창녕군', '통영시', '하동군', '함안군', '함양군', '합천군', '경산시', '경주시', '구미시',
#        '군위군', '김천시', '문경시', '봉화군', '영월군', '울진군', '영양군', '안동시', '상주시',
#        '성주군', '안막동', '영덕군', '영천시', '예천군', '청도군', '청송군', '칠곡군', '포항시',
#        '광산구', '남구', '동구', '북구', '서구', '달서구', '달성군', '수성구', '중구', '대덕구',
#        '유성구', '유성군', '강서구', '금정구', '기장군', '동래구', '부산진구', '사상구', '사하구',
#        '수영구', '연제구', '영도구', '해운대구'], dtype=object)

# %% [markdown]
# ## 인구 밀도 데이터 확인 및 state별 평균인구밀도 집계

# %%
df_pop1 = pd.read_csv('./인구밀도.csv', encoding = 'cp949')

# %%
df_pop1_mean = df_pop1.groupby(['행정구역별'], as_index=False).mean()

# %%
df_pop1_mean.drop('시점', axis=1, inplace = True)

# %%
df_pop1_mean.rename(columns={'데이터':'인구밀도평균'}, inplace=True)

# %%
df_pop1
# Out:
#     행정구역별    시점      데이터
# 0   서울특별시  2017  16095.8
# 1   서울특별시  2018  15983.7
# 2   서울특별시  2019  15926.9
# 3   서울특별시  2020  15839.0
# 4   서울특별시  2021  15650.1
# ..    ...   ...      ...
# 80    제주도  2017    346.9
# 81    제주도  2018    355.8
# 82    제주도  2019    359.4
# 83    제주도  2020    362.6
# 84    제주도  2021    363.8
#
# [85 rows x 3 columns]

# %%
df_pop1_mean.columns
# Out:
# Index(['행정구역별', '인구밀도평균'], dtype='object')

# %%
df_pop1_mean.rename(columns={'행정구역별':'state', '인구밀도평균':'avg_pop_density'}, inplace=True)

# %%
# 제주도 이름 제주특별자치도로 통일

# %%
df_pop1_mean.loc[df_pop1_mean['state']=='제주도', 'state'] = df_pop1_mean.loc[df_pop1_mean['state']=='제주도', 'state'].str.replace('제주도', '제주특별자치도')

# %%
df_pop1_mean
# Out:
#       state  avg_pop_density
# 0       강원도            90.36
# 1       경기도          1303.40
# 2      경상남도           316.54
# 3      경상북도           139.72
# 4     광주광역시          2964.74
# 5     대구광역시          2744.80
# 6     대전광역시          2781.58
# 7     부산광역시          4378.44
# 8     서울특별시         15899.10
# 9   세종특별자치시           708.64
# 10    울산광역시          1074.94
# 11    인천광역시          2765.64
# 12     전라남도           144.78
# 13     전라북도           224.08
# 14  제주특별자치도           357.70
# 15     충청남도           264.24
# 16     충청북도           219.20

# %% [markdown]
# ## df_sclight1과 평균인구밀도 데이터 합치기

# %%
df_sclight1 = df_sclight1.join(df_pop1_mean.set_index('state')['avg_pop_density'], on='state')

# %%
df_sclight1[df_sclight1.avg_pop_density.isna()]
# Out:
#              address         state city        lat        long install_cnt  \
# 286646           NaN           NaN  NaN  37.322221  127.098055           1
# 286649           NaN           NaN  NaN  37.347595  127.074637           1
# 286653           NaN           NaN  NaN  37.352356  127.051022           1
# 286654           NaN           NaN  NaN  37.347878  127.075029           1
# 286655           NaN           NaN  NaN  37.352292  127.050989           1
# 286656           NaN           NaN  NaN  37.352541  127.061822           1
# 287211           NaN           NaN  NaN  37.344997  127.061633           1
# 287472           NaN           NaN  NaN  37.309964  127.076666           1
# 287558           NaN           NaN  NaN  37.319594  127.056815           1
# 287695           NaN           NaN  NaN   37.33267  127.057069           1
# 689475  35.873161183  35.873161183  NaN  35.873006  128.498271           1
# ...

# %% [markdown]
# ## 위도 & 경도만 있는 주소는 전체 데이터의 10% 미만이므로 drop 진행

# %%
df_sclight1['state'].unique()
# Out:
# array(['강원도', '경기도', '충청북도', '충청남도', nan, '경상남도', '경상북도', '광주광역시',
#        '대구광역시', '35.873161183', '대전광역시', '113-3', '487-6', '부산광역시'],
#       dtype=object)

# %%
df_sclight1[df_sclight1['state'].isna()]
# Out:
#        address state city        lat        long install_cnt        date  \
# 286646     NaN   NaN  NaN  37.322221  127.098055           1  2019-07-11
# 286649     NaN   NaN  NaN  37.347595  127.074637           1  2019-07-11
# 286653     NaN   NaN  NaN  37.352356  127.051022           1  2019-07-11
# 286654     NaN   NaN  NaN  37.347878  127.075029           1  2019-07-11
# 286655     NaN   NaN  NaN  37.352292  127.050989           1  2019-07-11
# 286656     NaN   NaN  NaN  37.352541  127.061822           1  2019-07-11
# 287211     NaN   NaN  NaN  37.344997  127.061633           1  2019-07-11
# 287472     NaN   NaN  NaN  37.309964  127.076666           1  2019-07-11
# 287558     NaN   NaN  NaN  37.319594  127.056815           1  2019-07-11
# 287695     NaN   NaN  NaN   37.33267  127.057069           1  2019-07-11
#
#         avg_pop_density
# 286646              NaN
# 286649              NaN
# 286653              NaN
# 286654              NaN
# 286655              NaN
# ...

# %%
df_sclight1['city'].unique()
# Out:
# array(['강릉시', '동해시', '삼척시', '속초시', '양구군', '양양군', '원주시', '인제군', '철원군',
#        '근남면', '철원읍', '춘천시', '태백시', '평창군', '홍천군', '횡성군', '가평군', '고양시',
#        '파주시', '과천시', '광명시', '광주시', '구리시', '군포시', '김포시', '남양주시', '동두천시',
#        '부천시', '성남시', '수원시', '용인시', '시흥시', '안산시', '안성시', '평택시', '진천군',
#        '천안시', '양주시', '의정부시', '양평군', '여주시', '연천군', '오산시', '화성시', nan,
#        '의왕시', '이천시', '아산시', '포천시', '하남시', '거제시', '거제면', '거창군', '고성군',
#        '김해시', '창원시', '진영읍', '남해군', '밀양시', '산청군', '양산시', '의령군', '진주시',
#        '창녕군', '통영시', '하동군', '함안군', '함양군', '합천군', '경산시', '경주시', '구미시',
#        '군위군', '김천시', '문경시', '봉화군', '영월군', '울진군', '영양군', '안동시', '상주시',
#        '성주군', '안막동', '영덕군', '영천시', '예천군', '청도군', '청송군', '칠곡군', '포항시',
#        '광산구', '남구', '동구', '북구', '서구', '달서구', '달성군', '수성구', '중구', '대덕구',
#        '유성구', '유성군', '강서구', '금정구', '기장군', '동래구', '부산진구', '사상구', '사하구',
#        '수영구', '연제구', '영도구', '해운대구'], dtype=object)

# %%
df_sclight1[df_sclight1['city'].isna()].index
# Out:
# Int64Index([286646, 286649, 286653, 286654, 286655, 286656, 287211, 287472,
#             287558, 287695, 689475, 747889, 748305],
#            dtype='int64')

# %%
df_sclight1.drop([286646, 286649, 286653, 286654, 286655, 286656, 287211, 287472,
            287558, 287695, 689475, 747889, 748305], axis = 0, inplace=True)

# %%
df_sclight1[df_sclight1['state'].isna()]
# Out:
# Empty DataFrame
# Columns: [address, state, city, lat, long, install_cnt, date, avg_pop_density]
# Index: []

# %%
df_sclight1[df_sclight1.avg_pop_density.isna()]
# Out:
# Empty DataFrame
# Columns: [address, state, city, lat, long, install_cnt, date, avg_pop_density]
# Index: []

# %% [markdown]
# ### --- df_sclight1 전처리 완료 ---

# %% [markdown]
# ## df_sclight1과 df_sclight2 합치기 - 1. 파일 읽고 불필요 컬럼 drop

# %%
df_sclight2 = pd.read_csv('./df_sclight2.csv', encoding = 'utf-8')

# %%
df_sclight2.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df_sclight2
# Out:
#                         address  state city        lat        long  \
# 0             서울특별시 강남구 개포동 570  서울특별시  강남구  37.476065  127.067286
# 1           서울특별시 강남구 개포동 571-1  서울특별시  강남구  37.476065  127.067286
# 2           서울특별시 강남구 개포동 572-1  서울특별시  강남구  37.477803  127.065296
# 3           서울특별시 강남구 개포동 571-1  서울특별시  강남구  37.476065  127.067286
# 4             서울특별시 강남구 개포동 570  서울특별시  강남구  37.476065  127.067286
# ...                         ...    ...  ...        ...         ...
# 824292  충청북도 충주시 수안보면 온천리 111-2   충청북도  충주시  36.845823  127.994736
# 824293  충청북도 충주시 수안보면 온천리 131-2   충청북도  충주시  36.845097  127.994223
# 824294   충청북도 충주시 수안보면 온천리 산2-3   충청북도  충주시  36.845238  127.999317
# 824295  충청북도 충주시 수안보면 안보리 산1-12   충청북도  충주시  36.845208  128.000003
# 824296  충청북도 충주시 수안보면 안보리 579-2   충청북도  충주시  36.844581  128.001291
#
#         install_cnt        date
# 0                 1  2023-01-03
# 1                 1  2023-01-03
# 2                 1  2023-01-03
# ...

# %% [markdown]
# ## df_sclight2 'city' 잘못 들어간 데이터 수정 및 평균인구밀도 데이터와 합치기

# %%
df_sclight2['state'].unique()
# Out:
# array(['서울특별시', nan, '세종특별자치시', '울산광역시', '인천광역시', '전라남도', '전라북도',
#        '제주특별자치도', '충청남도', '충청북도'], dtype=object)

# %%
df_sclight2['city'].unique()
# Out:
# array(['강남구', '강동구', '강북구', '강서구', '관악구', '동작구', '광진구', '구로구', '금천구',
#        '노원구', '도봉구', '마포구', '서대문구', '서대문구통일로39다길', '서대문구통일로39길',
#        '서대문구통일로37나길34', nan, '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구',
#        '용산구', '종로구', '중구', '중랑구', '금남면', '부강면', '소정면', '연기면', '연동면',
#        '연서면', '장군면', '전동면', '전의면', '조치원읍', '남구', '동구', '북구', '울주군', '강화군',
#        '계양구', '부평구', '남동구', '미추홀구', '서구', '연수구', '강진군', '곡성군', '광양시',
#        '구례군', '나주시', '담양군', '목포시', '무안군', '함평군', '순천시', '신안군', '여수시',
#        '영광군', '영암군', '완도군', '장성군', '장흥군', '장흥읍', '용산면', '진도군', '해남군',
#        '화순군', '고창군', '공음면', '군산시', '익산시', '김제시', '남원시', '무주군', '부안군',
#        '정읍시', '순창군', '완주군', '임실군', '진안군', '장수군', '전주시', '서귀포시', '제주시',
#        '계룡시', '공주시', '금산군', '논산시', '당진시', '보령시', '부여군', '서산시', '운산면',
#        '아산시', '서천군', '예산군', '천안시', '청양군', '태안군', '홍성군', '영동군', '괴산군',
#        '단양군', '보은군', '옥천군', '음성군', '제천시', '증평군', '청주시', '충주시'],
#       dtype=object)

# %%
df_sclight2.loc[df_sclight2['city']=='서대문구통일로39다길'] = df_sclight2.loc[df_sclight2['city']=='서대문구']
df_sclight2.loc[df_sclight2['city']=='서대문구통일로39길'] = df_sclight2.loc[df_sclight2['city']=='서대문구']
df_sclight2.loc[df_sclight2['city']=='서대문구통일로37나길34'] = df_sclight2.loc[df_sclight2['city']=='서대문구']

# %%
df_sclight2 = df_sclight2.join(df_pop1_mean.set_index('state')['avg_pop_density'], on='state')

# %%
df_sclight2
# Out:
#                         address  state city        lat        long  \
# 0             서울특별시 강남구 개포동 570  서울특별시  강남구  37.476065  127.067286
# 1           서울특별시 강남구 개포동 571-1  서울특별시  강남구  37.476065  127.067286
# 2           서울특별시 강남구 개포동 572-1  서울특별시  강남구  37.477803  127.065296
# 3           서울특별시 강남구 개포동 571-1  서울특별시  강남구  37.476065  127.067286
# 4             서울특별시 강남구 개포동 570  서울특별시  강남구  37.476065  127.067286
# ...                         ...    ...  ...        ...         ...
# 824292  충청북도 충주시 수안보면 온천리 111-2   충청북도  충주시  36.845823  127.994736
# 824293  충청북도 충주시 수안보면 온천리 131-2   충청북도  충주시  36.845097  127.994223
# 824294   충청북도 충주시 수안보면 온천리 산2-3   충청북도  충주시  36.845238  127.999317
# 824295  충청북도 충주시 수안보면 안보리 산1-12   충청북도  충주시  36.845208  128.000003
# 824296  충청북도 충주시 수안보면 안보리 579-2   충청북도  충주시  36.844581  128.001291
#
#         install_cnt        date  avg_pop_density
# 0               1.0  2023-01-03          15899.1
# 1               1.0  2023-01-03          15899.1
# ...

# %% [markdown]
# ## 위도 & 경도만 있는 주소는 전체 데이터의 약 12%정도이므로 drop 진행

# %%
drop_list = df_sclight2[df_sclight2['city'].isna() & df_sclight2['state'].isna()].index.tolist()
df_sclight2.drop(drop_list, axis=0, inplace=True)

# %% [markdown]
# ## df_sclight1과 df_sclight2 concat하여 최종본 df_sclight 생성

# %%
df_sclight = pd.concat([df_sclight1, df_sclight2], axis =0)
df_sclight.reset_index(inplace=True, drop=True)
df_sclight
# Out:
#                          address state city        lat        long  \
# 0              강원도 강릉시 장현동 463-1   강원도  강릉시   37.72858  128.887487
# 1               강원도 강릉시 장현동 40-1   강원도  강릉시  37.732262  128.900575
# 2               강원도 강릉시 장현동 97-2   강원도  강릉시  37.730126  128.900761
# 3               강원도 강릉시 담산동 55-1   강원도  강릉시  37.717822  128.904406
# 4               강원도 강릉시 담산동 55-1   강원도  강릉시  37.717822  128.904406
# ...                          ...   ...  ...        ...         ...
# 1688370  충청북도 충주시 수안보면 온천리 111-2  충청북도  충주시  36.845823  127.994736
# 1688371  충청북도 충주시 수안보면 온천리 131-2  충청북도  충주시  36.845097  127.994223
# 1688372   충청북도 충주시 수안보면 온천리 산2-3  충청북도  충주시  36.845238  127.999317
# 1688373  충청북도 충주시 수안보면 안보리 산1-12  충청북도  충주시  36.845208  128.000003
# 1688374  충청북도 충주시 수안보면 안보리 579-2  충청북도  충주시  36.844581  128.001291
#
#         install_cnt        date  avg_pop_density
# 0                 1  2022-07-20            90.36
# 1                 1  2022-07-20            90.36
# ...

# %% [markdown]
# ### install_cnt type 정수형으로 통일

# %%
df_sclight = df_sclight.astype({'install_cnt':'int32'})
df_sclight
# Out:
#                          address state city        lat        long  \
# 0              강원도 강릉시 장현동 463-1   강원도  강릉시   37.72858  128.887487
# 1               강원도 강릉시 장현동 40-1   강원도  강릉시  37.732262  128.900575
# 2               강원도 강릉시 장현동 97-2   강원도  강릉시  37.730126  128.900761
# 3               강원도 강릉시 담산동 55-1   강원도  강릉시  37.717822  128.904406
# 4               강원도 강릉시 담산동 55-1   강원도  강릉시  37.717822  128.904406
# ...                          ...   ...  ...        ...         ...
# 1688370  충청북도 충주시 수안보면 온천리 111-2  충청북도  충주시  36.845823  127.994736
# 1688371  충청북도 충주시 수안보면 온천리 131-2  충청북도  충주시  36.845097  127.994223
# 1688372   충청북도 충주시 수안보면 온천리 산2-3  충청북도  충주시  36.845238  127.999317
# 1688373  충청북도 충주시 수안보면 안보리 산1-12  충청북도  충주시  36.845208  128.000003
# 1688374  충청북도 충주시 수안보면 안보리 579-2  충청북도  충주시  36.844581  128.001291
#
#          install_cnt        date  avg_pop_density
# 0                  1  2022-07-20            90.36
# 1                  1  2022-07-20            90.36
# ...

# %% [markdown]
# ### 중복값 확인하려 했으나 실제로 같은 주소에 보안등이 2개 이상 있는 경우가 있어 따로 제거하지 않기로 결정

# %%
df_sclight[df_sclight.duplicated(subset=['address', 'lat', 'long', 'date'])]
# Out:
#                           address state city        lat        long  \
# 4                강원도 강릉시 담산동 55-1   강원도  강릉시  37.717822  128.904406
# 150             강원도 강릉시 노암동 372-2   강원도  강릉시  37.743866  128.899522
# 244              강원도 강릉시 노암동 28-6   강원도  강릉시        NaN         NaN
# 289             강원도 강릉시 노암동 730-1   강원도  강릉시  37.747694  128.894354
# 298             강원도 강릉시 노암동 214-2   강원도  강릉시        NaN         NaN
# ...                           ...   ...  ...        ...         ...
# 1681826        충청북도 충주시 용두동 462-1  충청북도  충주시  36.962593  127.882853
# 1684194      충청북도 충주시 동량면 조동리 180  충청북도  충주시  37.029975  127.996712
# 1684486        충청북도 충주시 목행동 816-6  충청북도  충주시  37.007044  127.916441
# 1686214  충청북도 충주시 산척면 영덕리 1744-58  충청북도  충주시  37.070934  127.955033
# 1686215  충청북도 충주시 산척면 영덕리 1744-58  충청북도  충주시  37.070934  127.955033
#
#          install_cnt        date  avg_pop_density
# 4                  1  2022-07-20            90.36
# ...

# %%
df_sclight[df_sclight['lat'].isna()]
# Out:
#                          address state city  lat long  install_cnt  \
# 5              강원도 강릉시 담산동 322-3   강원도  강릉시  NaN  NaN            1
# 6                강원도 강릉시 박월동 370   강원도  강릉시  NaN  NaN            1
# 13             강원도 강릉시 노암동 217-1   강원도  강릉시  NaN  NaN            1
# 21               강원도 강릉시 장현동 224   강원도  강릉시  NaN  NaN            1
# 22               강원도 강릉시 장현동 282   강원도  강릉시  NaN  NaN            1
# ...                          ...   ...  ...  ...  ...          ...
# 1652938   충청북도 증평군 도안면 화성리 산45-1  충청북도  증평군  NaN  NaN            1
# 1652939   충청북도 증평군 도안면 화성리 산46-1  충청북도  증평군  NaN  NaN            1
# 1652940   충청북도 증평군 도안면 화성리 산46-1  충청북도  증평군  NaN  NaN            1
# 1652941  충청북도 증평군 도안면 송정리 147-10  충청북도  증평군  NaN  NaN            1
# 1652942   충청북도 증평군 도안면 도당리 163-1  충청북도  증평군  NaN  NaN            1
#
#                date  avg_pop_density
# 5        2022-07-20            90.36
# 6        2022-07-20            90.36
# 13       2022-07-20            90.36
# ...

# %% [markdown]
# ## 최종본(df_sclight).csv로 저장, 해당 파일 read시 encoding='cp949' 지정 필수

# %%
df_sclight.to_csv("./df_sclight.csv", index=False, encoding='cp949')

# %% [markdown]
# ### df_sclight와 저장된 df_sclight와 차이가 있는지 확인 => 결과: 차이 없음

# %%
df_sclight_check = pd.read_csv('./df_sclight.csv', encoding='cp949')
df_sclight_check
# Out:
#                          address state city        lat        long  \
# 0              강원도 강릉시 장현동 463-1   강원도  강릉시  37.728580  128.887487
# 1               강원도 강릉시 장현동 40-1   강원도  강릉시  37.732262  128.900575
# 2               강원도 강릉시 장현동 97-2   강원도  강릉시  37.730126  128.900761
# 3               강원도 강릉시 담산동 55-1   강원도  강릉시  37.717822  128.904406
# 4               강원도 강릉시 담산동 55-1   강원도  강릉시  37.717822  128.904406
# ...                          ...   ...  ...        ...         ...
# 1688370  충청북도 충주시 수안보면 온천리 111-2  충청북도  충주시  36.845823  127.994736
# 1688371  충청북도 충주시 수안보면 온천리 131-2  충청북도  충주시  36.845097  127.994223
# 1688372   충청북도 충주시 수안보면 온천리 산2-3  충청북도  충주시  36.845238  127.999317
# 1688373  충청북도 충주시 수안보면 안보리 산1-12  충청북도  충주시  36.845208  128.000003
# 1688374  충청북도 충주시 수안보면 안보리 579-2  충청북도  충주시  36.844581  128.001291
#
#          install_cnt        date  avg_pop_density
# 0                  1  2022-07-20            90.36
# 1                  1  2022-07-20            90.36
# ...

# %%
df_sclight_check[df_sclight_check['state']=='제주특별자치도']['avg_pop_density'].unique()
# Out:
# array([357.7])

# %%
# end of file
