# %% [markdown]
# <h1>목차<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import numpy as np

# %%
df_index = pd.read_csv('./df_G_index.csv', encoding='cp949')
df_index
# Out:
#       state  visit_pop_mms  light_pop_mms  bell_pop_mms  crime_pop_mms  \
# 0       강원도       1.000000       0.537311      0.669186       0.926865
# 1       경기도       0.165054       0.107417      0.472804       0.584376
# 2      경상남도       0.273093       0.300233      0.241883       0.701634
# 3      경상북도       0.236277       0.630034      0.458441       1.000000
# 4     광주광역시       0.048972       0.032875      0.015489       0.011849
# 5     대구광역시       0.075683       0.051956      0.015586       0.038515
# 6     대전광역시       0.054547       0.054290      0.022430       0.016546
# 7     부산광역시       0.029319       0.006200      0.003230       0.036950
# 8     서울특별시       0.000000       0.000000      0.060213       0.019975
# 9   세종특별자치시       0.034686       0.024407      0.000000       0.000000
# 10    울산광역시       0.120941       0.079476      0.781925       0.021558
# 11    인천광역시       0.057292       0.021768      0.148108       0.048625
# ...

# %%
df_index.columns
# Out:
# Index(['state', 'visit_pop_mms', 'light_pop_mms', 'bell_pop_mms',
#        'crime_pop_mms', 'G_index'],
#       dtype='object')

# %%
df_concat = pd.read_csv('./df_security_concat_9.csv', encoding='cp949')
df_concat
# Out:
#    state city  visit_cnt  cctv_cnt  sclight_cnt  smalight_cnt  crime_rate  \
# 0    강원도  정선군    8151609     515.0       4391.0          13.0      0.0271
# 1    강원도  평창군   13399820     190.0       6747.0          46.0      0.0271
# 2    강원도  홍천군   15125927     428.0       1191.0          37.0      0.0271
# 3    강원도  양구군    1828609     296.0        190.0          22.0      0.0271
# 4    강원도  고성군   11612683     422.0       4391.0          94.0      0.0271
# ..   ...  ...        ...       ...          ...           ...         ...
# 73  충청북도  제천시   12125010     979.0       9024.0         314.0      0.0299
# 74  충청북도  보은군    4737641     316.0       6349.0          99.0      0.0299
# 75  충청북도  충주시   14797862    1578.0      10600.0         219.0      0.0299
# 76  충청북도  영동군    4133509       1.0       6076.0         112.0      0.0299
# 77  충청북도  단양군    6679972     287.0       1499.0          21.0      0.0299
#
#     avg_pop_density  mean_hours  mean_days new_state
# ...

# %%
df_concat_index1 = df_concat.join(df_index.set_index('state')['visit_pop_mms'], on='state')
df_concat_index2 = df_concat_index1.join(df_index.set_index('state')['light_pop_mms'], on='state')
df_concat_index3 = df_concat_index2.join(df_index.set_index('state')['bell_pop_mms'], on='state')
df_concat_index4 = df_concat_index3.join(df_index.set_index('state')['crime_pop_mms'], on='state')
df_concat_index = df_concat_index4.join(df_index.set_index('state')['G_index'], on='state')
df_concat_index
# Out:
#    state city  visit_cnt  cctv_cnt  sclight_cnt  smalight_cnt  crime_rate  \
# 0    강원도  정선군    8151609     515.0       4391.0          13.0      0.0271
# 1    강원도  평창군   13399820     190.0       6747.0          46.0      0.0271
# 2    강원도  홍천군   15125927     428.0       1191.0          37.0      0.0271
# 3    강원도  양구군    1828609     296.0        190.0          22.0      0.0271
# 4    강원도  고성군   11612683     422.0       4391.0          94.0      0.0271
# ..   ...  ...        ...       ...          ...           ...         ...
# 73  충청북도  제천시   12125010     979.0       9024.0         314.0      0.0299
# 74  충청북도  보은군    4737641     316.0       6349.0          99.0      0.0299
# 75  충청북도  충주시   14797862    1578.0      10600.0         219.0      0.0299
# 76  충청북도  영동군    4133509       1.0       6076.0         112.0      0.0299
# 77  충청북도  단양군    6679972     287.0       1499.0          21.0      0.0299
#
#     avg_pop_density  mean_hours  mean_days new_state  visit_pop_mms  \
# ...

# %%
df_concat_index.to_csv("./df_concat_index.csv", index=False, encoding='cp949')
